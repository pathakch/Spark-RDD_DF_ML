# %%
import pyspark
import findspark
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import Row
from pyspark.sql import *
sc=SparkContext.getOrCreate(SparkConf().setMaster("local[*]")) # '*' denotes maximum number of core processor used 
sqlcontext=SQLContext(sc)

# %% [markdown]
# Creating a RDD reading a csv file with the help of SparkContext (sc).

# %%
input_file_path="file:///C:/Users/ckp43_000/Documents/movie_file/ratings.csv"

# creating RDD reading a csv file with the help of SparkContext.
lines_rdd=sc.textFile(input_file_path)

# Checking RDD has been created or not.
lines_rdd
# Out:
# file:///C:/Users/ckp43_000/Documents/movie_file/ratings.csv MapPartitionsRDD[20] at textFile at NativeMethodAccessorImpl.java:0

# %%
lines_rdd.collect()
# Out:
# ['1,1,4.0,964982703',
#  '1,3,4.0,964981247',
#  '1,6,4.0,964982224',
#  '1,47,5.0,964983815',
#  '1,50,5.0,964982931',
#  '1,70,3.0,964982400',
#  '1,101,5.0,964980868',
#  '1,110,4.0,964982176',
#  '1,151,5.0,964984041',
#  '1,157,5.0,964984100',
#  '1,163,5.0,964983650',
#  '1,216,5.0,964981208',
#  '1,223,3.0,964980985',
#  '1,231,5.0,964981179',
#  '1,235,4.0,964980908',
#  '1,260,5.0,964981680',
#  '1,296,3.0,964982967',
#  '1,316,3.0,964982310',
#  '1,333,5.0,964981179',
#  '1,349,4.0,964982563',
#  '1,356,4.0,964980962',
#  '1,362,5.0,964982588',
#  '1,367,4.0,964981710',
#  '1,423,3.0,964982363',
#  '1,441,4.0,964980868',
#  '1,457,5.0,964981909',
#  '1,480,4.0,964982346',
#  '1,500,3.0,964981208',
#  '1,527,5.0,964984002',
#  '1,543,4.0,964981179',
#  '1,552,4.0,964982653',
#  '1,553,5.0,964984153',
#  '1,590,4.0,964982546',
#  '1,592,4.0,964982271',
#  '1,593,4.0,964983793',
#  '1,596,5.0,964982838',
#  '1,608,5.0,964982931',
#  '1,648,3.0,964982563',
#  '1,661,5.0,964982838',
#  '1,673,3.0,964981775',
#  '1,733,4.0,964982400',
#  '1,736,3.0,964982653',
#  '1,780,3.0,964984086',
#  '1,804,4.0,964980499',
#  '1,919,5.0,964982475',
#  '1,923,5.0,964981529',
#  '1,940,5.0,964982176',
#  '1,943,4.0,964983614',
#  '1,954,5.0,964983219',
#  '1,1009,3.0,964981775',
#  '1,1023,5.0,964982681',
#  '1,1024,5.0,964982876',
#  '1,1025,5.0,964982791',
#  '1,1029,5.0,964982855',
#  '1,1030,3.0,964982903',
#  '1,1031,5.0,964982653',
#  '1,1032,5.0,964982791',
#  '1,1042,4.0,964981179',
#  '1,1049,5.0,964982400',
#  '1,1060,4.0,964980924',
#  '1,1073,5.0,964981680',
#  '1,1080,5.0,964981327',
#  '1,1089,5.0,964982951',
#  '1,1090,4.0,964984018',
#  '1,1092,5.0,964983484',
#  '1,1097,5.0,964981680',
#  '1,1127,4.0,964982513',
#  '1,1136,5.0,964981327',
#  '1,1196,5.0,964981827',
#  '1,1197,5.0,964981872',
#  '1,1198,5.0,964981827',
#  '1,1206,5.0,964983737',
#  '1,1208,4.0,964983250',
#  '1,1210,5.0,964980499',
#  '1,1213,5.0,964982951',
#  '1,1214,4.0,964981855',
#  '1,1219,2.0,964983393',
#  '1,1220,5.0,964981909',
#  '1,1222,5.0,964981909',
#  '1,1224,5.0,964984018',
#  '1,1226,5.0,964983618',
#  '1,1240,5.0,964983723',
#  '1,1256,5.0,964981442',
#  '1,1258,3.0,964983414',
#  '1,1265,4.0,964983599',
#  '1,1270,5.0,964983705',
#  '1,1275,5.0,964982290',
#  '1,1278,5.0,964983414',
#  '1,1282,5.0,964982703',
#  '1,1291,5.0,964981909',
#  '1,1298,5.0,964984086',
#  '1,1348,4.0,964983393',
#  '1,1377,3.0,964982653',
#  '1,1396,3.0,964983017',
#  '1,1408,3.0,964982310',
#  '1,1445,3.0,964984112',
#  '1,1473,4.0,964980875',
#  '1,1500,4.0,964980985',
#  '1,1517,5.0,964981107',
#  '1,1552,4.0,964982620',
#  '1,1573,5.0,964982290',
#  '1,1580,3.0,964981125',
#  '1,1587,5.0,964982346',
#  '1,1617,5.0,964982951',
#  '1,1620,4.0,964983056',
#  '1,1625,5.0,964983504',
#  '1,1644,3.0,964983536',
#  '1,1676,3.0,964982620',
#  '1,1732,5.0,964981125',
#  '1,1777,4.0,964981230',
#  '1,1793,4.0,964981404',
#  '1,1804,5.0,964983034',
#  '1,1805,4.0,964983056',
#  '1,1920,4.0,964981780',
#  '1,1927,5.0,964981497',
#  '1,1954,5.0,964982176',
#  '1,1967,4.0,964981710',
#  '1,2000,4.0,964982211',
#  '1,2005,5.0,964981710',
#  '1,2012,4.0,964984176',
#  '1,2018,5.0,964980523',
#  '1,2028,4.0,964981888',
#  '1,2033,5.0,964982903',
#  '1,2046,4.0,964982563',
#  '1,2048,5.0,964982791',
#  '1,2054,4.0,964981747',
#  '1,2058,5.0,964982400',
#  '1,2078,5.0,964982838',
#  '1,2090,5.0,964982838',
#  '1,2093,3.0,964981710',
#  '1,2094,5.0,964982653',
#  '1,2096,4.0,964982838',
#  '1,2099,4.0,964982588',
#  '1,2105,4.0,964981725',
#  '1,2115,5.0,964982529',
#  '1,2116,5.0,964982876',
#  '1,2137,5.0,964982791',
#  '1,2139,5.0,964982791',
#  '1,2141,5.0,964982838',
#  '1,2143,4.0,964981725',
#  '1,2161,5.0,964981710',
#  '1,2174,4.0,964981680',
#  '1,2193,4.0,964981710',
#  '1,2253,2.0,964981775',
#  '1,2268,4.0,964982989',
#  '1,2273,4.0,964982310',
#  '1,2291,5.0,964983664',
#  '1,2329,5.0,964983263',
#  '1,2338,2.0,964983546',
#  '1,2353,5.0,964983861',
#  '1,2366,4.0,964982462',
#  '1,2387,5.0,964983123',
#  '1,2389,2.0,964983094',
#  '1,2395,5.0,964981093',
#  '1,2406,4.0,964982310',
#  '1,2414,3.0,964982513',
#  '1,2427,5.0,964982242',
#  '1,2450,4.0,964982620',
#  '1,2459,5.0,964983414',
#  '1,2470,5.0,964982588',
#  '1,2478,4.0,964984169',
#  '1,2492,4.0,965719662',
#  '1,2502,5.0,964981278',
#  '1,2528,3.0,964982328',
#  '1,2529,5.0,964982242',
#  '1,2542,5.0,964981265',
#  '1,2571,5.0,964981888',
#  '1,2580,5.0,964983000',
#  '1,2596,5.0,964981144',
#  '1,2616,4.0,964983080',
#  '1,2617,2.0,964982588',
#  '1,2628,4.0,964980523',
#  '1,2640,4.0,964982377',
#  '1,2641,5.0,964982620',
#  '1,2644,4.0,964983393',
#  '1,2648,4.0,964983414',
#  '1,2654,5.0,964983393',
#  '1,2657,3.0,964983426',
#  '1,2692,5.0,964981855',
#  '1,2700,5.0,964980985',
#  '1,2716,5.0,964983414',
#  '1,2761,5.0,964982703',
#  '1,2797,4.0,964981710',
#  '1,2826,4.0,964980523',
#  '1,2858,5.0,964980868',
#  '1,2872,5.0,964981680',
#  '1,2899,5.0,964982703',
#  '1,2916,4.0,964982290',
#  '1,2944,5.0,964981872',
#  '1,2947,5.0,964982176',
#  '1,2948,5.0,964982191',
#  '1,2949,5.0,964981888',
#  '1,2959,5.0,964983282',
#  '1,2985,4.0,964983034',
#  '1,2987,5.0,964982495',
#  '1,2991,5.0,964982271',
#  '1,2993,5.0,964982242',
#  '1,2997,4.0,964980896',
#  '1,3033,5.0,964983762',
#  '1,3034,5.0,964982791',
#  '1,3052,5.0,964981208',
#  '1,3053,5.0,964984086',
#  '1,3062,4.0,964981872',
#  '1,3147,5.0,964983873',
#  '1,3168,4.0,964982495',
#  '1,3176,1.0,964983504',
#  '1,3243,3.0,964981093',
#  '1,3247,3.0,964983108',
#  '1,3253,5.0,964981107',
#  '1,3273,5.0,964983536',
#  '1,3386,5.0,964983484',
#  '1,3439,4.0,964981799',
#  '1,3440,4.0,964981799',
#  '1,3441,5.0,964982328',
#  '1,3448,5.0,964984054',
#  '1,3450,5.0,964981144',
#  '1,3479,4.0,964981725',
#  '1,3489,4.0,964981775',
#  '1,3527,4.0,964982271',
#  '1,3578,5.0,964980668',
#  '1,3617,4.0,964980683',
#  '1,3639,4.0,964982271',
#  '1,3671,5.0,964981589',
#  '1,3702,5.0,964983737',
#  '1,3703,5.0,964981909',
#  '1,3729,5.0,964982363',
#  '1,3740,4.0,964982417',
#  '1,3744,4.0,964980694',
#  '1,3793,5.0,964981855',
#  '1,3809,4.0,964981220',
#  '1,4006,4.0,964982903',
#  '1,5060,5.0,964984002',
#  '2,318,3.0,1445714835',
#  '2,333,4.0,1445715029',
#  '2,1704,4.5,1445715228',
#  '2,3578,4.0,1445714885',
#  '2,6874,4.0,1445714952',
#  '2,8798,3.5,1445714960',
#  '2,46970,4.0,1445715013',
#  '2,48516,4.0,1445715064',
#  '2,58559,4.5,1445715141',
#  '2,60756,5.0,1445714980',
#  '2,68157,4.5,1445715154',
#  '2,71535,3.0,1445714974',
#  '2,74458,4.0,1445714926',
#  '2,77455,3.0,1445714941',
#  '2,79132,4.0,1445714841',
#  '2,80489,4.5,1445715340',
#  '2,80906,5.0,1445715172',
#  '2,86345,4.0,1445715166',
#  '2,89774,5.0,1445715189',
#  '2,91529,3.5,1445714891',
#  '2,91658,2.5,1445714938',
#  '2,99114,3.5,1445714874',
#  '2,106782,5.0,1445714966',
#  '2,109487,3.0,1445715145',
#  '2,112552,4.0,1445714882',
#  '2,114060,2.0,1445715276',
#  '2,115713,3.5,1445714854',
#  '2,122882,5.0,1445715272',
#  '2,131724,5.0,1445714851',
#  '3,31,0.5,1306463578',
#  '3,527,0.5,1306464275',
#  '3,647,0.5,1306463619',
#  '3,688,0.5,1306464228',
#  '3,720,0.5,1306463595',
#  '3,849,5.0,1306463611',
#  '3,914,0.5,1306463567',
#  '3,1093,0.5,1306463627',
#  '3,1124,0.5,1306464216',
#  '3,1263,0.5,1306463569',
#  '3,1272,0.5,1306463624',
#  '3,1275,3.5,1306463323',
#  '3,1302,0.5,1306464189',
#  '3,1371,3.0,1306463561',
#  '3,1587,4.5,1306464003',
#  '3,2018,0.5,1306464175',
#  '3,2080,0.5,1306463572',
#  '3,2090,0.5,1306464261',
#  '3,2105,2.0,1306463559',
#  '3,2288,4.0,1306463631',
#  '3,2424,0.5,1306464293',
#  '3,2851,5.0,1306463925',
#  '3,3024,4.5,1306464054',
#  '3,3210,0.5,1306463638',
#  '3,3703,5.0,1306463603',
#  '3,3949,0.5,1306464245',
#  '3,4518,5.0,1306463770',
#  '3,5048,0.5,1306464284',
#  '3,5181,5.0,1306463718',
#  '3,5746,5.0,1306463708',
#  '3,5764,4.5,1306464021',
#  '3,5919,5.0,1306463825',
#  '3,6238,0.5,1306464204',
#  '3,6835,5.0,1306463670',
#  '3,7899,4.5,1306464036',
#  '3,7991,5.0,1306463684',
#  '3,26409,4.5,1306463993',
#  '3,70946,5.0,1306463815',
#  '3,72378,0.5,1306464164',
#  '4,21,3.0,986935199',
#  '4,32,2.0,945173447',
#  '4,45,3.0,986935047',
#  '4,47,2.0,945173425',
#  '4,52,3.0,964622786',
#  '4,58,3.0,964538444',
#  '4,106,4.0,986848784',
#  '4,125,5.0,964622758',
#  '4,126,1.0,986848920',
#  '4,162,5.0,945078571',
#  '4,171,3.0,945078428',
#  '4,176,5.0,964622565',
#  '4,190,2.0,945079259',
#  '4,215,5.0,945079078',
#  '4,222,1.0,945629040',
#  '4,232,5.0,964622684',
#  '4,235,2.0,945173513',
#  '4,247,3.0,986848894',
#  '4,260,5.0,945079259',
#  '4,265,5.0,964538468',
#  '4,296,1.0,945173350',
#  '4,319,5.0,945079182',
#  '4,342,5.0,964538500',
#  '4,345,4.0,945629063',
#  '4,348,4.0,964622786',
#  '4,351,3.0,986934901',
#  '4,357,3.0,964623306',
#  '4,368,4.0,945078690',
#  '4,417,2.0,945078467',
#  '4,441,1.0,986934915',
#  '4,450,2.0,986848828',
#  '4,457,5.0,945079259',
#  '4,475,5.0,945174290',
#  '4,492,5.0,945079872',
#  '4,509,1.0,945079106',
#  '4,538,5.0,945078636',
#  '4,539,1.0,964538832',
#  '4,553,2.0,945079301',
#  '4,588,4.0,945079670',
#  '4,593,5.0,964539986',
#  '4,595,3.0,986848609',
#  '4,599,2.0,945078587',
#  '4,608,5.0,964540008',
#  '4,648,3.0,945079906',
#  '4,708,4.0,986935230',
#  '4,759,3.0,945078601',
#  '4,800,4.0,945079106',
#  '4,892,4.0,964622714',
#  '4,898,5.0,964623347',
#  '4,899,4.0,945079653',
#  '4,902,4.0,945078446',
#  '4,904,4.0,945079837',
#  '4,908,5.0,945173902',
#  '4,910,5.0,945173989',
#  '4,912,5.0,945173902',
#  '4,914,5.0,945079670',
#  '4,919,5.0,945079521',
#  '4,920,5.0,945173602',
#  '4,930,5.0,964538571',
#  '4,937,3.0,986849085',
#  '4,1025,4.0,945079232',
#  '4,1046,5.0,945173654',
#  '4,1057,3.0,964540578',
#  '4,1060,2.0,986934819',
#  '4,1073,4.0,945079483',
#  '4,1077,5.0,945173692',
#  '4,1079,2.0,945078946',
#  '4,1080,5.0,986934696',
#  '4,1084,5.0,945079259',
#  '4,1086,5.0,964539723',
#  '4,1094,3.0,964538500',
#  '4,1103,5.0,964539723',
#  '4,1136,5.0,986934625',
#  '4,1179,4.0,964539180',
#  '4,1183,1.0,964778513',
#  '4,1188,5.0,964538500',
#  '4,1196,5.0,964538763',
#  '4,1197,5.0,964538763',
#  '4,1198,3.0,964538728',
#  '4,1199,2.0,945078967',
#  '4,1203,5.0,945174025',
#  '4,1211,1.0,964539205',
#  '4,1213,4.0,945079729',
#  '4,1219,4.0,964539961',
#  '4,1225,4.0,964539326',
#  '4,1250,5.0,945174008',
#  '4,1259,4.0,964538728',
#  '4,1265,4.0,964622684',
#  '4,1266,4.0,986849037',
#  '4,1279,2.0,986934832',
#  '4,1282,5.0,945079653',
#  '4,1283,5.0,945078690',
#  '4,1288,4.0,945079653',
#  '4,1291,4.0,964538763',
#  '4,1304,3.0,945078467',
#  '4,1391,1.0,945173766',
#  '4,1449,5.0,945079767',
#  '4,1466,4.0,945173492',
#  '4,1500,4.0,964622830',
#  '4,1517,4.0,945079790',
#  '4,1580,3.0,986935244',
#  '4,1597,1.0,945079906',
#  '4,1617,2.0,945079837',
#  '4,1641,4.0,964622758',
#  '4,1704,1.0,945629015',
#  '4,1719,4.0,945079956',
#  '4,1732,4.0,945079889',
#  '4,1733,5.0,945079143',
#  '4,1734,3.0,964539357',
#  '4,1834,5.0,945174134',
#  '4,1860,2.0,986849001',
#  '4,1883,4.0,964622642',
#  '4,1885,3.0,964622617',
#  '4,1892,2.0,964539431',
#  '4,1895,4.0,945629179',
#  '4,1907,3.0,964540505',
#  '4,1914,4.0,964622714',
#  '4,1916,1.0,986934786',
#  '4,1923,3.0,986934870',
#  '4,1947,5.0,945079653',
#  '4,1966,2.0,964622684',
#  '4,1967,5.0,945078967',
#  '4,1968,4.0,986934786',
#  '4,2019,2.0,945078690',
#  '4,2076,4.0,945079052',
#  '4,2078,5.0,945079521',
#  '4,2109,4.0,986935016',
#  '4,2145,3.0,986935328',
#  '4,2150,5.0,986934738',
#  '4,2174,5.0,964539855',
#  '4,2186,5.0,945174008',
#  '4,2203,4.0,945079729',
#  '4,2204,5.0,964540008',
#  '4,2282,1.0,945629238',
#  '4,2324,1.0,964622590',
#  '4,2336,2.0,964538964',
#  '4,2351,4.0,945078467',
#  '4,2359,4.0,964622590',
#  '4,2390,5.0,945079164',
#  '4,2395,3.0,964623306',
#  '4,2406,4.0,986935302',
#  '4,2467,4.0,945079858',
#  '4,2571,1.0,945173385',
#  '4,2583,5.0,945078863',
#  '4,2599,5.0,964622684',
#  '4,2628,1.0,986848894',
#  '4,2683,4.0,945079790',
#  '4,2692,5.0,945079013',
#  '4,2712,2.0,945078542',
#  '4,2762,4.0,964539986',
#  '4,2763,1.0,964778621',
#  '4,2770,2.0,945173553',
#  '4,2791,5.0,964539628',
#  '4,2843,5.0,945078814',
#  '4,2858,5.0,964539140',
#  '4,2874,4.0,986935016',
#  '4,2921,4.0,945078708',
#  '4,2926,5.0,986934870',
#  '4,2959,2.0,945078528',
#  '4,2973,2.0,945078946',
#  '4,2997,4.0,986848610',
#  '4,3033,4.0,986936200',
#  '4,3044,5.0,945079920',
#  '4,3060,4.0,986934884',
#  '4,3079,3.0,964778197',
#  '4,3083,5.0,964622487',
#  '4,3160,4.0,964539121',
#  '4,3175,1.0,964538930',
#  '4,3176,4.0,964539771',
#  '4,3204,4.0,964539828',
#  '4,3255,4.0,964623306',
#  '4,3317,4.0,986934498',
#  '4,3358,3.0,964622758',
#  '4,3365,5.0,964538329',
#  '4,3386,4.0,964539395',
#  '4,3408,4.0,986849238',
#  '4,3481,2.0,964538243',
#  '4,3489,1.0,986848908',
#  '4,3508,5.0,964538351',
#  '4,3538,2.0,986849212',
#  '4,3591,1.0,986935199',
#  '4,3788,3.0,964539085',
#  '4,3809,3.0,986936207',
#  '4,3851,5.0,986849180',
#  '4,3897,4.0,986934465',
#  '4,3911,3.0,986849149',
#  '4,3967,4.0,986849164',
#  '4,3996,4.0,986849130',
#  '4,4002,3.0,986934819',
#  '4,4014,1.0,986849254',
#  '4,4020,3.0,986848856',
#  '4,4021,4.0,986849180',
#  '4,4027,3.0,986849201',
#  '4,4029,3.0,986849226',
#  '4,4033,4.0,986849149',
#  '4,4034,5.0,986848753',
#  '4,4074,3.0,986848665',
#  '4,4121,4.0,986934901',
#  '4,4144,3.0,986848685',
#  '4,4166,3.0,986848700',
#  '4,4226,2.0,1007569424',
#  '4,4239,5.0,986848685',
#  '4,4246,4.0,1007574542',
#  '4,4252,3.0,1007569465',
#  '4,4260,2.0,1007569424',
#  '4,4273,4.0,1007574470',
#  '4,4308,1.0,1007569465',
#  '4,4347,4.0,1007569586',
#  '4,4381,3.0,1007574509',
#  '4,4641,1.0,1007569586',
#  '4,4741,3.0,1007574532',
#  '4,4765,5.0,1007569445',
#  '4,4881,3.0,1007569445',
#  '4,4896,4.0,1007574532',
#  '4,4902,4.0,1007569465',
#  '4,4967,5.0,1007569424',
#  '5,1,4.0,847434962',
#  '5,21,4.0,847435238',
#  '5,34,4.0,847434881',
#  '5,36,4.0,847435292',
#  '5,39,3.0,847434961',
#  '5,50,4.0,847434881',
#  '5,58,5.0,847435238',
#  '5,110,4.0,847434880',
#  '5,150,3.0,847434748',
#  '5,153,3.0,847434802',
#  '5,232,4.0,847435292',
#  '5,247,5.0,847435337',
#  '5,253,3.0,847435292',
#  '5,261,4.0,847435238',
#  '5,265,3.0,847435129',
#  '5,266,1.0,847435311',
#  '5,290,5.0,847435311',
#  '5,296,5.0,847434748',
#  '5,300,3.0,847435337',
#  '5,316,2.0,847434832',
#  '5,318,3.0,847434880',
#  '5,344,3.0,847434802',
#  '5,349,3.0,847434832',
#  '5,357,2.0,847435238',
#  '5,364,3.0,847434882',
#  '5,367,4.0,847435129',
#  '5,380,2.0,847434748',
#  '5,410,3.0,847435292',
#  '5,457,4.0,847434801',
#  '5,474,4.0,847435337',
#  '5,475,5.0,847435311',
#  '5,515,3.0,847435129',
#  '5,527,5.0,847434960',
#  '5,531,4.0,847435258',
#  '5,534,3.0,847435311',
#  '5,588,4.0,847434801',
#  '5,589,3.0,847435258',
#  '5,590,5.0,847434747',
#  '5,592,3.0,847434747',
#  '5,594,5.0,847435238',
#  '5,595,5.0,847434832',
#  '5,596,5.0,847435292',
#  '5,597,3.0,847434962',
#  '5,608,3.0,847435258',
#  '6,2,4.0,845553522',
#  '6,3,5.0,845554296',
#  '6,4,3.0,845554349',
#  '6,5,5.0,845553938',
#  '6,6,4.0,845553757',
#  '6,7,4.0,845554264',
#  '6,8,3.0,845555281',
#  '6,10,3.0,845553253',
#  '6,11,4.0,845553489',
#  '6,13,3.0,845555588',
#  '6,15,4.0,845554505',
#  '6,16,4.0,845553819',
#  '6,17,4.0,845553559',
#  '6,19,2.0,845553382',
#  '6,21,2.0,845553382',
#  '6,22,5.0,845553875',
#  '6,24,4.0,845554397',
#  '6,25,3.0,845553695',
#  '6,26,4.0,845555362',
#  '6,27,3.0,845555402',
#  '6,31,3.0,845553819',
#  '6,32,4.0,845553426',
#  '6,34,4.0,845553354',
#  '6,36,5.0,845553726',
#  '6,41,4.0,845554962',
#  '6,43,4.0,845555607',
#  '6,45,3.0,845553907',
#  '6,46,4.0,845554551',
#  '6,47,4.0,845553317',
#  '6,50,1.0,845553381',
#  '6,54,4.0,845555402',
#  '6,60,4.0,845554263',
#  '6,61,4.0,845555454',
#  '6,62,4.0,845553660',
#  '6,65,3.0,845555070',
#  '6,66,3.0,845555151',
#  '6,76,4.0,845555317',
#  '6,79,3.0,845554907',
#  '6,86,5.0,845556131',
#  '6,87,3.0,845555300',
#  '6,88,2.0,845555694',
#  '6,89,4.0,845555124',
#  '6,92,4.0,845555454',
#  '6,93,4.0,845554584',
#  '6,95,4.0,845553559',
#  '6,100,3.0,845555151',
#  '6,102,1.0,845555436',
#  '6,104,4.0,845554349',
#  '6,105,3.0,845553757',
#  '6,110,5.0,845553283',
#  '6,112,4.0,845553994',
#  '6,113,3.0,845556257',
#  '6,126,3.0,845555342',
#  '6,135,3.0,845554987',
#  '6,140,3.0,845555024',
#  '6,141,4.0,845553586',
#  '6,145,4.0,845553966',
#  '6,146,4.0,845555607',
#  '6,150,4.0,845553110',
#  '6,151,4.0,845553586',
#  '6,153,3.0,845553146',
#  '6,158,4.0,845553660',
#  '6,159,3.0,845555006',
#  '6,160,5.0,845553457',
#  '6,161,3.0,845553253',
#  '6,163,3.0,845553907',
#  '6,165,3.0,845553146',
#  '6,168,5.0,845553695',
#  '6,170,3.0,845554263',
#  '6,171,3.0,845555402',
#  '6,174,3.0,845554479',
#  '6,177,3.0,845554931',
#  '6,179,1.0,845555362',
#  '6,180,2.0,845555006',
#  '6,181,3.0,845553938',
#  '6,185,3.0,845553283',
#  '6,186,3.0,845553619',
#  '6,189,3.0,845556241',
#  '6,191,2.0,845554931',
#  '6,195,4.0,845554455',
#  '6,196,3.0,845553586',
#  '6,201,3.0,845556290',
#  '6,204,3.0,845553619',
#  '6,205,3.0,845555477',
#  '6,207,4.0,845554024',
#  '6,208,3.0,845553253',
#  '6,209,3.0,845556106',
#  '6,210,4.0,845556310',
#  '6,212,4.0,845556181',
#  '6,216,4.0,845554099',
#  '6,217,3.0,845555382',
#  '6,218,2.0,845553994',
#  '6,219,3.0,845556131',
#  '6,222,4.0,845554024',
#  '6,224,3.0,845553794',
#  '6,225,4.0,845553381',
#  '6,230,5.0,845553966',
#  '6,231,3.0,845553174',
#  '6,234,2.0,845554176',
#  '6,236,4.0,845553559',
#  '6,237,4.0,845553875',
#  '6,239,3.0,845554987',
#  '6,240,3.0,845555571',
#  '6,243,3.0,845555588',
#  '6,248,5.0,845554263',
#  '6,250,4.0,845555588',
#  '6,251,3.0,845556257',
#  '6,252,4.0,845553619',
#  '6,253,3.0,845553283',
#  '6,254,3.0,845555655',
#  '6,256,3.0,845553726',
#  '6,257,5.0,845554176',
#  '6,258,3.0,845555172',
#  '6,261,4.0,845553695',
#  '6,262,5.0,845554551',
#  '6,265,3.0,845553726',
#  '6,266,3.0,845553457',
#  '6,267,3.0,845554376',
#  '6,270,3.0,845555172',
#  '6,271,4.0,845555249',
#  '6,273,3.0,845553875',
#  '6,274,4.0,845555151',
#  '6,276,4.0,845553907',
#  '6,277,5.0,845553844',
#  '6,279,3.0,845555436',
#  '6,281,4.0,845554320',
#  '6,282,3.0,845553522',
#  '6,288,2.0,845553283',
#  '6,289,3.0,845554455',
#  '6,291,3.0,845555571',
#  '6,292,4.0,845553253',
#  '6,293,3.0,845553660',
#  '6,296,2.0,845553110',
#  '6,302,3.0,845555436',
#  '6,303,3.0,845554099',
#  '6,304,4.0,845555546',
#  '6,310,3.0,845556119',
#  '6,312,1.0,845555151',
#  '6,313,3.0,845555546',
#  '6,314,5.0,845554603',
#  '6,315,4.0,845553522',
#  '6,316,5.0,845553174',
#  '6,317,4.0,845553457',
#  '6,318,5.0,845553200',
#  '6,327,1.0,845554062',
#  '6,329,4.0,845553200',
#  '6,330,3.0,845555071',
#  '6,332,3.0,845555046',
#  '6,333,5.0,845553757',
#  '6,336,3.0,845556223',
#  '6,337,5.0,845553586',
#  '6,339,4.0,845553253',
#  '6,340,4.0,845555265',
#  '6,342,3.0,845553938',
#  '6,343,3.0,845555172',
#  '6,344,3.0,845553146',
#  '6,347,3.0,845555300',
#  '6,348,3.0,845553938',
#  '6,349,5.0,845553146',
#  '6,350,5.0,845553489',
#  '6,351,4.0,845554455',
#  '6,352,3.0,845555382',
#  '6,353,4.0,845553726',
#  '6,354,4.0,845555402',
#  '6,355,4.0,845553819',
#  '6,356,5.0,845553200',
#  '6,357,3.0,845553457',
#  '6,358,3.0,845555265',
#  '6,359,3.0,845556412',
#  '6,360,3.0,845555094',
#  '6,361,4.0,845554376',
#  '6,362,3.0,845553994',
#  '6,364,5.0,845553317',
#  '6,366,3.0,845554962',
#  '6,367,4.0,845553317',
#  '6,368,5.0,845553726',
#  '6,370,4.0,845553794',
#  '6,371,3.0,845554141',
#  '6,374,3.0,845554296',
#  '6,377,5.0,845553317',
#  '6,378,3.0,845554987',
#  '6,380,4.0,845553110',
#  '6,381,3.0,845553994',
#  '6,382,3.0,845554397',
#  '6,383,3.0,845554320',
#  '6,405,3.0,845554603',
#  '6,410,3.0,845553354',
#  '6,412,3.0,845554505',
#  '6,415,4.0,845554420',
#  '6,416,3.0,845554962',
#  '6,419,3.0,845554224',
#  '6,426,3.0,845554551',
#  '6,432,5.0,845553489',
#  '6,434,4.0,845553200',
#  '6,435,3.0,845553489',
#  '6,437,3.0,845554505',
#  '6,440,4.0,845553457',
#  '6,445,3.0,845555124',
#  '6,450,4.0,845555024',
#  '6,454,4.0,845553283',
#  '6,455,3.0,845554062',
#  '6,457,5.0,845553174',
#  '6,458,3.0,845555546',
#  '6,460,3.0,845555281',
#  '6,466,2.0,845553844',
#  '6,468,4.0,845553907',
#  '6,469,4.0,845555477',
#  '6,472,3.0,845555632',
#  '6,474,4.0,845553522',
#  '6,475,4.0,845554099',
#  '6,477,4.0,845554141',
#  '6,480,5.0,845553200',
#  '6,485,3.0,845553794',
#  '6,489,3.0,845554505',
#  '6,490,3.0,845554584',
#  '6,491,4.0,845554141',
#  '6,493,3.0,845555172',
#  '6,494,3.0,845554176',
#  '6,497,3.0,845553819',
#  '6,500,5.0,845553354',
#  '6,502,3.0,845554455',
#  '6,505,3.0,845555317',
#  '6,508,4.0,845553586',
#  '6,509,3.0,845553522',
#  '6,510,3.0,845555546',
#  '6,515,4.0,845553794',
#  '6,516,4.0,845554908',
#  '6,520,3.0,845553844',
#  '6,524,3.0,845554479',
#  '6,527,3.0,845553426',
#  '6,531,3.0,845554296',
#  '6,532,3.0,845554224',
#  '6,536,3.0,845556181',
#  '6,537,3.0,845554551',
#  '6,539,3.0,845553426',
#  '6,540,3.0,845554099',
#  '6,542,4.0,845554524',
#  '6,543,3.0,845554099',
#  '6,546,2.0,845554349',
#  '6,548,3.0,845554908',
#  '6,552,3.0,845553875',
#  '6,553,5.0,845553559',
#  '6,569,4.0,845555342',
#  '6,575,3.0,845555070',
#  '6,587,5.0,845553381',
#  '6,588,5.0,845553146',
#  '6,589,3.0,845553317',
#  '6,590,5.0,845553109',
#  '6,592,3.0,845553109',
#  '6,593,4.0,845553174',
#  '6,594,4.0,845553819',
#  '6,595,5.0,845553174',
#  '6,596,3.0,845554141',
#  '6,597,4.0,845553354',
#  '6,606,3.0,845555024',
#  '6,608,3.0,845553844',
#  '6,609,4.0,845555342',
#  '6,616,5.0,845554062',
#  '6,628,3.0,845555300',
#  '6,631,4.0,845555265',
#  '6,637,4.0,845555046',
#  '6,640,1.0,845555362',
#  '6,647,4.0,845555151',
#  '6,662,3.0,845556147',
#  '6,667,3.0,845555342',
#  '6,694,3.0,845555694',
#  '6,697,3.0,845556378',
#  '6,700,4.0,845556147',
#  '6,704,3.0,845555571',
#  '6,708,4.0,845554376',
#  '6,709,5.0,845555249',
#  '6,710,3.0,845556223',
#  '6,711,4.0,845555317',
#  '6,719,2.0,845555694',
#  '6,736,5.0,845553619',
#  '6,747,3.0,845555046',
#  '6,762,1.0,845555006',
#  '6,765,3.0,845555632',
#  '6,775,3.0,845556462',
#  '6,780,5.0,845556915',
#  '6,783,5.0,845554584',
#  '6,795,3.0,845556506',
#  '6,799,3.0,845555656',
#  '6,801,3.0,845556194',
#  '6,802,4.0,845554584',
#  '6,818,3.0,845555514',
#  '6,830,5.0,845556222',
#  '6,835,4.0,845556194',
#  '6,837,3.0,845556241',
#  '6,838,4.0,845555514',
#  '6,839,3.0,845556120',
#  '6,842,3.0,845555675',
#  '6,848,4.0,845556340',
#  '6,852,4.0,845555694',
#  '6,867,3.0,845556412',
#  '6,880,3.0,845556181',
#  '6,881,3.0,845556340',
#  '6,888,3.0,845556448',
#  '6,891,3.0,845556241',
#  '6,979,3.0,845556808',
#  '6,981,3.0,845556567',
#  '6,986,4.0,845556475',
#  '6,991,4.0,845556808',
#  '6,996,4.0,845556323',
#  '6,999,2.0,845556412',
#  '6,1004,4.0,845556506',
#  '6,1006,4.0,845556694',
#  '6,1042,3.0,845556462',
#  '6,1049,5.0,845556694',
#  '6,1061,4.0,845556860',
#  '6,1064,4.0,845556579',
#  '6,1073,3.0,845555571',
#  '6,1082,4.0,845556278',
#  '6,1084,3.0,845555454',
#  '7,1,4.5,1106635946',
#  '7,50,4.5,1106635993',
#  '7,58,3.0,1106635520',
#  '7,150,4.5,1106635925',
#  '7,165,4.0,1106635987',
#  '7,260,5.0,1106635933',
#  '7,356,5.0,1106635915',
#  '7,380,3.0,1106635937',
#  '7,466,5.0,1106635532',
#  '7,480,5.0,1106635917',
#  '7,587,2.0,1106635714',
#  '7,588,3.0,1106635971',
#  '7,589,2.5,1106635940',
#  '7,592,3.0,1106635922',
#  '7,593,5.0,1106635912',
#  '7,595,3.5,1106712636',
#  '7,648,4.0,1106635981',
#  '7,750,4.0,1106636810',
#  '7,780,4.5,1106635943',
#  '7,920,3.0,1106635685',
#  '7,924,4.0,1106712615',
#  '7,1101,4.0,1106635502',
#  '7,1183,1.5,1106712613',
#  '7,1196,4.0,1106635996',
#  '7,1208,4.0,1106635462',
#  '7,1210,4.0,1106635965',
#  '7,1219,5.0,1106635496',
#  '7,1220,4.5,1106635464',
#  '7,1240,5.0,1106712575',
#  '7,1246,1.5,1106635678',
#  '7,1270,5.0,1106635681',
#  '7,1517,3.5,1106635489',
#  '7,1584,5.0,1106635423',
#  '7,1610,4.0,1106635429',
#  '7,1617,3.0,1107127060',
#  '7,1682,3.0,1106635653',
#  '7,1784,0.5,1106635416',
#  '7,1917,4.0,1106635484',
#  '7,1923,1.5,1106635444',
#  '7,1954,4.5,1106635657',
#  '7,2019,5.0,1106713565',
#  '7,2324,2.0,1106712559',
#  '7,2353,3.5,1106635625',
#  '7,2529,5.0,1106635640',
#  '7,2628,1.5,1106712553',
#  '7,2640,3.0,1106635540',
#  '7,2671,4.5,1113542732',
#  '7,2683,2.0,1106635420',
#  '7,2688,2.5,1106713072',
#  '7,2701,1.5,1106713076',
#  '7,2717,3.5,1106713081',
#  '7,2762,4.5,1106635648',
#  '7,2858,4.0,1106712546',
#  '7,3114,4.5,1106635500',
#  '7,3354,1.5,1106713005',
#  '7,3408,4.5,1106712549',
#  '7,3578,1.5,1106636534',
#  '7,3623,1.0,1106712541',
#  '7,3793,3.5,1106635630',
#  '7,3869,5.0,1106635733',
#  '7,3916,4.0,1106636596',
#  '7,3977,2.5,1106635635',
#  '7,3994,3.0,1161738301',
#  '7,4018,4.0,1106712913',
#  '7,4223,2.0,1106635742',
#  '7,4246,2.0,1110855253',
#  '7,4306,4.0,1106635524',
#  '7,4310,0.5,1107127033',
#  '7,4370,4.5,1106712869',
#  '7,4643,1.0,1106635749',
#  '7,4700,1.5,1109746591',
#  '7,4844,1.5,1161738352',
#  '7,4874,3.0,1106635738',
#  '7,4886,4.0,1106636531',
#  '7,4896,4.0,1106636718',
#  '7,4963,4.0,1106636702',
#  '7,4993,4.5,1106636589',
#  '7,4995,4.5,1106636610',
#  '7,5218,3.5,1106712866',
#  '7,5349,3.5,1106636606',
#  '7,5378,0.5,1106635735',
#  '7,5445,4.0,1106636707',
#  '7,5459,3.0,1106712820',
#  '7,5464,3.0,1106636612',
#  '7,5502,1.5,1106635745',
#  '7,5618,5.0,1106713586',
#  '7,5816,4.5,1106635705',
#  '7,5952,4.5,1106636527',
#  '7,5989,4.0,1106636600',
#  '7,5991,4.5,1106712818',
#  '7,6333,4.0,1106636516',
#  '7,6365,4.0,1106712831',
#  '7,6534,0.5,1157949714',
#  '7,6539,4.5,1106636584',
#  '7,6863,4.5,1106712827',
#  '7,6934,2.0,1106712812',
#  '7,7143,4.5,1106636579',
#  '7,7153,4.0,1106636520',
#  '7,7155,3.0,1173051472',
#  '7,7445,4.0,1107473963',
#  '7,8207,4.5,1106713442',
#  '7,8360,3.5,1106636782',
#  '7,8368,2.5,1106636592',
#  '7,8373,2.0,1108602792',
#  '7,8528,4.5,1106636844',
#  '7,8636,4.5,1106636511',
#  '7,8665,3.5,1108602755',
#  '7,8666,1.0,1106779625',
#  '7,8783,1.0,1161738306',
#  '7,8798,4.5,1106636602',
#  '7,8808,1.5,1109746594',
#  '7,8865,1.0,1106713549',
#  '7,8870,3.5,1118025961',
#  '7,8907,1.0,1110757877',
#  '7,8908,4.5,1122333561',
#  '7,8949,4.0,1110757890',
#  '7,8957,4.0,1106636098',
#  '7,8958,3.5,1110173697',
#  '7,8961,4.0,1106636064',
#  '7,8965,1.0,1106636095',
#  '7,8970,2.5,1106636069',
#  '7,8972,2.5,1111552650',
#  '7,8984,4.0,1106636101',
#  '7,27741,3.0,1107474020',
#  '7,30812,3.5,1113353083',
#  '7,30816,2.0,1107127004',
#  ...]

# %% [markdown]
# In above output we can see that output of rdd is in random format without any schema
#
# we cant perform most of the operation on this output format
#
# therefore we will give this rdd a schema where every records will be notified with a name
#
# for that we need to create a function which splits the values of rdd and assgign a name to each values

# %%
# Creating a function to provide a schema to RDD so that each element of the row will have a name.
def mapper(lines):
    fields=lines.split(",")
    return Row(user_id=int(fields[0]),movie_id=int(fields[1]),ratings=float(fields[2]),timestamp=int(fields[3]))

# %%
# Applying above schema on RDD with the help of 'map' function.
rating_rdd=lines_rdd.map(mapper)
rating_rdd.collect()
# Out:
# [Row(movie_id=1, ratings=4.0, timestamp=964982703, user_id=1),
#  Row(movie_id=3, ratings=4.0, timestamp=964981247, user_id=1),
#  Row(movie_id=6, ratings=4.0, timestamp=964982224, user_id=1),
#  Row(movie_id=47, ratings=5.0, timestamp=964983815, user_id=1),
#  Row(movie_id=50, ratings=5.0, timestamp=964982931, user_id=1),
#  Row(movie_id=70, ratings=3.0, timestamp=964982400, user_id=1),
#  Row(movie_id=101, ratings=5.0, timestamp=964980868, user_id=1),
#  Row(movie_id=110, ratings=4.0, timestamp=964982176, user_id=1),
#  Row(movie_id=151, ratings=5.0, timestamp=964984041, user_id=1),
#  Row(movie_id=157, ratings=5.0, timestamp=964984100, user_id=1),
#  Row(movie_id=163, ratings=5.0, timestamp=964983650, user_id=1),
#  Row(movie_id=216, ratings=5.0, timestamp=964981208, user_id=1),
#  Row(movie_id=223, ratings=3.0, timestamp=964980985, user_id=1),
#  Row(movie_id=231, ratings=5.0, timestamp=964981179, user_id=1),
#  Row(movie_id=235, ratings=4.0, timestamp=964980908, user_id=1),
#  Row(movie_id=260, ratings=5.0, timestamp=964981680, user_id=1),
#  Row(movie_id=296, ratings=3.0, timestamp=964982967, user_id=1),
#  Row(movie_id=316, ratings=3.0, timestamp=964982310, user_id=1),
#  Row(movie_id=333, ratings=5.0, timestamp=964981179, user_id=1),
#  Row(movie_id=349, ratings=4.0, timestamp=964982563, user_id=1),
#  Row(movie_id=356, ratings=4.0, timestamp=964980962, user_id=1),
#  Row(movie_id=362, ratings=5.0, timestamp=964982588, user_id=1),
#  Row(movie_id=367, ratings=4.0, timestamp=964981710, user_id=1),
#  Row(movie_id=423, ratings=3.0, timestamp=964982363, user_id=1),
#  Row(movie_id=441, ratings=4.0, timestamp=964980868, user_id=1),
#  Row(movie_id=457, ratings=5.0, timestamp=964981909, user_id=1),
#  Row(movie_id=480, ratings=4.0, timestamp=964982346, user_id=1),
#  Row(movie_id=500, ratings=3.0, timestamp=964981208, user_id=1),
#  Row(movie_id=527, ratings=5.0, timestamp=964984002, user_id=1),
#  Row(movie_id=543, ratings=4.0, timestamp=964981179, user_id=1),
#  Row(movie_id=552, ratings=4.0, timestamp=964982653, user_id=1),
#  Row(movie_id=553, ratings=5.0, timestamp=964984153, user_id=1),
#  Row(movie_id=590, ratings=4.0, timestamp=964982546, user_id=1),
#  Row(movie_id=592, ratings=4.0, timestamp=964982271, user_id=1),
#  Row(movie_id=593, ratings=4.0, timestamp=964983793, user_id=1),
#  Row(movie_id=596, ratings=5.0, timestamp=964982838, user_id=1),
#  Row(movie_id=608, ratings=5.0, timestamp=964982931, user_id=1),
#  Row(movie_id=648, ratings=3.0, timestamp=964982563, user_id=1),
#  Row(movie_id=661, ratings=5.0, timestamp=964982838, user_id=1),
#  Row(movie_id=673, ratings=3.0, timestamp=964981775, user_id=1),
#  Row(movie_id=733, ratings=4.0, timestamp=964982400, user_id=1),
#  Row(movie_id=736, ratings=3.0, timestamp=964982653, user_id=1),
#  Row(movie_id=780, ratings=3.0, timestamp=964984086, user_id=1),
#  Row(movie_id=804, ratings=4.0, timestamp=964980499, user_id=1),
#  Row(movie_id=919, ratings=5.0, timestamp=964982475, user_id=1),
#  Row(movie_id=923, ratings=5.0, timestamp=964981529, user_id=1),
#  Row(movie_id=940, ratings=5.0, timestamp=964982176, user_id=1),
#  Row(movie_id=943, ratings=4.0, timestamp=964983614, user_id=1),
#  Row(movie_id=954, ratings=5.0, timestamp=964983219, user_id=1),
#  Row(movie_id=1009, ratings=3.0, timestamp=964981775, user_id=1),
#  Row(movie_id=1023, ratings=5.0, timestamp=964982681, user_id=1),
#  Row(movie_id=1024, ratings=5.0, timestamp=964982876, user_id=1),
#  Row(movie_id=1025, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=1029, ratings=5.0, timestamp=964982855, user_id=1),
#  Row(movie_id=1030, ratings=3.0, timestamp=964982903, user_id=1),
#  Row(movie_id=1031, ratings=5.0, timestamp=964982653, user_id=1),
#  Row(movie_id=1032, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=1042, ratings=4.0, timestamp=964981179, user_id=1),
#  Row(movie_id=1049, ratings=5.0, timestamp=964982400, user_id=1),
#  Row(movie_id=1060, ratings=4.0, timestamp=964980924, user_id=1),
#  Row(movie_id=1073, ratings=5.0, timestamp=964981680, user_id=1),
#  Row(movie_id=1080, ratings=5.0, timestamp=964981327, user_id=1),
#  Row(movie_id=1089, ratings=5.0, timestamp=964982951, user_id=1),
#  Row(movie_id=1090, ratings=4.0, timestamp=964984018, user_id=1),
#  Row(movie_id=1092, ratings=5.0, timestamp=964983484, user_id=1),
#  Row(movie_id=1097, ratings=5.0, timestamp=964981680, user_id=1),
#  Row(movie_id=1127, ratings=4.0, timestamp=964982513, user_id=1),
#  Row(movie_id=1136, ratings=5.0, timestamp=964981327, user_id=1),
#  Row(movie_id=1196, ratings=5.0, timestamp=964981827, user_id=1),
#  Row(movie_id=1197, ratings=5.0, timestamp=964981872, user_id=1),
#  Row(movie_id=1198, ratings=5.0, timestamp=964981827, user_id=1),
#  Row(movie_id=1206, ratings=5.0, timestamp=964983737, user_id=1),
#  Row(movie_id=1208, ratings=4.0, timestamp=964983250, user_id=1),
#  Row(movie_id=1210, ratings=5.0, timestamp=964980499, user_id=1),
#  Row(movie_id=1213, ratings=5.0, timestamp=964982951, user_id=1),
#  Row(movie_id=1214, ratings=4.0, timestamp=964981855, user_id=1),
#  Row(movie_id=1219, ratings=2.0, timestamp=964983393, user_id=1),
#  Row(movie_id=1220, ratings=5.0, timestamp=964981909, user_id=1),
#  Row(movie_id=1222, ratings=5.0, timestamp=964981909, user_id=1),
#  Row(movie_id=1224, ratings=5.0, timestamp=964984018, user_id=1),
#  Row(movie_id=1226, ratings=5.0, timestamp=964983618, user_id=1),
#  Row(movie_id=1240, ratings=5.0, timestamp=964983723, user_id=1),
#  Row(movie_id=1256, ratings=5.0, timestamp=964981442, user_id=1),
#  Row(movie_id=1258, ratings=3.0, timestamp=964983414, user_id=1),
#  Row(movie_id=1265, ratings=4.0, timestamp=964983599, user_id=1),
#  Row(movie_id=1270, ratings=5.0, timestamp=964983705, user_id=1),
#  Row(movie_id=1275, ratings=5.0, timestamp=964982290, user_id=1),
#  Row(movie_id=1278, ratings=5.0, timestamp=964983414, user_id=1),
#  Row(movie_id=1282, ratings=5.0, timestamp=964982703, user_id=1),
#  Row(movie_id=1291, ratings=5.0, timestamp=964981909, user_id=1),
#  Row(movie_id=1298, ratings=5.0, timestamp=964984086, user_id=1),
#  Row(movie_id=1348, ratings=4.0, timestamp=964983393, user_id=1),
#  Row(movie_id=1377, ratings=3.0, timestamp=964982653, user_id=1),
#  Row(movie_id=1396, ratings=3.0, timestamp=964983017, user_id=1),
#  Row(movie_id=1408, ratings=3.0, timestamp=964982310, user_id=1),
#  Row(movie_id=1445, ratings=3.0, timestamp=964984112, user_id=1),
#  Row(movie_id=1473, ratings=4.0, timestamp=964980875, user_id=1),
#  Row(movie_id=1500, ratings=4.0, timestamp=964980985, user_id=1),
#  Row(movie_id=1517, ratings=5.0, timestamp=964981107, user_id=1),
#  Row(movie_id=1552, ratings=4.0, timestamp=964982620, user_id=1),
#  Row(movie_id=1573, ratings=5.0, timestamp=964982290, user_id=1),
#  Row(movie_id=1580, ratings=3.0, timestamp=964981125, user_id=1),
#  Row(movie_id=1587, ratings=5.0, timestamp=964982346, user_id=1),
#  Row(movie_id=1617, ratings=5.0, timestamp=964982951, user_id=1),
#  Row(movie_id=1620, ratings=4.0, timestamp=964983056, user_id=1),
#  Row(movie_id=1625, ratings=5.0, timestamp=964983504, user_id=1),
#  Row(movie_id=1644, ratings=3.0, timestamp=964983536, user_id=1),
#  Row(movie_id=1676, ratings=3.0, timestamp=964982620, user_id=1),
#  Row(movie_id=1732, ratings=5.0, timestamp=964981125, user_id=1),
#  Row(movie_id=1777, ratings=4.0, timestamp=964981230, user_id=1),
#  Row(movie_id=1793, ratings=4.0, timestamp=964981404, user_id=1),
#  Row(movie_id=1804, ratings=5.0, timestamp=964983034, user_id=1),
#  Row(movie_id=1805, ratings=4.0, timestamp=964983056, user_id=1),
#  Row(movie_id=1920, ratings=4.0, timestamp=964981780, user_id=1),
#  Row(movie_id=1927, ratings=5.0, timestamp=964981497, user_id=1),
#  Row(movie_id=1954, ratings=5.0, timestamp=964982176, user_id=1),
#  Row(movie_id=1967, ratings=4.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2000, ratings=4.0, timestamp=964982211, user_id=1),
#  Row(movie_id=2005, ratings=5.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2012, ratings=4.0, timestamp=964984176, user_id=1),
#  Row(movie_id=2018, ratings=5.0, timestamp=964980523, user_id=1),
#  Row(movie_id=2028, ratings=4.0, timestamp=964981888, user_id=1),
#  Row(movie_id=2033, ratings=5.0, timestamp=964982903, user_id=1),
#  Row(movie_id=2046, ratings=4.0, timestamp=964982563, user_id=1),
#  Row(movie_id=2048, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=2054, ratings=4.0, timestamp=964981747, user_id=1),
#  Row(movie_id=2058, ratings=5.0, timestamp=964982400, user_id=1),
#  Row(movie_id=2078, ratings=5.0, timestamp=964982838, user_id=1),
#  Row(movie_id=2090, ratings=5.0, timestamp=964982838, user_id=1),
#  Row(movie_id=2093, ratings=3.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2094, ratings=5.0, timestamp=964982653, user_id=1),
#  Row(movie_id=2096, ratings=4.0, timestamp=964982838, user_id=1),
#  Row(movie_id=2099, ratings=4.0, timestamp=964982588, user_id=1),
#  Row(movie_id=2105, ratings=4.0, timestamp=964981725, user_id=1),
#  Row(movie_id=2115, ratings=5.0, timestamp=964982529, user_id=1),
#  Row(movie_id=2116, ratings=5.0, timestamp=964982876, user_id=1),
#  Row(movie_id=2137, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=2139, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=2141, ratings=5.0, timestamp=964982838, user_id=1),
#  Row(movie_id=2143, ratings=4.0, timestamp=964981725, user_id=1),
#  Row(movie_id=2161, ratings=5.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2174, ratings=4.0, timestamp=964981680, user_id=1),
#  Row(movie_id=2193, ratings=4.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2253, ratings=2.0, timestamp=964981775, user_id=1),
#  Row(movie_id=2268, ratings=4.0, timestamp=964982989, user_id=1),
#  Row(movie_id=2273, ratings=4.0, timestamp=964982310, user_id=1),
#  Row(movie_id=2291, ratings=5.0, timestamp=964983664, user_id=1),
#  Row(movie_id=2329, ratings=5.0, timestamp=964983263, user_id=1),
#  Row(movie_id=2338, ratings=2.0, timestamp=964983546, user_id=1),
#  Row(movie_id=2353, ratings=5.0, timestamp=964983861, user_id=1),
#  Row(movie_id=2366, ratings=4.0, timestamp=964982462, user_id=1),
#  Row(movie_id=2387, ratings=5.0, timestamp=964983123, user_id=1),
#  Row(movie_id=2389, ratings=2.0, timestamp=964983094, user_id=1),
#  Row(movie_id=2395, ratings=5.0, timestamp=964981093, user_id=1),
#  Row(movie_id=2406, ratings=4.0, timestamp=964982310, user_id=1),
#  Row(movie_id=2414, ratings=3.0, timestamp=964982513, user_id=1),
#  Row(movie_id=2427, ratings=5.0, timestamp=964982242, user_id=1),
#  Row(movie_id=2450, ratings=4.0, timestamp=964982620, user_id=1),
#  Row(movie_id=2459, ratings=5.0, timestamp=964983414, user_id=1),
#  Row(movie_id=2470, ratings=5.0, timestamp=964982588, user_id=1),
#  Row(movie_id=2478, ratings=4.0, timestamp=964984169, user_id=1),
#  Row(movie_id=2492, ratings=4.0, timestamp=965719662, user_id=1),
#  Row(movie_id=2502, ratings=5.0, timestamp=964981278, user_id=1),
#  Row(movie_id=2528, ratings=3.0, timestamp=964982328, user_id=1),
#  Row(movie_id=2529, ratings=5.0, timestamp=964982242, user_id=1),
#  Row(movie_id=2542, ratings=5.0, timestamp=964981265, user_id=1),
#  Row(movie_id=2571, ratings=5.0, timestamp=964981888, user_id=1),
#  Row(movie_id=2580, ratings=5.0, timestamp=964983000, user_id=1),
#  Row(movie_id=2596, ratings=5.0, timestamp=964981144, user_id=1),
#  Row(movie_id=2616, ratings=4.0, timestamp=964983080, user_id=1),
#  Row(movie_id=2617, ratings=2.0, timestamp=964982588, user_id=1),
#  Row(movie_id=2628, ratings=4.0, timestamp=964980523, user_id=1),
#  Row(movie_id=2640, ratings=4.0, timestamp=964982377, user_id=1),
#  Row(movie_id=2641, ratings=5.0, timestamp=964982620, user_id=1),
#  Row(movie_id=2644, ratings=4.0, timestamp=964983393, user_id=1),
#  Row(movie_id=2648, ratings=4.0, timestamp=964983414, user_id=1),
#  Row(movie_id=2654, ratings=5.0, timestamp=964983393, user_id=1),
#  Row(movie_id=2657, ratings=3.0, timestamp=964983426, user_id=1),
#  Row(movie_id=2692, ratings=5.0, timestamp=964981855, user_id=1),
#  Row(movie_id=2700, ratings=5.0, timestamp=964980985, user_id=1),
#  Row(movie_id=2716, ratings=5.0, timestamp=964983414, user_id=1),
#  Row(movie_id=2761, ratings=5.0, timestamp=964982703, user_id=1),
#  Row(movie_id=2797, ratings=4.0, timestamp=964981710, user_id=1),
#  Row(movie_id=2826, ratings=4.0, timestamp=964980523, user_id=1),
#  Row(movie_id=2858, ratings=5.0, timestamp=964980868, user_id=1),
#  Row(movie_id=2872, ratings=5.0, timestamp=964981680, user_id=1),
#  Row(movie_id=2899, ratings=5.0, timestamp=964982703, user_id=1),
#  Row(movie_id=2916, ratings=4.0, timestamp=964982290, user_id=1),
#  Row(movie_id=2944, ratings=5.0, timestamp=964981872, user_id=1),
#  Row(movie_id=2947, ratings=5.0, timestamp=964982176, user_id=1),
#  Row(movie_id=2948, ratings=5.0, timestamp=964982191, user_id=1),
#  Row(movie_id=2949, ratings=5.0, timestamp=964981888, user_id=1),
#  Row(movie_id=2959, ratings=5.0, timestamp=964983282, user_id=1),
#  Row(movie_id=2985, ratings=4.0, timestamp=964983034, user_id=1),
#  Row(movie_id=2987, ratings=5.0, timestamp=964982495, user_id=1),
#  Row(movie_id=2991, ratings=5.0, timestamp=964982271, user_id=1),
#  Row(movie_id=2993, ratings=5.0, timestamp=964982242, user_id=1),
#  Row(movie_id=2997, ratings=4.0, timestamp=964980896, user_id=1),
#  Row(movie_id=3033, ratings=5.0, timestamp=964983762, user_id=1),
#  Row(movie_id=3034, ratings=5.0, timestamp=964982791, user_id=1),
#  Row(movie_id=3052, ratings=5.0, timestamp=964981208, user_id=1),
#  Row(movie_id=3053, ratings=5.0, timestamp=964984086, user_id=1),
#  Row(movie_id=3062, ratings=4.0, timestamp=964981872, user_id=1),
#  Row(movie_id=3147, ratings=5.0, timestamp=964983873, user_id=1),
#  Row(movie_id=3168, ratings=4.0, timestamp=964982495, user_id=1),
#  Row(movie_id=3176, ratings=1.0, timestamp=964983504, user_id=1),
#  Row(movie_id=3243, ratings=3.0, timestamp=964981093, user_id=1),
#  Row(movie_id=3247, ratings=3.0, timestamp=964983108, user_id=1),
#  Row(movie_id=3253, ratings=5.0, timestamp=964981107, user_id=1),
#  Row(movie_id=3273, ratings=5.0, timestamp=964983536, user_id=1),
#  Row(movie_id=3386, ratings=5.0, timestamp=964983484, user_id=1),
#  Row(movie_id=3439, ratings=4.0, timestamp=964981799, user_id=1),
#  Row(movie_id=3440, ratings=4.0, timestamp=964981799, user_id=1),
#  Row(movie_id=3441, ratings=5.0, timestamp=964982328, user_id=1),
#  Row(movie_id=3448, ratings=5.0, timestamp=964984054, user_id=1),
#  Row(movie_id=3450, ratings=5.0, timestamp=964981144, user_id=1),
#  Row(movie_id=3479, ratings=4.0, timestamp=964981725, user_id=1),
#  Row(movie_id=3489, ratings=4.0, timestamp=964981775, user_id=1),
#  Row(movie_id=3527, ratings=4.0, timestamp=964982271, user_id=1),
#  Row(movie_id=3578, ratings=5.0, timestamp=964980668, user_id=1),
#  Row(movie_id=3617, ratings=4.0, timestamp=964980683, user_id=1),
#  Row(movie_id=3639, ratings=4.0, timestamp=964982271, user_id=1),
#  Row(movie_id=3671, ratings=5.0, timestamp=964981589, user_id=1),
#  Row(movie_id=3702, ratings=5.0, timestamp=964983737, user_id=1),
#  Row(movie_id=3703, ratings=5.0, timestamp=964981909, user_id=1),
#  Row(movie_id=3729, ratings=5.0, timestamp=964982363, user_id=1),
#  Row(movie_id=3740, ratings=4.0, timestamp=964982417, user_id=1),
#  Row(movie_id=3744, ratings=4.0, timestamp=964980694, user_id=1),
#  Row(movie_id=3793, ratings=5.0, timestamp=964981855, user_id=1),
#  Row(movie_id=3809, ratings=4.0, timestamp=964981220, user_id=1),
#  Row(movie_id=4006, ratings=4.0, timestamp=964982903, user_id=1),
#  Row(movie_id=5060, ratings=5.0, timestamp=964984002, user_id=1),
#  Row(movie_id=318, ratings=3.0, timestamp=1445714835, user_id=2),
#  Row(movie_id=333, ratings=4.0, timestamp=1445715029, user_id=2),
#  Row(movie_id=1704, ratings=4.5, timestamp=1445715228, user_id=2),
#  Row(movie_id=3578, ratings=4.0, timestamp=1445714885, user_id=2),
#  Row(movie_id=6874, ratings=4.0, timestamp=1445714952, user_id=2),
#  Row(movie_id=8798, ratings=3.5, timestamp=1445714960, user_id=2),
#  Row(movie_id=46970, ratings=4.0, timestamp=1445715013, user_id=2),
#  Row(movie_id=48516, ratings=4.0, timestamp=1445715064, user_id=2),
#  Row(movie_id=58559, ratings=4.5, timestamp=1445715141, user_id=2),
#  Row(movie_id=60756, ratings=5.0, timestamp=1445714980, user_id=2),
#  Row(movie_id=68157, ratings=4.5, timestamp=1445715154, user_id=2),
#  Row(movie_id=71535, ratings=3.0, timestamp=1445714974, user_id=2),
#  Row(movie_id=74458, ratings=4.0, timestamp=1445714926, user_id=2),
#  Row(movie_id=77455, ratings=3.0, timestamp=1445714941, user_id=2),
#  Row(movie_id=79132, ratings=4.0, timestamp=1445714841, user_id=2),
#  Row(movie_id=80489, ratings=4.5, timestamp=1445715340, user_id=2),
#  Row(movie_id=80906, ratings=5.0, timestamp=1445715172, user_id=2),
#  Row(movie_id=86345, ratings=4.0, timestamp=1445715166, user_id=2),
#  Row(movie_id=89774, ratings=5.0, timestamp=1445715189, user_id=2),
#  Row(movie_id=91529, ratings=3.5, timestamp=1445714891, user_id=2),
#  Row(movie_id=91658, ratings=2.5, timestamp=1445714938, user_id=2),
#  Row(movie_id=99114, ratings=3.5, timestamp=1445714874, user_id=2),
#  Row(movie_id=106782, ratings=5.0, timestamp=1445714966, user_id=2),
#  Row(movie_id=109487, ratings=3.0, timestamp=1445715145, user_id=2),
#  Row(movie_id=112552, ratings=4.0, timestamp=1445714882, user_id=2),
#  Row(movie_id=114060, ratings=2.0, timestamp=1445715276, user_id=2),
#  Row(movie_id=115713, ratings=3.5, timestamp=1445714854, user_id=2),
#  Row(movie_id=122882, ratings=5.0, timestamp=1445715272, user_id=2),
#  Row(movie_id=131724, ratings=5.0, timestamp=1445714851, user_id=2),
#  Row(movie_id=31, ratings=0.5, timestamp=1306463578, user_id=3),
#  Row(movie_id=527, ratings=0.5, timestamp=1306464275, user_id=3),
#  Row(movie_id=647, ratings=0.5, timestamp=1306463619, user_id=3),
#  Row(movie_id=688, ratings=0.5, timestamp=1306464228, user_id=3),
#  Row(movie_id=720, ratings=0.5, timestamp=1306463595, user_id=3),
#  Row(movie_id=849, ratings=5.0, timestamp=1306463611, user_id=3),
#  Row(movie_id=914, ratings=0.5, timestamp=1306463567, user_id=3),
#  Row(movie_id=1093, ratings=0.5, timestamp=1306463627, user_id=3),
#  Row(movie_id=1124, ratings=0.5, timestamp=1306464216, user_id=3),
#  Row(movie_id=1263, ratings=0.5, timestamp=1306463569, user_id=3),
#  Row(movie_id=1272, ratings=0.5, timestamp=1306463624, user_id=3),
#  Row(movie_id=1275, ratings=3.5, timestamp=1306463323, user_id=3),
#  Row(movie_id=1302, ratings=0.5, timestamp=1306464189, user_id=3),
#  Row(movie_id=1371, ratings=3.0, timestamp=1306463561, user_id=3),
#  Row(movie_id=1587, ratings=4.5, timestamp=1306464003, user_id=3),
#  Row(movie_id=2018, ratings=0.5, timestamp=1306464175, user_id=3),
#  Row(movie_id=2080, ratings=0.5, timestamp=1306463572, user_id=3),
#  Row(movie_id=2090, ratings=0.5, timestamp=1306464261, user_id=3),
#  Row(movie_id=2105, ratings=2.0, timestamp=1306463559, user_id=3),
#  Row(movie_id=2288, ratings=4.0, timestamp=1306463631, user_id=3),
#  Row(movie_id=2424, ratings=0.5, timestamp=1306464293, user_id=3),
#  Row(movie_id=2851, ratings=5.0, timestamp=1306463925, user_id=3),
#  Row(movie_id=3024, ratings=4.5, timestamp=1306464054, user_id=3),
#  Row(movie_id=3210, ratings=0.5, timestamp=1306463638, user_id=3),
#  Row(movie_id=3703, ratings=5.0, timestamp=1306463603, user_id=3),
#  Row(movie_id=3949, ratings=0.5, timestamp=1306464245, user_id=3),
#  Row(movie_id=4518, ratings=5.0, timestamp=1306463770, user_id=3),
#  Row(movie_id=5048, ratings=0.5, timestamp=1306464284, user_id=3),
#  Row(movie_id=5181, ratings=5.0, timestamp=1306463718, user_id=3),
#  Row(movie_id=5746, ratings=5.0, timestamp=1306463708, user_id=3),
#  Row(movie_id=5764, ratings=4.5, timestamp=1306464021, user_id=3),
#  Row(movie_id=5919, ratings=5.0, timestamp=1306463825, user_id=3),
#  Row(movie_id=6238, ratings=0.5, timestamp=1306464204, user_id=3),
#  Row(movie_id=6835, ratings=5.0, timestamp=1306463670, user_id=3),
#  Row(movie_id=7899, ratings=4.5, timestamp=1306464036, user_id=3),
#  Row(movie_id=7991, ratings=5.0, timestamp=1306463684, user_id=3),
#  Row(movie_id=26409, ratings=4.5, timestamp=1306463993, user_id=3),
#  Row(movie_id=70946, ratings=5.0, timestamp=1306463815, user_id=3),
#  Row(movie_id=72378, ratings=0.5, timestamp=1306464164, user_id=3),
#  Row(movie_id=21, ratings=3.0, timestamp=986935199, user_id=4),
#  Row(movie_id=32, ratings=2.0, timestamp=945173447, user_id=4),
#  Row(movie_id=45, ratings=3.0, timestamp=986935047, user_id=4),
#  Row(movie_id=47, ratings=2.0, timestamp=945173425, user_id=4),
#  Row(movie_id=52, ratings=3.0, timestamp=964622786, user_id=4),
#  Row(movie_id=58, ratings=3.0, timestamp=964538444, user_id=4),
#  Row(movie_id=106, ratings=4.0, timestamp=986848784, user_id=4),
#  Row(movie_id=125, ratings=5.0, timestamp=964622758, user_id=4),
#  Row(movie_id=126, ratings=1.0, timestamp=986848920, user_id=4),
#  Row(movie_id=162, ratings=5.0, timestamp=945078571, user_id=4),
#  Row(movie_id=171, ratings=3.0, timestamp=945078428, user_id=4),
#  Row(movie_id=176, ratings=5.0, timestamp=964622565, user_id=4),
#  Row(movie_id=190, ratings=2.0, timestamp=945079259, user_id=4),
#  Row(movie_id=215, ratings=5.0, timestamp=945079078, user_id=4),
#  Row(movie_id=222, ratings=1.0, timestamp=945629040, user_id=4),
#  Row(movie_id=232, ratings=5.0, timestamp=964622684, user_id=4),
#  Row(movie_id=235, ratings=2.0, timestamp=945173513, user_id=4),
#  Row(movie_id=247, ratings=3.0, timestamp=986848894, user_id=4),
#  Row(movie_id=260, ratings=5.0, timestamp=945079259, user_id=4),
#  Row(movie_id=265, ratings=5.0, timestamp=964538468, user_id=4),
#  Row(movie_id=296, ratings=1.0, timestamp=945173350, user_id=4),
#  Row(movie_id=319, ratings=5.0, timestamp=945079182, user_id=4),
#  Row(movie_id=342, ratings=5.0, timestamp=964538500, user_id=4),
#  Row(movie_id=345, ratings=4.0, timestamp=945629063, user_id=4),
#  Row(movie_id=348, ratings=4.0, timestamp=964622786, user_id=4),
#  Row(movie_id=351, ratings=3.0, timestamp=986934901, user_id=4),
#  Row(movie_id=357, ratings=3.0, timestamp=964623306, user_id=4),
#  Row(movie_id=368, ratings=4.0, timestamp=945078690, user_id=4),
#  Row(movie_id=417, ratings=2.0, timestamp=945078467, user_id=4),
#  Row(movie_id=441, ratings=1.0, timestamp=986934915, user_id=4),
#  Row(movie_id=450, ratings=2.0, timestamp=986848828, user_id=4),
#  Row(movie_id=457, ratings=5.0, timestamp=945079259, user_id=4),
#  Row(movie_id=475, ratings=5.0, timestamp=945174290, user_id=4),
#  Row(movie_id=492, ratings=5.0, timestamp=945079872, user_id=4),
#  Row(movie_id=509, ratings=1.0, timestamp=945079106, user_id=4),
#  Row(movie_id=538, ratings=5.0, timestamp=945078636, user_id=4),
#  Row(movie_id=539, ratings=1.0, timestamp=964538832, user_id=4),
#  Row(movie_id=553, ratings=2.0, timestamp=945079301, user_id=4),
#  Row(movie_id=588, ratings=4.0, timestamp=945079670, user_id=4),
#  Row(movie_id=593, ratings=5.0, timestamp=964539986, user_id=4),
#  Row(movie_id=595, ratings=3.0, timestamp=986848609, user_id=4),
#  Row(movie_id=599, ratings=2.0, timestamp=945078587, user_id=4),
#  Row(movie_id=608, ratings=5.0, timestamp=964540008, user_id=4),
#  Row(movie_id=648, ratings=3.0, timestamp=945079906, user_id=4),
#  Row(movie_id=708, ratings=4.0, timestamp=986935230, user_id=4),
#  Row(movie_id=759, ratings=3.0, timestamp=945078601, user_id=4),
#  Row(movie_id=800, ratings=4.0, timestamp=945079106, user_id=4),
#  Row(movie_id=892, ratings=4.0, timestamp=964622714, user_id=4),
#  Row(movie_id=898, ratings=5.0, timestamp=964623347, user_id=4),
#  Row(movie_id=899, ratings=4.0, timestamp=945079653, user_id=4),
#  Row(movie_id=902, ratings=4.0, timestamp=945078446, user_id=4),
#  Row(movie_id=904, ratings=4.0, timestamp=945079837, user_id=4),
#  Row(movie_id=908, ratings=5.0, timestamp=945173902, user_id=4),
#  Row(movie_id=910, ratings=5.0, timestamp=945173989, user_id=4),
#  Row(movie_id=912, ratings=5.0, timestamp=945173902, user_id=4),
#  Row(movie_id=914, ratings=5.0, timestamp=945079670, user_id=4),
#  Row(movie_id=919, ratings=5.0, timestamp=945079521, user_id=4),
#  Row(movie_id=920, ratings=5.0, timestamp=945173602, user_id=4),
#  Row(movie_id=930, ratings=5.0, timestamp=964538571, user_id=4),
#  Row(movie_id=937, ratings=3.0, timestamp=986849085, user_id=4),
#  Row(movie_id=1025, ratings=4.0, timestamp=945079232, user_id=4),
#  Row(movie_id=1046, ratings=5.0, timestamp=945173654, user_id=4),
#  Row(movie_id=1057, ratings=3.0, timestamp=964540578, user_id=4),
#  Row(movie_id=1060, ratings=2.0, timestamp=986934819, user_id=4),
#  Row(movie_id=1073, ratings=4.0, timestamp=945079483, user_id=4),
#  Row(movie_id=1077, ratings=5.0, timestamp=945173692, user_id=4),
#  Row(movie_id=1079, ratings=2.0, timestamp=945078946, user_id=4),
#  Row(movie_id=1080, ratings=5.0, timestamp=986934696, user_id=4),
#  Row(movie_id=1084, ratings=5.0, timestamp=945079259, user_id=4),
#  Row(movie_id=1086, ratings=5.0, timestamp=964539723, user_id=4),
#  Row(movie_id=1094, ratings=3.0, timestamp=964538500, user_id=4),
#  Row(movie_id=1103, ratings=5.0, timestamp=964539723, user_id=4),
#  Row(movie_id=1136, ratings=5.0, timestamp=986934625, user_id=4),
#  Row(movie_id=1179, ratings=4.0, timestamp=964539180, user_id=4),
#  Row(movie_id=1183, ratings=1.0, timestamp=964778513, user_id=4),
#  Row(movie_id=1188, ratings=5.0, timestamp=964538500, user_id=4),
#  Row(movie_id=1196, ratings=5.0, timestamp=964538763, user_id=4),
#  Row(movie_id=1197, ratings=5.0, timestamp=964538763, user_id=4),
#  Row(movie_id=1198, ratings=3.0, timestamp=964538728, user_id=4),
#  Row(movie_id=1199, ratings=2.0, timestamp=945078967, user_id=4),
#  Row(movie_id=1203, ratings=5.0, timestamp=945174025, user_id=4),
#  Row(movie_id=1211, ratings=1.0, timestamp=964539205, user_id=4),
#  Row(movie_id=1213, ratings=4.0, timestamp=945079729, user_id=4),
#  Row(movie_id=1219, ratings=4.0, timestamp=964539961, user_id=4),
#  Row(movie_id=1225, ratings=4.0, timestamp=964539326, user_id=4),
#  Row(movie_id=1250, ratings=5.0, timestamp=945174008, user_id=4),
#  Row(movie_id=1259, ratings=4.0, timestamp=964538728, user_id=4),
#  Row(movie_id=1265, ratings=4.0, timestamp=964622684, user_id=4),
#  Row(movie_id=1266, ratings=4.0, timestamp=986849037, user_id=4),
#  Row(movie_id=1279, ratings=2.0, timestamp=986934832, user_id=4),
#  Row(movie_id=1282, ratings=5.0, timestamp=945079653, user_id=4),
#  Row(movie_id=1283, ratings=5.0, timestamp=945078690, user_id=4),
#  Row(movie_id=1288, ratings=4.0, timestamp=945079653, user_id=4),
#  Row(movie_id=1291, ratings=4.0, timestamp=964538763, user_id=4),
#  Row(movie_id=1304, ratings=3.0, timestamp=945078467, user_id=4),
#  Row(movie_id=1391, ratings=1.0, timestamp=945173766, user_id=4),
#  Row(movie_id=1449, ratings=5.0, timestamp=945079767, user_id=4),
#  Row(movie_id=1466, ratings=4.0, timestamp=945173492, user_id=4),
#  Row(movie_id=1500, ratings=4.0, timestamp=964622830, user_id=4),
#  Row(movie_id=1517, ratings=4.0, timestamp=945079790, user_id=4),
#  Row(movie_id=1580, ratings=3.0, timestamp=986935244, user_id=4),
#  Row(movie_id=1597, ratings=1.0, timestamp=945079906, user_id=4),
#  Row(movie_id=1617, ratings=2.0, timestamp=945079837, user_id=4),
#  Row(movie_id=1641, ratings=4.0, timestamp=964622758, user_id=4),
#  Row(movie_id=1704, ratings=1.0, timestamp=945629015, user_id=4),
#  Row(movie_id=1719, ratings=4.0, timestamp=945079956, user_id=4),
#  Row(movie_id=1732, ratings=4.0, timestamp=945079889, user_id=4),
#  Row(movie_id=1733, ratings=5.0, timestamp=945079143, user_id=4),
#  Row(movie_id=1734, ratings=3.0, timestamp=964539357, user_id=4),
#  Row(movie_id=1834, ratings=5.0, timestamp=945174134, user_id=4),
#  Row(movie_id=1860, ratings=2.0, timestamp=986849001, user_id=4),
#  Row(movie_id=1883, ratings=4.0, timestamp=964622642, user_id=4),
#  Row(movie_id=1885, ratings=3.0, timestamp=964622617, user_id=4),
#  Row(movie_id=1892, ratings=2.0, timestamp=964539431, user_id=4),
#  Row(movie_id=1895, ratings=4.0, timestamp=945629179, user_id=4),
#  Row(movie_id=1907, ratings=3.0, timestamp=964540505, user_id=4),
#  Row(movie_id=1914, ratings=4.0, timestamp=964622714, user_id=4),
#  Row(movie_id=1916, ratings=1.0, timestamp=986934786, user_id=4),
#  Row(movie_id=1923, ratings=3.0, timestamp=986934870, user_id=4),
#  Row(movie_id=1947, ratings=5.0, timestamp=945079653, user_id=4),
#  Row(movie_id=1966, ratings=2.0, timestamp=964622684, user_id=4),
#  Row(movie_id=1967, ratings=5.0, timestamp=945078967, user_id=4),
#  Row(movie_id=1968, ratings=4.0, timestamp=986934786, user_id=4),
#  Row(movie_id=2019, ratings=2.0, timestamp=945078690, user_id=4),
#  Row(movie_id=2076, ratings=4.0, timestamp=945079052, user_id=4),
#  Row(movie_id=2078, ratings=5.0, timestamp=945079521, user_id=4),
#  Row(movie_id=2109, ratings=4.0, timestamp=986935016, user_id=4),
#  Row(movie_id=2145, ratings=3.0, timestamp=986935328, user_id=4),
#  Row(movie_id=2150, ratings=5.0, timestamp=986934738, user_id=4),
#  Row(movie_id=2174, ratings=5.0, timestamp=964539855, user_id=4),
#  Row(movie_id=2186, ratings=5.0, timestamp=945174008, user_id=4),
#  Row(movie_id=2203, ratings=4.0, timestamp=945079729, user_id=4),
#  Row(movie_id=2204, ratings=5.0, timestamp=964540008, user_id=4),
#  Row(movie_id=2282, ratings=1.0, timestamp=945629238, user_id=4),
#  Row(movie_id=2324, ratings=1.0, timestamp=964622590, user_id=4),
#  Row(movie_id=2336, ratings=2.0, timestamp=964538964, user_id=4),
#  Row(movie_id=2351, ratings=4.0, timestamp=945078467, user_id=4),
#  Row(movie_id=2359, ratings=4.0, timestamp=964622590, user_id=4),
#  Row(movie_id=2390, ratings=5.0, timestamp=945079164, user_id=4),
#  Row(movie_id=2395, ratings=3.0, timestamp=964623306, user_id=4),
#  Row(movie_id=2406, ratings=4.0, timestamp=986935302, user_id=4),
#  Row(movie_id=2467, ratings=4.0, timestamp=945079858, user_id=4),
#  Row(movie_id=2571, ratings=1.0, timestamp=945173385, user_id=4),
#  Row(movie_id=2583, ratings=5.0, timestamp=945078863, user_id=4),
#  Row(movie_id=2599, ratings=5.0, timestamp=964622684, user_id=4),
#  Row(movie_id=2628, ratings=1.0, timestamp=986848894, user_id=4),
#  Row(movie_id=2683, ratings=4.0, timestamp=945079790, user_id=4),
#  Row(movie_id=2692, ratings=5.0, timestamp=945079013, user_id=4),
#  Row(movie_id=2712, ratings=2.0, timestamp=945078542, user_id=4),
#  Row(movie_id=2762, ratings=4.0, timestamp=964539986, user_id=4),
#  Row(movie_id=2763, ratings=1.0, timestamp=964778621, user_id=4),
#  Row(movie_id=2770, ratings=2.0, timestamp=945173553, user_id=4),
#  Row(movie_id=2791, ratings=5.0, timestamp=964539628, user_id=4),
#  Row(movie_id=2843, ratings=5.0, timestamp=945078814, user_id=4),
#  Row(movie_id=2858, ratings=5.0, timestamp=964539140, user_id=4),
#  Row(movie_id=2874, ratings=4.0, timestamp=986935016, user_id=4),
#  Row(movie_id=2921, ratings=4.0, timestamp=945078708, user_id=4),
#  Row(movie_id=2926, ratings=5.0, timestamp=986934870, user_id=4),
#  Row(movie_id=2959, ratings=2.0, timestamp=945078528, user_id=4),
#  Row(movie_id=2973, ratings=2.0, timestamp=945078946, user_id=4),
#  Row(movie_id=2997, ratings=4.0, timestamp=986848610, user_id=4),
#  Row(movie_id=3033, ratings=4.0, timestamp=986936200, user_id=4),
#  Row(movie_id=3044, ratings=5.0, timestamp=945079920, user_id=4),
#  Row(movie_id=3060, ratings=4.0, timestamp=986934884, user_id=4),
#  Row(movie_id=3079, ratings=3.0, timestamp=964778197, user_id=4),
#  Row(movie_id=3083, ratings=5.0, timestamp=964622487, user_id=4),
#  Row(movie_id=3160, ratings=4.0, timestamp=964539121, user_id=4),
#  Row(movie_id=3175, ratings=1.0, timestamp=964538930, user_id=4),
#  Row(movie_id=3176, ratings=4.0, timestamp=964539771, user_id=4),
#  Row(movie_id=3204, ratings=4.0, timestamp=964539828, user_id=4),
#  Row(movie_id=3255, ratings=4.0, timestamp=964623306, user_id=4),
#  Row(movie_id=3317, ratings=4.0, timestamp=986934498, user_id=4),
#  Row(movie_id=3358, ratings=3.0, timestamp=964622758, user_id=4),
#  Row(movie_id=3365, ratings=5.0, timestamp=964538329, user_id=4),
#  Row(movie_id=3386, ratings=4.0, timestamp=964539395, user_id=4),
#  Row(movie_id=3408, ratings=4.0, timestamp=986849238, user_id=4),
#  Row(movie_id=3481, ratings=2.0, timestamp=964538243, user_id=4),
#  Row(movie_id=3489, ratings=1.0, timestamp=986848908, user_id=4),
#  Row(movie_id=3508, ratings=5.0, timestamp=964538351, user_id=4),
#  Row(movie_id=3538, ratings=2.0, timestamp=986849212, user_id=4),
#  Row(movie_id=3591, ratings=1.0, timestamp=986935199, user_id=4),
#  Row(movie_id=3788, ratings=3.0, timestamp=964539085, user_id=4),
#  Row(movie_id=3809, ratings=3.0, timestamp=986936207, user_id=4),
#  Row(movie_id=3851, ratings=5.0, timestamp=986849180, user_id=4),
#  Row(movie_id=3897, ratings=4.0, timestamp=986934465, user_id=4),
#  Row(movie_id=3911, ratings=3.0, timestamp=986849149, user_id=4),
#  Row(movie_id=3967, ratings=4.0, timestamp=986849164, user_id=4),
#  Row(movie_id=3996, ratings=4.0, timestamp=986849130, user_id=4),
#  Row(movie_id=4002, ratings=3.0, timestamp=986934819, user_id=4),
#  Row(movie_id=4014, ratings=1.0, timestamp=986849254, user_id=4),
#  Row(movie_id=4020, ratings=3.0, timestamp=986848856, user_id=4),
#  Row(movie_id=4021, ratings=4.0, timestamp=986849180, user_id=4),
#  Row(movie_id=4027, ratings=3.0, timestamp=986849201, user_id=4),
#  Row(movie_id=4029, ratings=3.0, timestamp=986849226, user_id=4),
#  Row(movie_id=4033, ratings=4.0, timestamp=986849149, user_id=4),
#  Row(movie_id=4034, ratings=5.0, timestamp=986848753, user_id=4),
#  Row(movie_id=4074, ratings=3.0, timestamp=986848665, user_id=4),
#  Row(movie_id=4121, ratings=4.0, timestamp=986934901, user_id=4),
#  Row(movie_id=4144, ratings=3.0, timestamp=986848685, user_id=4),
#  Row(movie_id=4166, ratings=3.0, timestamp=986848700, user_id=4),
#  Row(movie_id=4226, ratings=2.0, timestamp=1007569424, user_id=4),
#  Row(movie_id=4239, ratings=5.0, timestamp=986848685, user_id=4),
#  Row(movie_id=4246, ratings=4.0, timestamp=1007574542, user_id=4),
#  Row(movie_id=4252, ratings=3.0, timestamp=1007569465, user_id=4),
#  Row(movie_id=4260, ratings=2.0, timestamp=1007569424, user_id=4),
#  Row(movie_id=4273, ratings=4.0, timestamp=1007574470, user_id=4),
#  Row(movie_id=4308, ratings=1.0, timestamp=1007569465, user_id=4),
#  Row(movie_id=4347, ratings=4.0, timestamp=1007569586, user_id=4),
#  Row(movie_id=4381, ratings=3.0, timestamp=1007574509, user_id=4),
#  Row(movie_id=4641, ratings=1.0, timestamp=1007569586, user_id=4),
#  Row(movie_id=4741, ratings=3.0, timestamp=1007574532, user_id=4),
#  Row(movie_id=4765, ratings=5.0, timestamp=1007569445, user_id=4),
#  Row(movie_id=4881, ratings=3.0, timestamp=1007569445, user_id=4),
#  Row(movie_id=4896, ratings=4.0, timestamp=1007574532, user_id=4),
#  Row(movie_id=4902, ratings=4.0, timestamp=1007569465, user_id=4),
#  Row(movie_id=4967, ratings=5.0, timestamp=1007569424, user_id=4),
#  Row(movie_id=1, ratings=4.0, timestamp=847434962, user_id=5),
#  Row(movie_id=21, ratings=4.0, timestamp=847435238, user_id=5),
#  Row(movie_id=34, ratings=4.0, timestamp=847434881, user_id=5),
#  Row(movie_id=36, ratings=4.0, timestamp=847435292, user_id=5),
#  Row(movie_id=39, ratings=3.0, timestamp=847434961, user_id=5),
#  Row(movie_id=50, ratings=4.0, timestamp=847434881, user_id=5),
#  Row(movie_id=58, ratings=5.0, timestamp=847435238, user_id=5),
#  Row(movie_id=110, ratings=4.0, timestamp=847434880, user_id=5),
#  Row(movie_id=150, ratings=3.0, timestamp=847434748, user_id=5),
#  Row(movie_id=153, ratings=3.0, timestamp=847434802, user_id=5),
#  Row(movie_id=232, ratings=4.0, timestamp=847435292, user_id=5),
#  Row(movie_id=247, ratings=5.0, timestamp=847435337, user_id=5),
#  Row(movie_id=253, ratings=3.0, timestamp=847435292, user_id=5),
#  Row(movie_id=261, ratings=4.0, timestamp=847435238, user_id=5),
#  Row(movie_id=265, ratings=3.0, timestamp=847435129, user_id=5),
#  Row(movie_id=266, ratings=1.0, timestamp=847435311, user_id=5),
#  Row(movie_id=290, ratings=5.0, timestamp=847435311, user_id=5),
#  Row(movie_id=296, ratings=5.0, timestamp=847434748, user_id=5),
#  Row(movie_id=300, ratings=3.0, timestamp=847435337, user_id=5),
#  Row(movie_id=316, ratings=2.0, timestamp=847434832, user_id=5),
#  Row(movie_id=318, ratings=3.0, timestamp=847434880, user_id=5),
#  Row(movie_id=344, ratings=3.0, timestamp=847434802, user_id=5),
#  Row(movie_id=349, ratings=3.0, timestamp=847434832, user_id=5),
#  Row(movie_id=357, ratings=2.0, timestamp=847435238, user_id=5),
#  Row(movie_id=364, ratings=3.0, timestamp=847434882, user_id=5),
#  Row(movie_id=367, ratings=4.0, timestamp=847435129, user_id=5),
#  Row(movie_id=380, ratings=2.0, timestamp=847434748, user_id=5),
#  Row(movie_id=410, ratings=3.0, timestamp=847435292, user_id=5),
#  Row(movie_id=457, ratings=4.0, timestamp=847434801, user_id=5),
#  Row(movie_id=474, ratings=4.0, timestamp=847435337, user_id=5),
#  Row(movie_id=475, ratings=5.0, timestamp=847435311, user_id=5),
#  Row(movie_id=515, ratings=3.0, timestamp=847435129, user_id=5),
#  Row(movie_id=527, ratings=5.0, timestamp=847434960, user_id=5),
#  Row(movie_id=531, ratings=4.0, timestamp=847435258, user_id=5),
#  Row(movie_id=534, ratings=3.0, timestamp=847435311, user_id=5),
#  Row(movie_id=588, ratings=4.0, timestamp=847434801, user_id=5),
#  Row(movie_id=589, ratings=3.0, timestamp=847435258, user_id=5),
#  Row(movie_id=590, ratings=5.0, timestamp=847434747, user_id=5),
#  Row(movie_id=592, ratings=3.0, timestamp=847434747, user_id=5),
#  Row(movie_id=594, ratings=5.0, timestamp=847435238, user_id=5),
#  Row(movie_id=595, ratings=5.0, timestamp=847434832, user_id=5),
#  Row(movie_id=596, ratings=5.0, timestamp=847435292, user_id=5),
#  Row(movie_id=597, ratings=3.0, timestamp=847434962, user_id=5),
#  Row(movie_id=608, ratings=3.0, timestamp=847435258, user_id=5),
#  Row(movie_id=2, ratings=4.0, timestamp=845553522, user_id=6),
#  Row(movie_id=3, ratings=5.0, timestamp=845554296, user_id=6),
#  Row(movie_id=4, ratings=3.0, timestamp=845554349, user_id=6),
#  Row(movie_id=5, ratings=5.0, timestamp=845553938, user_id=6),
#  Row(movie_id=6, ratings=4.0, timestamp=845553757, user_id=6),
#  Row(movie_id=7, ratings=4.0, timestamp=845554264, user_id=6),
#  Row(movie_id=8, ratings=3.0, timestamp=845555281, user_id=6),
#  Row(movie_id=10, ratings=3.0, timestamp=845553253, user_id=6),
#  Row(movie_id=11, ratings=4.0, timestamp=845553489, user_id=6),
#  Row(movie_id=13, ratings=3.0, timestamp=845555588, user_id=6),
#  Row(movie_id=15, ratings=4.0, timestamp=845554505, user_id=6),
#  Row(movie_id=16, ratings=4.0, timestamp=845553819, user_id=6),
#  Row(movie_id=17, ratings=4.0, timestamp=845553559, user_id=6),
#  Row(movie_id=19, ratings=2.0, timestamp=845553382, user_id=6),
#  Row(movie_id=21, ratings=2.0, timestamp=845553382, user_id=6),
#  Row(movie_id=22, ratings=5.0, timestamp=845553875, user_id=6),
#  Row(movie_id=24, ratings=4.0, timestamp=845554397, user_id=6),
#  Row(movie_id=25, ratings=3.0, timestamp=845553695, user_id=6),
#  Row(movie_id=26, ratings=4.0, timestamp=845555362, user_id=6),
#  Row(movie_id=27, ratings=3.0, timestamp=845555402, user_id=6),
#  Row(movie_id=31, ratings=3.0, timestamp=845553819, user_id=6),
#  Row(movie_id=32, ratings=4.0, timestamp=845553426, user_id=6),
#  Row(movie_id=34, ratings=4.0, timestamp=845553354, user_id=6),
#  Row(movie_id=36, ratings=5.0, timestamp=845553726, user_id=6),
#  Row(movie_id=41, ratings=4.0, timestamp=845554962, user_id=6),
#  Row(movie_id=43, ratings=4.0, timestamp=845555607, user_id=6),
#  Row(movie_id=45, ratings=3.0, timestamp=845553907, user_id=6),
#  Row(movie_id=46, ratings=4.0, timestamp=845554551, user_id=6),
#  Row(movie_id=47, ratings=4.0, timestamp=845553317, user_id=6),
#  Row(movie_id=50, ratings=1.0, timestamp=845553381, user_id=6),
#  Row(movie_id=54, ratings=4.0, timestamp=845555402, user_id=6),
#  Row(movie_id=60, ratings=4.0, timestamp=845554263, user_id=6),
#  Row(movie_id=61, ratings=4.0, timestamp=845555454, user_id=6),
#  Row(movie_id=62, ratings=4.0, timestamp=845553660, user_id=6),
#  Row(movie_id=65, ratings=3.0, timestamp=845555070, user_id=6),
#  Row(movie_id=66, ratings=3.0, timestamp=845555151, user_id=6),
#  Row(movie_id=76, ratings=4.0, timestamp=845555317, user_id=6),
#  Row(movie_id=79, ratings=3.0, timestamp=845554907, user_id=6),
#  Row(movie_id=86, ratings=5.0, timestamp=845556131, user_id=6),
#  Row(movie_id=87, ratings=3.0, timestamp=845555300, user_id=6),
#  Row(movie_id=88, ratings=2.0, timestamp=845555694, user_id=6),
#  Row(movie_id=89, ratings=4.0, timestamp=845555124, user_id=6),
#  Row(movie_id=92, ratings=4.0, timestamp=845555454, user_id=6),
#  Row(movie_id=93, ratings=4.0, timestamp=845554584, user_id=6),
#  Row(movie_id=95, ratings=4.0, timestamp=845553559, user_id=6),
#  Row(movie_id=100, ratings=3.0, timestamp=845555151, user_id=6),
#  Row(movie_id=102, ratings=1.0, timestamp=845555436, user_id=6),
#  Row(movie_id=104, ratings=4.0, timestamp=845554349, user_id=6),
#  Row(movie_id=105, ratings=3.0, timestamp=845553757, user_id=6),
#  Row(movie_id=110, ratings=5.0, timestamp=845553283, user_id=6),
#  Row(movie_id=112, ratings=4.0, timestamp=845553994, user_id=6),
#  Row(movie_id=113, ratings=3.0, timestamp=845556257, user_id=6),
#  Row(movie_id=126, ratings=3.0, timestamp=845555342, user_id=6),
#  Row(movie_id=135, ratings=3.0, timestamp=845554987, user_id=6),
#  Row(movie_id=140, ratings=3.0, timestamp=845555024, user_id=6),
#  Row(movie_id=141, ratings=4.0, timestamp=845553586, user_id=6),
#  Row(movie_id=145, ratings=4.0, timestamp=845553966, user_id=6),
#  Row(movie_id=146, ratings=4.0, timestamp=845555607, user_id=6),
#  Row(movie_id=150, ratings=4.0, timestamp=845553110, user_id=6),
#  Row(movie_id=151, ratings=4.0, timestamp=845553586, user_id=6),
#  Row(movie_id=153, ratings=3.0, timestamp=845553146, user_id=6),
#  Row(movie_id=158, ratings=4.0, timestamp=845553660, user_id=6),
#  Row(movie_id=159, ratings=3.0, timestamp=845555006, user_id=6),
#  Row(movie_id=160, ratings=5.0, timestamp=845553457, user_id=6),
#  Row(movie_id=161, ratings=3.0, timestamp=845553253, user_id=6),
#  Row(movie_id=163, ratings=3.0, timestamp=845553907, user_id=6),
#  Row(movie_id=165, ratings=3.0, timestamp=845553146, user_id=6),
#  Row(movie_id=168, ratings=5.0, timestamp=845553695, user_id=6),
#  Row(movie_id=170, ratings=3.0, timestamp=845554263, user_id=6),
#  Row(movie_id=171, ratings=3.0, timestamp=845555402, user_id=6),
#  Row(movie_id=174, ratings=3.0, timestamp=845554479, user_id=6),
#  Row(movie_id=177, ratings=3.0, timestamp=845554931, user_id=6),
#  Row(movie_id=179, ratings=1.0, timestamp=845555362, user_id=6),
#  Row(movie_id=180, ratings=2.0, timestamp=845555006, user_id=6),
#  Row(movie_id=181, ratings=3.0, timestamp=845553938, user_id=6),
#  Row(movie_id=185, ratings=3.0, timestamp=845553283, user_id=6),
#  Row(movie_id=186, ratings=3.0, timestamp=845553619, user_id=6),
#  Row(movie_id=189, ratings=3.0, timestamp=845556241, user_id=6),
#  Row(movie_id=191, ratings=2.0, timestamp=845554931, user_id=6),
#  Row(movie_id=195, ratings=4.0, timestamp=845554455, user_id=6),
#  Row(movie_id=196, ratings=3.0, timestamp=845553586, user_id=6),
#  Row(movie_id=201, ratings=3.0, timestamp=845556290, user_id=6),
#  Row(movie_id=204, ratings=3.0, timestamp=845553619, user_id=6),
#  Row(movie_id=205, ratings=3.0, timestamp=845555477, user_id=6),
#  Row(movie_id=207, ratings=4.0, timestamp=845554024, user_id=6),
#  Row(movie_id=208, ratings=3.0, timestamp=845553253, user_id=6),
#  Row(movie_id=209, ratings=3.0, timestamp=845556106, user_id=6),
#  Row(movie_id=210, ratings=4.0, timestamp=845556310, user_id=6),
#  Row(movie_id=212, ratings=4.0, timestamp=845556181, user_id=6),
#  Row(movie_id=216, ratings=4.0, timestamp=845554099, user_id=6),
#  Row(movie_id=217, ratings=3.0, timestamp=845555382, user_id=6),
#  Row(movie_id=218, ratings=2.0, timestamp=845553994, user_id=6),
#  Row(movie_id=219, ratings=3.0, timestamp=845556131, user_id=6),
#  Row(movie_id=222, ratings=4.0, timestamp=845554024, user_id=6),
#  Row(movie_id=224, ratings=3.0, timestamp=845553794, user_id=6),
#  Row(movie_id=225, ratings=4.0, timestamp=845553381, user_id=6),
#  Row(movie_id=230, ratings=5.0, timestamp=845553966, user_id=6),
#  Row(movie_id=231, ratings=3.0, timestamp=845553174, user_id=6),
#  Row(movie_id=234, ratings=2.0, timestamp=845554176, user_id=6),
#  Row(movie_id=236, ratings=4.0, timestamp=845553559, user_id=6),
#  Row(movie_id=237, ratings=4.0, timestamp=845553875, user_id=6),
#  Row(movie_id=239, ratings=3.0, timestamp=845554987, user_id=6),
#  Row(movie_id=240, ratings=3.0, timestamp=845555571, user_id=6),
#  Row(movie_id=243, ratings=3.0, timestamp=845555588, user_id=6),
#  Row(movie_id=248, ratings=5.0, timestamp=845554263, user_id=6),
#  Row(movie_id=250, ratings=4.0, timestamp=845555588, user_id=6),
#  Row(movie_id=251, ratings=3.0, timestamp=845556257, user_id=6),
#  Row(movie_id=252, ratings=4.0, timestamp=845553619, user_id=6),
#  Row(movie_id=253, ratings=3.0, timestamp=845553283, user_id=6),
#  Row(movie_id=254, ratings=3.0, timestamp=845555655, user_id=6),
#  Row(movie_id=256, ratings=3.0, timestamp=845553726, user_id=6),
#  Row(movie_id=257, ratings=5.0, timestamp=845554176, user_id=6),
#  Row(movie_id=258, ratings=3.0, timestamp=845555172, user_id=6),
#  Row(movie_id=261, ratings=4.0, timestamp=845553695, user_id=6),
#  Row(movie_id=262, ratings=5.0, timestamp=845554551, user_id=6),
#  Row(movie_id=265, ratings=3.0, timestamp=845553726, user_id=6),
#  Row(movie_id=266, ratings=3.0, timestamp=845553457, user_id=6),
#  Row(movie_id=267, ratings=3.0, timestamp=845554376, user_id=6),
#  Row(movie_id=270, ratings=3.0, timestamp=845555172, user_id=6),
#  Row(movie_id=271, ratings=4.0, timestamp=845555249, user_id=6),
#  Row(movie_id=273, ratings=3.0, timestamp=845553875, user_id=6),
#  Row(movie_id=274, ratings=4.0, timestamp=845555151, user_id=6),
#  Row(movie_id=276, ratings=4.0, timestamp=845553907, user_id=6),
#  Row(movie_id=277, ratings=5.0, timestamp=845553844, user_id=6),
#  Row(movie_id=279, ratings=3.0, timestamp=845555436, user_id=6),
#  Row(movie_id=281, ratings=4.0, timestamp=845554320, user_id=6),
#  Row(movie_id=282, ratings=3.0, timestamp=845553522, user_id=6),
#  Row(movie_id=288, ratings=2.0, timestamp=845553283, user_id=6),
#  Row(movie_id=289, ratings=3.0, timestamp=845554455, user_id=6),
#  Row(movie_id=291, ratings=3.0, timestamp=845555571, user_id=6),
#  Row(movie_id=292, ratings=4.0, timestamp=845553253, user_id=6),
#  Row(movie_id=293, ratings=3.0, timestamp=845553660, user_id=6),
#  Row(movie_id=296, ratings=2.0, timestamp=845553110, user_id=6),
#  Row(movie_id=302, ratings=3.0, timestamp=845555436, user_id=6),
#  Row(movie_id=303, ratings=3.0, timestamp=845554099, user_id=6),
#  Row(movie_id=304, ratings=4.0, timestamp=845555546, user_id=6),
#  Row(movie_id=310, ratings=3.0, timestamp=845556119, user_id=6),
#  Row(movie_id=312, ratings=1.0, timestamp=845555151, user_id=6),
#  Row(movie_id=313, ratings=3.0, timestamp=845555546, user_id=6),
#  Row(movie_id=314, ratings=5.0, timestamp=845554603, user_id=6),
#  Row(movie_id=315, ratings=4.0, timestamp=845553522, user_id=6),
#  Row(movie_id=316, ratings=5.0, timestamp=845553174, user_id=6),
#  Row(movie_id=317, ratings=4.0, timestamp=845553457, user_id=6),
#  Row(movie_id=318, ratings=5.0, timestamp=845553200, user_id=6),
#  Row(movie_id=327, ratings=1.0, timestamp=845554062, user_id=6),
#  Row(movie_id=329, ratings=4.0, timestamp=845553200, user_id=6),
#  Row(movie_id=330, ratings=3.0, timestamp=845555071, user_id=6),
#  Row(movie_id=332, ratings=3.0, timestamp=845555046, user_id=6),
#  Row(movie_id=333, ratings=5.0, timestamp=845553757, user_id=6),
#  Row(movie_id=336, ratings=3.0, timestamp=845556223, user_id=6),
#  Row(movie_id=337, ratings=5.0, timestamp=845553586, user_id=6),
#  Row(movie_id=339, ratings=4.0, timestamp=845553253, user_id=6),
#  Row(movie_id=340, ratings=4.0, timestamp=845555265, user_id=6),
#  Row(movie_id=342, ratings=3.0, timestamp=845553938, user_id=6),
#  Row(movie_id=343, ratings=3.0, timestamp=845555172, user_id=6),
#  Row(movie_id=344, ratings=3.0, timestamp=845553146, user_id=6),
#  Row(movie_id=347, ratings=3.0, timestamp=845555300, user_id=6),
#  Row(movie_id=348, ratings=3.0, timestamp=845553938, user_id=6),
#  Row(movie_id=349, ratings=5.0, timestamp=845553146, user_id=6),
#  Row(movie_id=350, ratings=5.0, timestamp=845553489, user_id=6),
#  Row(movie_id=351, ratings=4.0, timestamp=845554455, user_id=6),
#  Row(movie_id=352, ratings=3.0, timestamp=845555382, user_id=6),
#  Row(movie_id=353, ratings=4.0, timestamp=845553726, user_id=6),
#  Row(movie_id=354, ratings=4.0, timestamp=845555402, user_id=6),
#  Row(movie_id=355, ratings=4.0, timestamp=845553819, user_id=6),
#  Row(movie_id=356, ratings=5.0, timestamp=845553200, user_id=6),
#  Row(movie_id=357, ratings=3.0, timestamp=845553457, user_id=6),
#  Row(movie_id=358, ratings=3.0, timestamp=845555265, user_id=6),
#  Row(movie_id=359, ratings=3.0, timestamp=845556412, user_id=6),
#  Row(movie_id=360, ratings=3.0, timestamp=845555094, user_id=6),
#  Row(movie_id=361, ratings=4.0, timestamp=845554376, user_id=6),
# ...
#  Row(movie_id=450, ratings=4.0, timestamp=845555024, user_id=6),
#  Row(movie_id=454, ratings=4.0, timestamp=845553283, user_id=6),
#  Row(movie_id=455, ratings=3.0, timestamp=845554062, user_id=6),
#  Row(movie_id=457, ratings=5.0, timestamp=845553174, user_id=6),
#  Row(movie_id=458, ratings=3.0, timestamp=845555546, user_id=6),
#  Row(movie_id=460, ratings=3.0, timestamp=845555281, user_id=6),
#  Row(movie_id=466, ratings=2.0, timestamp=845553844, user_id=6),
#  Row(movie_id=468, ratings=4.0, timestamp=845553907, user_id=6),
#  Row(movie_id=469, ratings=4.0, timestamp=845555477, user_id=6),
#  Row(movie_id=472, ratings=3.0, timestamp=845555632, user_id=6),
#  Row(movie_id=474, ratings=4.0, timestamp=845553522, user_id=6),
#  Row(movie_id=475, ratings=4.0, timestamp=845554099, user_id=6),
#  Row(movie_id=477, ratings=4.0, timestamp=845554141, user_id=6),
#  Row(movie_id=480, ratings=5.0, timestamp=845553200, user_id=6),
#  Row(movie_id=485, ratings=3.0, timestamp=845553794, user_id=6),
#  Row(movie_id=489, ratings=3.0, timestamp=845554505, user_id=6),
#  Row(movie_id=490, ratings=3.0, timestamp=845554584, user_id=6),
#  Row(movie_id=491, ratings=4.0, timestamp=845554141, user_id=6),
#  Row(movie_id=493, ratings=3.0, timestamp=845555172, user_id=6),
#  Row(movie_id=494, ratings=3.0, timestamp=845554176, user_id=6),
#  Row(movie_id=497, ratings=3.0, timestamp=845553819, user_id=6),
#  Row(movie_id=500, ratings=5.0, timestamp=845553354, user_id=6),
#  Row(movie_id=502, ratings=3.0, timestamp=845554455, user_id=6),
#  Row(movie_id=505, ratings=3.0, timestamp=845555317, user_id=6),
#  Row(movie_id=508, ratings=4.0, timestamp=845553586, user_id=6),
#  Row(movie_id=509, ratings=3.0, timestamp=845553522, user_id=6),
#  Row(movie_id=510, ratings=3.0, timestamp=845555546, user_id=6),
#  Row(movie_id=515, ratings=4.0, timestamp=845553794, user_id=6),
#  Row(movie_id=516, ratings=4.0, timestamp=845554908, user_id=6),
#  Row(movie_id=520, ratings=3.0, timestamp=845553844, user_id=6),
#  Row(movie_id=524, ratings=3.0, timestamp=845554479, user_id=6),
#  Row(movie_id=527, ratings=3.0, timestamp=845553426, user_id=6),
#  Row(movie_id=531, ratings=3.0, timestamp=845554296, user_id=6),
#  Row(movie_id=532, ratings=3.0, timestamp=845554224, user_id=6),
#  Row(movie_id=536, ratings=3.0, timestamp=845556181, user_id=6),
#  Row(movie_id=537, ratings=3.0, timestamp=845554551, user_id=6),
#  Row(movie_id=539, ratings=3.0, timestamp=845553426, user_id=6),
#  Row(movie_id=540, ratings=3.0, timestamp=845554099, user_id=6),
#  Row(movie_id=542, ratings=4.0, timestamp=845554524, user_id=6),
#  Row(movie_id=543, ratings=3.0, timestamp=845554099, user_id=6),
#  Row(movie_id=546, ratings=2.0, timestamp=845554349, user_id=6),
#  Row(movie_id=548, ratings=3.0, timestamp=845554908, user_id=6),
#  Row(movie_id=552, ratings=3.0, timestamp=845553875, user_id=6),
#  Row(movie_id=553, ratings=5.0, timestamp=845553559, user_id=6),
#  Row(movie_id=569, ratings=4.0, timestamp=845555342, user_id=6),
#  Row(movie_id=575, ratings=3.0, timestamp=845555070, user_id=6),
#  Row(movie_id=587, ratings=5.0, timestamp=845553381, user_id=6),
#  Row(movie_id=588, ratings=5.0, timestamp=845553146, user_id=6),
#  Row(movie_id=589, ratings=3.0, timestamp=845553317, user_id=6),
#  Row(movie_id=590, ratings=5.0, timestamp=845553109, user_id=6),
#  Row(movie_id=592, ratings=3.0, timestamp=845553109, user_id=6),
#  Row(movie_id=593, ratings=4.0, timestamp=845553174, user_id=6),
#  Row(movie_id=594, ratings=4.0, timestamp=845553819, user_id=6),
#  Row(movie_id=595, ratings=5.0, timestamp=845553174, user_id=6),
#  Row(movie_id=596, ratings=3.0, timestamp=845554141, user_id=6),
#  Row(movie_id=597, ratings=4.0, timestamp=845553354, user_id=6),
#  Row(movie_id=606, ratings=3.0, timestamp=845555024, user_id=6),
#  Row(movie_id=608, ratings=3.0, timestamp=845553844, user_id=6),
#  Row(movie_id=609, ratings=4.0, timestamp=845555342, user_id=6),
#  Row(movie_id=616, ratings=5.0, timestamp=845554062, user_id=6),
#  Row(movie_id=628, ratings=3.0, timestamp=845555300, user_id=6),
#  Row(movie_id=631, ratings=4.0, timestamp=845555265, user_id=6),
#  Row(movie_id=637, ratings=4.0, timestamp=845555046, user_id=6),
#  Row(movie_id=640, ratings=1.0, timestamp=845555362, user_id=6),
#  Row(movie_id=647, ratings=4.0, timestamp=845555151, user_id=6),
#  Row(movie_id=662, ratings=3.0, timestamp=845556147, user_id=6),
#  Row(movie_id=667, ratings=3.0, timestamp=845555342, user_id=6),
#  Row(movie_id=694, ratings=3.0, timestamp=845555694, user_id=6),
#  Row(movie_id=697, ratings=3.0, timestamp=845556378, user_id=6),
#  Row(movie_id=700, ratings=4.0, timestamp=845556147, user_id=6),
#  Row(movie_id=704, ratings=3.0, timestamp=845555571, user_id=6),
#  Row(movie_id=708, ratings=4.0, timestamp=845554376, user_id=6),
#  Row(movie_id=709, ratings=5.0, timestamp=845555249, user_id=6),
#  Row(movie_id=710, ratings=3.0, timestamp=845556223, user_id=6),
#  Row(movie_id=711, ratings=4.0, timestamp=845555317, user_id=6),
#  Row(movie_id=719, ratings=2.0, timestamp=845555694, user_id=6),
#  Row(movie_id=736, ratings=5.0, timestamp=845553619, user_id=6),
#  Row(movie_id=747, ratings=3.0, timestamp=845555046, user_id=6),
#  Row(movie_id=762, ratings=1.0, timestamp=845555006, user_id=6),
#  Row(movie_id=765, ratings=3.0, timestamp=845555632, user_id=6),
#  Row(movie_id=775, ratings=3.0, timestamp=845556462, user_id=6),
#  Row(movie_id=780, ratings=5.0, timestamp=845556915, user_id=6),
#  Row(movie_id=783, ratings=5.0, timestamp=845554584, user_id=6),
#  Row(movie_id=795, ratings=3.0, timestamp=845556506, user_id=6),
#  Row(movie_id=799, ratings=3.0, timestamp=845555656, user_id=6),
#  Row(movie_id=801, ratings=3.0, timestamp=845556194, user_id=6),
#  Row(movie_id=802, ratings=4.0, timestamp=845554584, user_id=6),
#  Row(movie_id=818, ratings=3.0, timestamp=845555514, user_id=6),
#  Row(movie_id=830, ratings=5.0, timestamp=845556222, user_id=6),
#  Row(movie_id=835, ratings=4.0, timestamp=845556194, user_id=6),
#  Row(movie_id=837, ratings=3.0, timestamp=845556241, user_id=6),
#  Row(movie_id=838, ratings=4.0, timestamp=845555514, user_id=6),
#  Row(movie_id=839, ratings=3.0, timestamp=845556120, user_id=6),
#  Row(movie_id=842, ratings=3.0, timestamp=845555675, user_id=6),
#  Row(movie_id=848, ratings=4.0, timestamp=845556340, user_id=6),
#  Row(movie_id=852, ratings=4.0, timestamp=845555694, user_id=6),
#  Row(movie_id=867, ratings=3.0, timestamp=845556412, user_id=6),
#  Row(movie_id=880, ratings=3.0, timestamp=845556181, user_id=6),
#  Row(movie_id=881, ratings=3.0, timestamp=845556340, user_id=6),
#  Row(movie_id=888, ratings=3.0, timestamp=845556448, user_id=6),
#  Row(movie_id=891, ratings=3.0, timestamp=845556241, user_id=6),
#  Row(movie_id=979, ratings=3.0, timestamp=845556808, user_id=6),
#  Row(movie_id=981, ratings=3.0, timestamp=845556567, user_id=6),
#  Row(movie_id=986, ratings=4.0, timestamp=845556475, user_id=6),
#  Row(movie_id=991, ratings=4.0, timestamp=845556808, user_id=6),
#  Row(movie_id=996, ratings=4.0, timestamp=845556323, user_id=6),
#  Row(movie_id=999, ratings=2.0, timestamp=845556412, user_id=6),
#  Row(movie_id=1004, ratings=4.0, timestamp=845556506, user_id=6),
#  Row(movie_id=1006, ratings=4.0, timestamp=845556694, user_id=6),
#  Row(movie_id=1042, ratings=3.0, timestamp=845556462, user_id=6),
#  Row(movie_id=1049, ratings=5.0, timestamp=845556694, user_id=6),
#  Row(movie_id=1061, ratings=4.0, timestamp=845556860, user_id=6),
#  Row(movie_id=1064, ratings=4.0, timestamp=845556579, user_id=6),
#  Row(movie_id=1073, ratings=3.0, timestamp=845555571, user_id=6),
#  Row(movie_id=1082, ratings=4.0, timestamp=845556278, user_id=6),
#  Row(movie_id=1084, ratings=3.0, timestamp=845555454, user_id=6),
#  Row(movie_id=1, ratings=4.5, timestamp=1106635946, user_id=7),
#  Row(movie_id=50, ratings=4.5, timestamp=1106635993, user_id=7),
#  Row(movie_id=58, ratings=3.0, timestamp=1106635520, user_id=7),
#  Row(movie_id=150, ratings=4.5, timestamp=1106635925, user_id=7),
#  Row(movie_id=165, ratings=4.0, timestamp=1106635987, user_id=7),
#  Row(movie_id=260, ratings=5.0, timestamp=1106635933, user_id=7),
#  Row(movie_id=356, ratings=5.0, timestamp=1106635915, user_id=7),
#  Row(movie_id=380, ratings=3.0, timestamp=1106635937, user_id=7),
#  Row(movie_id=466, ratings=5.0, timestamp=1106635532, user_id=7),
#  Row(movie_id=480, ratings=5.0, timestamp=1106635917, user_id=7),
#  Row(movie_id=587, ratings=2.0, timestamp=1106635714, user_id=7),
#  Row(movie_id=588, ratings=3.0, timestamp=1106635971, user_id=7),
#  Row(movie_id=589, ratings=2.5, timestamp=1106635940, user_id=7),
#  Row(movie_id=592, ratings=3.0, timestamp=1106635922, user_id=7),
#  Row(movie_id=593, ratings=5.0, timestamp=1106635912, user_id=7),
#  Row(movie_id=595, ratings=3.5, timestamp=1106712636, user_id=7),
#  Row(movie_id=648, ratings=4.0, timestamp=1106635981, user_id=7),
#  Row(movie_id=750, ratings=4.0, timestamp=1106636810, user_id=7),
#  Row(movie_id=780, ratings=4.5, timestamp=1106635943, user_id=7),
#  Row(movie_id=920, ratings=3.0, timestamp=1106635685, user_id=7),
#  Row(movie_id=924, ratings=4.0, timestamp=1106712615, user_id=7),
#  Row(movie_id=1101, ratings=4.0, timestamp=1106635502, user_id=7),
#  Row(movie_id=1183, ratings=1.5, timestamp=1106712613, user_id=7),
#  Row(movie_id=1196, ratings=4.0, timestamp=1106635996, user_id=7),
#  Row(movie_id=1208, ratings=4.0, timestamp=1106635462, user_id=7),
#  Row(movie_id=1210, ratings=4.0, timestamp=1106635965, user_id=7),
#  Row(movie_id=1219, ratings=5.0, timestamp=1106635496, user_id=7),
#  Row(movie_id=1220, ratings=4.5, timestamp=1106635464, user_id=7),
#  Row(movie_id=1240, ratings=5.0, timestamp=1106712575, user_id=7),
#  Row(movie_id=1246, ratings=1.5, timestamp=1106635678, user_id=7),
#  Row(movie_id=1270, ratings=5.0, timestamp=1106635681, user_id=7),
#  Row(movie_id=1517, ratings=3.5, timestamp=1106635489, user_id=7),
#  Row(movie_id=1584, ratings=5.0, timestamp=1106635423, user_id=7),
#  Row(movie_id=1610, ratings=4.0, timestamp=1106635429, user_id=7),
#  Row(movie_id=1617, ratings=3.0, timestamp=1107127060, user_id=7),
#  Row(movie_id=1682, ratings=3.0, timestamp=1106635653, user_id=7),
#  Row(movie_id=1784, ratings=0.5, timestamp=1106635416, user_id=7),
#  Row(movie_id=1917, ratings=4.0, timestamp=1106635484, user_id=7),
#  Row(movie_id=1923, ratings=1.5, timestamp=1106635444, user_id=7),
#  Row(movie_id=1954, ratings=4.5, timestamp=1106635657, user_id=7),
#  Row(movie_id=2019, ratings=5.0, timestamp=1106713565, user_id=7),
#  Row(movie_id=2324, ratings=2.0, timestamp=1106712559, user_id=7),
#  Row(movie_id=2353, ratings=3.5, timestamp=1106635625, user_id=7),
#  Row(movie_id=2529, ratings=5.0, timestamp=1106635640, user_id=7),
#  Row(movie_id=2628, ratings=1.5, timestamp=1106712553, user_id=7),
#  Row(movie_id=2640, ratings=3.0, timestamp=1106635540, user_id=7),
#  Row(movie_id=2671, ratings=4.5, timestamp=1113542732, user_id=7),
#  Row(movie_id=2683, ratings=2.0, timestamp=1106635420, user_id=7),
#  Row(movie_id=2688, ratings=2.5, timestamp=1106713072, user_id=7),
#  Row(movie_id=2701, ratings=1.5, timestamp=1106713076, user_id=7),
#  Row(movie_id=2717, ratings=3.5, timestamp=1106713081, user_id=7),
#  Row(movie_id=2762, ratings=4.5, timestamp=1106635648, user_id=7),
#  Row(movie_id=2858, ratings=4.0, timestamp=1106712546, user_id=7),
#  Row(movie_id=3114, ratings=4.5, timestamp=1106635500, user_id=7),
#  Row(movie_id=3354, ratings=1.5, timestamp=1106713005, user_id=7),
#  Row(movie_id=3408, ratings=4.5, timestamp=1106712549, user_id=7),
#  Row(movie_id=3578, ratings=1.5, timestamp=1106636534, user_id=7),
#  Row(movie_id=3623, ratings=1.0, timestamp=1106712541, user_id=7),
#  Row(movie_id=3793, ratings=3.5, timestamp=1106635630, user_id=7),
#  Row(movie_id=3869, ratings=5.0, timestamp=1106635733, user_id=7),
#  Row(movie_id=3916, ratings=4.0, timestamp=1106636596, user_id=7),
#  Row(movie_id=3977, ratings=2.5, timestamp=1106635635, user_id=7),
#  Row(movie_id=3994, ratings=3.0, timestamp=1161738301, user_id=7),
#  Row(movie_id=4018, ratings=4.0, timestamp=1106712913, user_id=7),
#  Row(movie_id=4223, ratings=2.0, timestamp=1106635742, user_id=7),
#  Row(movie_id=4246, ratings=2.0, timestamp=1110855253, user_id=7),
#  Row(movie_id=4306, ratings=4.0, timestamp=1106635524, user_id=7),
#  Row(movie_id=4310, ratings=0.5, timestamp=1107127033, user_id=7),
#  Row(movie_id=4370, ratings=4.5, timestamp=1106712869, user_id=7),
#  Row(movie_id=4643, ratings=1.0, timestamp=1106635749, user_id=7),
#  Row(movie_id=4700, ratings=1.5, timestamp=1109746591, user_id=7),
#  Row(movie_id=4844, ratings=1.5, timestamp=1161738352, user_id=7),
#  Row(movie_id=4874, ratings=3.0, timestamp=1106635738, user_id=7),
#  Row(movie_id=4886, ratings=4.0, timestamp=1106636531, user_id=7),
#  Row(movie_id=4896, ratings=4.0, timestamp=1106636718, user_id=7),
#  Row(movie_id=4963, ratings=4.0, timestamp=1106636702, user_id=7),
#  Row(movie_id=4993, ratings=4.5, timestamp=1106636589, user_id=7),
#  Row(movie_id=4995, ratings=4.5, timestamp=1106636610, user_id=7),
#  Row(movie_id=5218, ratings=3.5, timestamp=1106712866, user_id=7),
#  Row(movie_id=5349, ratings=3.5, timestamp=1106636606, user_id=7),
#  Row(movie_id=5378, ratings=0.5, timestamp=1106635735, user_id=7),
#  Row(movie_id=5445, ratings=4.0, timestamp=1106636707, user_id=7),
#  Row(movie_id=5459, ratings=3.0, timestamp=1106712820, user_id=7),
#  Row(movie_id=5464, ratings=3.0, timestamp=1106636612, user_id=7),
#  Row(movie_id=5502, ratings=1.5, timestamp=1106635745, user_id=7),
#  Row(movie_id=5618, ratings=5.0, timestamp=1106713586, user_id=7),
#  Row(movie_id=5816, ratings=4.5, timestamp=1106635705, user_id=7),
#  Row(movie_id=5952, ratings=4.5, timestamp=1106636527, user_id=7),
#  Row(movie_id=5989, ratings=4.0, timestamp=1106636600, user_id=7),
#  Row(movie_id=5991, ratings=4.5, timestamp=1106712818, user_id=7),
#  Row(movie_id=6333, ratings=4.0, timestamp=1106636516, user_id=7),
#  Row(movie_id=6365, ratings=4.0, timestamp=1106712831, user_id=7),
#  Row(movie_id=6534, ratings=0.5, timestamp=1157949714, user_id=7),
#  Row(movie_id=6539, ratings=4.5, timestamp=1106636584, user_id=7),
#  Row(movie_id=6863, ratings=4.5, timestamp=1106712827, user_id=7),
#  Row(movie_id=6934, ratings=2.0, timestamp=1106712812, user_id=7),
#  Row(movie_id=7143, ratings=4.5, timestamp=1106636579, user_id=7),
#  Row(movie_id=7153, ratings=4.0, timestamp=1106636520, user_id=7),
#  Row(movie_id=7155, ratings=3.0, timestamp=1173051472, user_id=7),
#  Row(movie_id=7445, ratings=4.0, timestamp=1107473963, user_id=7),
#  Row(movie_id=8207, ratings=4.5, timestamp=1106713442, user_id=7),
#  Row(movie_id=8360, ratings=3.5, timestamp=1106636782, user_id=7),
#  Row(movie_id=8368, ratings=2.5, timestamp=1106636592, user_id=7),
#  Row(movie_id=8373, ratings=2.0, timestamp=1108602792, user_id=7),
#  Row(movie_id=8528, ratings=4.5, timestamp=1106636844, user_id=7),
#  Row(movie_id=8636, ratings=4.5, timestamp=1106636511, user_id=7),
#  Row(movie_id=8665, ratings=3.5, timestamp=1108602755, user_id=7),
#  Row(movie_id=8666, ratings=1.0, timestamp=1106779625, user_id=7),
#  Row(movie_id=8783, ratings=1.0, timestamp=1161738306, user_id=7),
#  Row(movie_id=8798, ratings=4.5, timestamp=1106636602, user_id=7),
#  Row(movie_id=8808, ratings=1.5, timestamp=1109746594, user_id=7),
#  Row(movie_id=8865, ratings=1.0, timestamp=1106713549, user_id=7),
#  Row(movie_id=8870, ratings=3.5, timestamp=1118025961, user_id=7),
#  Row(movie_id=8907, ratings=1.0, timestamp=1110757877, user_id=7),
#  Row(movie_id=8908, ratings=4.5, timestamp=1122333561, user_id=7),
#  Row(movie_id=8949, ratings=4.0, timestamp=1110757890, user_id=7),
#  Row(movie_id=8957, ratings=4.0, timestamp=1106636098, user_id=7),
#  Row(movie_id=8958, ratings=3.5, timestamp=1110173697, user_id=7),
#  Row(movie_id=8961, ratings=4.0, timestamp=1106636064, user_id=7),
#  Row(movie_id=8965, ratings=1.0, timestamp=1106636095, user_id=7),
#  Row(movie_id=8970, ratings=2.5, timestamp=1106636069, user_id=7),
#  Row(movie_id=8972, ratings=2.5, timestamp=1111552650, user_id=7),
#  Row(movie_id=8984, ratings=4.0, timestamp=1106636101, user_id=7),
#  Row(movie_id=27741, ratings=3.0, timestamp=1107474020, user_id=7),
#  Row(movie_id=30812, ratings=3.5, timestamp=1113353083, user_id=7),
#  Row(movie_id=30816, ratings=2.0, timestamp=1107127004, user_id=7),
#  ...]

# %% [markdown]
# ##### creating a dataframe from RDD using 'SQLContext'.

# %%
rating_df=sqlcontext.createDataFrame(rating_rdd)

# %% [markdown]
# ##### creating a dataframe from a RDD using SparkContext
#
#       This will throw an error because there is no function in SparkContext to create a dataframe from a RDD

# %%
new_rating_df=sc.createDataFrame(rating_rdd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-441007061514> in <module>
# ----> 1 new_rating_df=sc.createDataFrame(rating_rdd)
#
# AttributeError: 'SparkContext' object has no attribute 'createDataFrame'

# %% [markdown]
# in above example we can see that SparkContext has no attribute 'createDataFrame'
#
# so to create data frame from RDD we need sql context
#
# Check above:--->>>

# %%
rating_df.show(10)
# Out:
# +--------+-------+---------+-------+
# |movie_id|ratings|timestamp|user_id|
# +--------+-------+---------+-------+
# |       1|    4.0|964982703|      1|
# |       3|    4.0|964981247|      1|
# |       6|    4.0|964982224|      1|
# |      47|    5.0|964983815|      1|
# |      50|    5.0|964982931|      1|
# |      70|    3.0|964982400|      1|
# |     101|    5.0|964980868|      1|
# |     110|    4.0|964982176|      1|
# |     151|    5.0|964984041|      1|
# |     157|    5.0|964984100|      1|
# +--------+-------+---------+-------+
# only showing top 10 rows

# %%
rating_table=rating_df.createOrReplaceTempView("rating_table")

# %% [markdown]
# we can register the dataFrame 'rating_df' as a table then we can write sql query on the table and process
#
# check above :--->>>

# %%
sqlcontext.sql("""
describe table rating_table""").show()
# Out:
# +---------+---------+-------+
# | col_name|data_type|comment|
# +---------+---------+-------+
# | movie_id|   bigint|   null|
# |  ratings|   double|   null|
# |timestamp|   bigint|   null|
# |  user_id|   bigint|   null|
# +---------+---------+-------+

# %%
# Using sparkSQL to write SQL query to get count of rating for each movie.
# SparkSQL script returns a dataframe. --  'top_rated_movies' will be a type of dataframe.

top_rated_movies=sqlcontext.sql("""
select movie_id,count(ratings) as cnt  from rating_table group by movie_id order by cnt desc limit 10 """)

# %%
# Checking whether dataframe has been created from SparkSQL script.
top_rated_movies
# Out:
# DataFrame[movie_id: bigint, cnt: bigint]

# %%
top_rated_movies.show()
# Out:
# +--------+---+
# |movie_id|cnt|
# +--------+---+
# |     356|329|
# |     318|317|
# |     296|307|
# |     593|279|
# |    2571|278|
# |     260|251|
# |     480|238|
# |     110|237|
# |     589|224|
# |     527|220|
# +--------+---+

# %%
top_rated_movies.collect()
# Out:
# [Row(movie_id=356, cnt=329),
#  Row(movie_id=318, cnt=317),
#  Row(movie_id=296, cnt=307),
#  Row(movie_id=593, cnt=279),
#  Row(movie_id=2571, cnt=278),
#  Row(movie_id=260, cnt=251),
#  Row(movie_id=480, cnt=238),
#  Row(movie_id=110, cnt=237),
#  Row(movie_id=589, cnt=224),
#  Row(movie_id=527, cnt=220)]

# %% [markdown]
# we can use '.collect' method on dataFrame to store the result of a rdd in list
#
# results will be of type list since this is output of rdd
#
# check above:-->>

# %%
data_f1=top_rated_movies.collect()

# %%
type(data_f1)
# Out:
# list

# %%
for movie in data_f1:
    print(movie)
# Out:
# Row(movie_id=356, cnt=329)
# Row(movie_id=318, cnt=317)
# Row(movie_id=296, cnt=307)
# Row(movie_id=593, cnt=279)
# Row(movie_id=2571, cnt=278)
# Row(movie_id=260, cnt=251)
# Row(movie_id=480, cnt=238)
# Row(movie_id=110, cnt=237)
# Row(movie_id=589, cnt=224)
# Row(movie_id=527, cnt=220)
# Row(movie_id=2959, cnt=218)
# Row(movie_id=1, cnt=215)
# Row(movie_id=1196, cnt=211)
# Row(movie_id=50, cnt=204)
# Row(movie_id=2858, cnt=204)
# Row(movie_id=47, cnt=203)
# Row(movie_id=780, cnt=202)
# Row(movie_id=150, cnt=201)
# Row(movie_id=1198, cnt=200)
# Row(movie_id=4993, cnt=198)
# Row(movie_id=1210, cnt=196)
# Row(movie_id=858, cnt=192)
# Row(movie_id=457, cnt=190)
# Row(movie_id=592, cnt=189)
# Row(movie_id=2028, cnt=188)
# Row(movie_id=5952, cnt=188)
# Row(movie_id=7153, cnt=185)
# Row(movie_id=588, cnt=183)
# Row(movie_id=608, cnt=181)
# Row(movie_id=2762, cnt=179)
# Row(movie_id=380, cnt=178)
# Row(movie_id=32, cnt=177)
# Row(movie_id=364, cnt=172)
# Row(movie_id=377, cnt=171)
# Row(movie_id=1270, cnt=171)
# Row(movie_id=4306, cnt=170)
# Row(movie_id=3578, cnt=170)
# Row(movie_id=1580, cnt=165)
# Row(movie_id=590, cnt=164)
# Row(movie_id=648, cnt=162)
# Row(movie_id=344, cnt=161)
# Row(movie_id=4226, cnt=159)
# Row(movie_id=367, cnt=157)
# Row(movie_id=6539, cnt=149)
# Row(movie_id=58559, cnt=149)
# Row(movie_id=595, cnt=146)
# Row(movie_id=1214, cnt=146)
# Row(movie_id=1036, cnt=145)
# Row(movie_id=500, cnt=144)
# Row(movie_id=165, cnt=144)
# Row(movie_id=1265, cnt=143)
# Row(movie_id=79132, cnt=143)
# Row(movie_id=1197, cnt=142)
# Row(movie_id=6377, cnt=141)
# Row(movie_id=1704, cnt=141)
# Row(movie_id=1721, cnt=140)
# Row(movie_id=316, cnt=140)
# Row(movie_id=2628, cnt=140)
# Row(movie_id=1291, cnt=140)
# Row(movie_id=153, cnt=137)
# Row(movie_id=1136, cnt=136)
# Row(movie_id=597, cnt=135)
# Row(movie_id=293, cnt=133)
# Row(movie_id=3793, cnt=133)
# Row(movie_id=1193, cnt=133)
# Row(movie_id=231, cnt=133)
# Row(movie_id=10, cnt=132)
# Row(movie_id=4886, cnt=132)
# Row(movie_id=1240, cnt=131)
# Row(movie_id=1089, cnt=131)
# Row(movie_id=6874, cnt=131)
# Row(movie_id=7361, cnt=131)
# Row(movie_id=2329, cnt=129)
# Row(movie_id=1221, cnt=129)
# Row(movie_id=34, cnt=128)
# Row(movie_id=1200, cnt=126)
# Row(movie_id=1213, cnt=126)
# Row(movie_id=1682, cnt=125)
# Row(movie_id=8961, cnt=125)
# Row(movie_id=541, cnt=124)
# Row(movie_id=736, cnt=123)
# Row(movie_id=4995, cnt=123)
# Row(movie_id=5349, cnt=122)
# Row(movie_id=1097, cnt=122)
# Row(movie_id=2683, cnt=121)
# Row(movie_id=733, cnt=121)
# Row(movie_id=1206, cnt=120)
# Row(movie_id=4973, cnt=120)
# Row(movie_id=2716, cnt=120)
# Row(movie_id=5445, cnt=120)
# Row(movie_id=1073, cnt=119)
# Row(movie_id=4963, cnt=119)
# Row(movie_id=1527, cnt=116)
# Row(movie_id=586, cnt=116)
# Row(movie_id=33794, cnt=116)
# Row(movie_id=208, cnt=115)
# Row(movie_id=587, cnt=115)
# Row(movie_id=5989, cnt=115)
# Row(movie_id=1968, cnt=113)
# Row(movie_id=5418, cnt=112)
# Row(movie_id=185, cnt=112)
# Row(movie_id=3147, cnt=111)
# Row(movie_id=3996, cnt=110)
# Row(movie_id=349, cnt=110)
# Row(movie_id=2, cnt=110)
# Row(movie_id=7438, cnt=110)
# Row(movie_id=1258, cnt=109)
# Row(movie_id=253, cnt=109)
# Row(movie_id=2918, cnt=109)
# Row(movie_id=924, cnt=109)
# Row(movie_id=4878, cnt=109)
# Row(movie_id=2115, cnt=108)
# Row(movie_id=329, cnt=108)
# Row(movie_id=4896, cnt=107)
# Row(movie_id=1208, cnt=107)
# Row(movie_id=48516, cnt=107)
# Row(movie_id=539, cnt=106)
# Row(movie_id=1732, cnt=106)
# Row(movie_id=1923, cnt=105)
# Row(movie_id=68954, cnt=105)
# Row(movie_id=60069, cnt=104)
# Row(movie_id=39, cnt=104)
# Row(movie_id=111, cnt=104)
# Row(movie_id=223, cnt=104)
# Row(movie_id=2706, cnt=103)
# Row(movie_id=161, cnt=103)
# Row(movie_id=357, cnt=103)
# Row(movie_id=6, cnt=102)
# Row(movie_id=5816, cnt=102)
# Row(movie_id=1222, cnt=102)
# Row(movie_id=778, cnt=102)
# Row(movie_id=434, cnt=101)
# Row(movie_id=454, cnt=101)
# Row(movie_id=292, cnt=101)
# Row(movie_id=912, cnt=100)
# Row(movie_id=1517, cnt=100)
# Row(movie_id=4022, cnt=100)
# Row(movie_id=44191, cnt=100)
# Row(movie_id=104, cnt=99)
# Row(movie_id=2997, cnt=99)
# Row(movie_id=339, cnt=98)
# Row(movie_id=2987, cnt=97)
# Row(movie_id=3114, cnt=97)
# Row(movie_id=1617, cnt=97)
# Row(movie_id=750, cnt=97)
# Row(movie_id=72998, cnt=97)
# Row(movie_id=6365, cnt=96)
# Row(movie_id=1784, cnt=96)
# Row(movie_id=3949, cnt=96)
# Row(movie_id=1961, cnt=96)
# Row(movie_id=2502, cnt=94)
# Row(movie_id=4027, cnt=94)
# Row(movie_id=59315, cnt=94)
# Row(movie_id=551, cnt=93)
# Row(movie_id=8368, cnt=93)
# Row(movie_id=4011, cnt=93)
# Row(movie_id=8360, cnt=92)
# Row(movie_id=2355, cnt=92)
# Row(movie_id=2396, cnt=92)
# Row(movie_id=919, cnt=92)
# Row(movie_id=288, cnt=92)
# Row(movie_id=5378, cnt=92)
# Row(movie_id=1917, cnt=92)
# Row(movie_id=2797, cnt=91)
# Row(movie_id=1259, cnt=91)
# Row(movie_id=1387, cnt=91)
# Row(movie_id=2174, cnt=91)
# Row(movie_id=3948, cnt=91)
# Row(movie_id=1356, cnt=91)
# Row(movie_id=48780, cnt=90)
# Row(movie_id=1610, cnt=90)
# Row(movie_id=1080, cnt=89)
# Row(movie_id=21, cnt=89)
# Row(movie_id=19, cnt=88)
# Row(movie_id=68157, cnt=88)
# Row(movie_id=2012, cnt=88)
# Row(movie_id=2324, cnt=88)
# Row(movie_id=2916, cnt=88)
# Row(movie_id=5618, cnt=87)
# Row(movie_id=2011, cnt=87)
# Row(movie_id=2791, cnt=87)
# Row(movie_id=2617, cnt=87)
# Row(movie_id=1246, cnt=86)
# Row(movie_id=141, cnt=86)
# Row(movie_id=1653, cnt=86)
# Row(movie_id=1391, cnt=86)
# Row(movie_id=5218, cnt=85)
# Row(movie_id=1307, cnt=85)
# Row(movie_id=1393, cnt=85)
# Row(movie_id=95, cnt=84)
# Row(movie_id=904, cnt=84)
# Row(movie_id=410, cnt=84)
# Row(movie_id=1220, cnt=84)
# Row(movie_id=32587, cnt=84)
# Row(movie_id=1219, cnt=83)
# Row(movie_id=3897, cnt=83)
# Row(movie_id=1101, cnt=83)
# Row(movie_id=1584, cnt=82)
# Row(movie_id=16, cnt=82)
# Row(movie_id=788, cnt=82)
# Row(movie_id=442, cnt=81)
# Row(movie_id=49272, cnt=81)
# Row(movie_id=48394, cnt=81)
# Row(movie_id=54286, cnt=81)
# Row(movie_id=300, cnt=81)
# Row(movie_id=317, cnt=81)
# Row(movie_id=2291, cnt=80)
# Row(movie_id=62, cnt=80)
# Row(movie_id=51662, cnt=80)
# Row(movie_id=1676, cnt=80)
# Row(movie_id=8636, cnt=79)
# Row(movie_id=3052, cnt=79)
# Row(movie_id=6934, cnt=79)
# Row(movie_id=1247, cnt=79)
# Row(movie_id=3751, cnt=78)
# Row(movie_id=33493, cnt=78)
# Row(movie_id=3623, cnt=77)
# Row(movie_id=1625, cnt=77)
# Row(movie_id=46578, cnt=77)
# Row(movie_id=337, cnt=77)
# Row(movie_id=8874, cnt=77)
# Row(movie_id=594, cnt=77)
# Row(movie_id=1573, cnt=77)
# Row(movie_id=2700, cnt=76)
# Row(movie_id=69122, cnt=76)
# Row(movie_id=25, cnt=76)
# Row(movie_id=91529, cnt=76)
# Row(movie_id=440, cnt=76)
# Row(movie_id=1225, cnt=76)
# Row(movie_id=6333, cnt=76)
# Row(movie_id=3175, cnt=75)
# Row(movie_id=3481, cnt=75)
# Row(movie_id=8665, cnt=75)
# Row(movie_id=6016, cnt=75)
# Row(movie_id=2000, cnt=75)
# Row(movie_id=2692, cnt=75)
# Row(movie_id=1485, cnt=74)
# Row(movie_id=368, cnt=74)
# Row(movie_id=35836, cnt=74)
# Row(movie_id=6711, cnt=74)
# Row(movie_id=109487, cnt=73)
# Row(movie_id=3994, cnt=73)
# Row(movie_id=50872, cnt=72)
# Row(movie_id=1201, cnt=72)
# Row(movie_id=3977, cnt=72)
# Row(movie_id=45722, cnt=72)
# Row(movie_id=40815, cnt=71)
# Row(movie_id=1079, cnt=71)
# Row(movie_id=99114, cnt=71)
# Row(movie_id=6373, cnt=71)
# Row(movie_id=63082, cnt=71)
# Row(movie_id=1028, cnt=71)
# Row(movie_id=474, cnt=70)
# Row(movie_id=1407, cnt=70)
# Row(movie_id=4034, cnt=70)
# Row(movie_id=3408, cnt=70)
# Row(movie_id=2985, cnt=70)
# Row(movie_id=235, cnt=70)
# Row(movie_id=11, cnt=70)
# Row(movie_id=89745, cnt=69)
# Row(movie_id=7147, cnt=69)
# Row(movie_id=1278, cnt=69)
# Row(movie_id=923, cnt=69)
# Row(movie_id=520, cnt=69)
# Row(movie_id=266, cnt=68)
# Row(movie_id=48, cnt=68)
# Row(movie_id=3753, cnt=68)
# Row(movie_id=2054, cnt=68)
# Row(movie_id=4979, cnt=68)
# Row(movie_id=1380, cnt=68)
# Row(movie_id=1370, cnt=68)
# Row(movie_id=17, cnt=67)
# Row(movie_id=4262, cnt=67)
# Row(movie_id=2353, cnt=67)
# Row(movie_id=1544, cnt=67)
# Row(movie_id=36, cnt=67)
# Row(movie_id=74458, cnt=67)
# Row(movie_id=2081, cnt=67)
# Row(movie_id=2542, cnt=67)
# Row(movie_id=6863, cnt=66)
# Row(movie_id=508, cnt=66)
# Row(movie_id=163, cnt=66)
# Row(movie_id=1288, cnt=66)
# Row(movie_id=555, cnt=65)
# Row(movie_id=653, cnt=65)
# Row(movie_id=5481, cnt=65)
# Row(movie_id=2194, cnt=65)
# Row(movie_id=56367, cnt=65)
# Row(movie_id=553, cnt=65)
# Row(movie_id=48385, cnt=65)
# Row(movie_id=4246, cnt=65)
# Row(movie_id=70286, cnt=65)
# Row(movie_id=2710, cnt=64)
# Row(movie_id=48774, cnt=64)
# Row(movie_id=353, cnt=64)
# Row(movie_id=4447, cnt=64)
# Row(movie_id=4025, cnt=64)
# Row(movie_id=1035, cnt=64)
# Row(movie_id=1954, cnt=64)
# Row(movie_id=1234, cnt=64)
# Row(movie_id=55820, cnt=64)
# Row(movie_id=786, cnt=64)
# Row(movie_id=435, cnt=63)
# Row(movie_id=1090, cnt=63)
# Row(movie_id=5502, cnt=63)
# Row(movie_id=2657, cnt=63)
# Row(movie_id=1127, cnt=62)
# Row(movie_id=3081, cnt=62)
# Row(movie_id=1374, cnt=62)
# Row(movie_id=3671, cnt=62)
# Row(movie_id=56174, cnt=62)
# Row(movie_id=41566, cnt=62)
# Row(movie_id=7143, cnt=62)
# Row(movie_id=158, cnt=62)
# Row(movie_id=3421, cnt=62)
# Row(movie_id=1304, cnt=62)
# Row(movie_id=173, cnt=62)
# Row(movie_id=3253, cnt=61)
# Row(movie_id=509, cnt=61)
# Row(movie_id=3717, cnt=61)
# Row(movie_id=552, cnt=61)
# Row(movie_id=51255, cnt=61)
# Row(movie_id=2640, cnt=61)
# Row(movie_id=5459, cnt=61)
# Row(movie_id=8644, cnt=61)
# Row(movie_id=3527, cnt=61)
# Row(movie_id=30793, cnt=61)
# Row(movie_id=2321, cnt=61)
# Row(movie_id=596, cnt=60)
# Row(movie_id=466, cnt=60)
# Row(movie_id=5299, cnt=60)
# Row(movie_id=903, cnt=60)
# Row(movie_id=2006, cnt=60)
# Row(movie_id=3471, cnt=60)
# Row(movie_id=1377, cnt=60)
# Row(movie_id=68358, cnt=59)
# Row(movie_id=1199, cnt=59)
# Row(movie_id=6378, cnt=59)
# Row(movie_id=420, cnt=59)
# Row(movie_id=1252, cnt=59)
# Row(movie_id=3535, cnt=59)
# Row(movie_id=6942, cnt=59)
# Row(movie_id=2302, cnt=59)
# Row(movie_id=112852, cnt=59)
# Row(movie_id=1552, cnt=59)
# Row(movie_id=1500, cnt=59)
# Row(movie_id=33679, cnt=59)
# Row(movie_id=3033, cnt=59)
# Row(movie_id=6502, cnt=58)
# Row(movie_id=54001, cnt=58)
# Row(movie_id=370, cnt=58)
# Row(movie_id=1608, cnt=58)
# Row(movie_id=81845, cnt=58)
# Row(movie_id=1230, cnt=58)
# Row(movie_id=953, cnt=58)
# Row(movie_id=1207, cnt=58)
# Row(movie_id=73017, cnt=58)
# Row(movie_id=34162, cnt=58)
# Row(movie_id=5669, cnt=58)
# Row(movie_id=69844, cnt=58)
# Row(movie_id=2167, cnt=58)
# Row(movie_id=708, cnt=58)
# Row(movie_id=1394, cnt=58)
# Row(movie_id=2470, cnt=57)
# Row(movie_id=2268, cnt=57)
# Row(movie_id=80463, cnt=57)
# Row(movie_id=160, cnt=57)
# Row(movie_id=8641, cnt=57)
# Row(movie_id=1203, cnt=57)
# Row(movie_id=2005, cnt=57)
# Row(movie_id=350, cnt=57)
# Row(movie_id=1276, cnt=57)
# Row(movie_id=908, cnt=57)
# Row(movie_id=2529, cnt=56)
# Row(movie_id=4370, cnt=56)
# Row(movie_id=1302, cnt=56)
# Row(movie_id=1777, cnt=56)
# Row(movie_id=53125, cnt=56)
# Row(movie_id=1641, cnt=56)
# Row(movie_id=2671, cnt=56)
# Row(movie_id=2395, cnt=56)
# Row(movie_id=1148, cnt=56)
# Row(movie_id=2599, cnt=56)
# Row(movie_id=2080, cnt=55)
# Row(movie_id=54503, cnt=55)
# Row(movie_id=5956, cnt=55)
# Row(movie_id=432, cnt=55)
# Row(movie_id=70, cnt=55)
# Row(movie_id=78499, cnt=55)
# Row(movie_id=4308, cnt=55)
# Row(movie_id=4720, cnt=55)
# Row(movie_id=2804, cnt=55)
# Row(movie_id=7, cnt=54)
# Row(movie_id=4018, cnt=54)
# Row(movie_id=2572, cnt=54)
# Row(movie_id=784, cnt=54)
# Row(movie_id=168, cnt=54)
# Row(movie_id=91500, cnt=54)
# Row(movie_id=2406, cnt=54)
# Row(movie_id=122904, cnt=54)
# Row(movie_id=106782, cnt=54)
# Row(movie_id=59784, cnt=54)
# Row(movie_id=4816, cnt=54)
# Row(movie_id=3489, cnt=53)
# Row(movie_id=1282, cnt=53)
# Row(movie_id=76093, cnt=53)
# Row(movie_id=1997, cnt=53)
# Row(movie_id=2701, cnt=53)
# Row(movie_id=2699, cnt=53)
# Row(movie_id=485, cnt=53)
# Row(movie_id=673, cnt=53)
# Row(movie_id=3911, cnt=53)
# Row(movie_id=2712, cnt=53)
# Row(movie_id=71535, cnt=53)
# Row(movie_id=172, cnt=53)
# Row(movie_id=2078, cnt=53)
# Row(movie_id=2947, cnt=53)
# Row(movie_id=49530, cnt=53)
# Row(movie_id=30707, cnt=52)
# Row(movie_id=3552, cnt=52)
# Row(movie_id=1639, cnt=52)
# Row(movie_id=6870, cnt=52)
# Row(movie_id=225, cnt=52)
# Row(movie_id=109374, cnt=52)
# Row(movie_id=3, cnt=52)
# Row(movie_id=1466, cnt=52)
# Row(movie_id=52973, cnt=52)
# Row(movie_id=3160, cnt=52)
# Row(movie_id=45499, cnt=52)
# Row(movie_id=4848, cnt=51)
# Row(movie_id=145, cnt=51)
# Row(movie_id=2100, cnt=51)
# Row(movie_id=4239, cnt=51)
# Row(movie_id=4776, cnt=51)
# Row(movie_id=1215, cnt=51)
# Row(movie_id=1645, cnt=51)
# Row(movie_id=8361, cnt=50)
# Row(movie_id=34405, cnt=50)
# Row(movie_id=33166, cnt=50)
# Row(movie_id=5010, cnt=50)
# Row(movie_id=2424, cnt=50)
# Row(movie_id=333, cnt=50)
# Row(movie_id=3785, cnt=50)
# Row(movie_id=910, cnt=50)
# Row(movie_id=96079, cnt=50)
# Row(movie_id=8464, cnt=50)
# Row(movie_id=34048, cnt=50)
# Row(movie_id=2105, cnt=50)
# Row(movie_id=116797, cnt=50)
# Row(movie_id=88125, cnt=50)
# Row(movie_id=661, cnt=49)
# Row(movie_id=4643, cnt=49)
# Row(movie_id=45447, cnt=49)
# Row(movie_id=5, cnt=49)
# Row(movie_id=2144, cnt=49)
# Row(movie_id=216, cnt=49)
# Row(movie_id=5464, cnt=49)
# Row(movie_id=5991, cnt=49)
# Row(movie_id=3176, cnt=49)
# Row(movie_id=2641, cnt=49)
# Row(movie_id=2694, cnt=48)
# Row(movie_id=2763, cnt=48)
# Row(movie_id=7458, cnt=48)
# Row(movie_id=1729, cnt=48)
# Row(movie_id=134130, cnt=48)
# Row(movie_id=8784, cnt=48)
# Row(movie_id=186, cnt=48)
# Row(movie_id=30749, cnt=48)
# Row(movie_id=745, cnt=48)
# Row(movie_id=1275, cnt=48)
# Row(movie_id=2019, cnt=48)
# Row(movie_id=3000, cnt=48)
# Row(movie_id=1748, cnt=48)
# Row(movie_id=1921, cnt=47)
# Row(movie_id=2717, cnt=47)
# Row(movie_id=81834, cnt=47)
# Row(movie_id=1994, cnt=47)
# Row(movie_id=1358, cnt=47)
# Row(movie_id=1367, cnt=47)
# Row(movie_id=8529, cnt=47)
# Row(movie_id=5679, cnt=47)
# Row(movie_id=77561, cnt=47)
# Row(movie_id=2539, cnt=47)
# Row(movie_id=899, cnt=47)
# Row(movie_id=4014, cnt=47)
# Row(movie_id=1320, cnt=47)
# Row(movie_id=783, cnt=47)
# Row(movie_id=7293, cnt=47)
# Row(movie_id=2001, cnt=47)
# Row(movie_id=122882, cnt=47)
# Row(movie_id=1092, cnt=47)
# Row(movie_id=112, cnt=46)
# Row(movie_id=3752, cnt=46)
# Row(movie_id=7254, cnt=46)
# Row(movie_id=2076, cnt=46)
# Row(movie_id=64614, cnt=46)
# Row(movie_id=1884, cnt=46)
# Row(movie_id=5902, cnt=46)
# Row(movie_id=4085, cnt=46)
# Row(movie_id=44, cnt=46)
# Row(movie_id=2002, cnt=46)
# Row(movie_id=54272, cnt=46)
# Row(movie_id=47099, cnt=46)
# Row(movie_id=5060, cnt=46)
# Row(movie_id=1396, cnt=46)
# Row(movie_id=802, cnt=46)
# Row(movie_id=5995, cnt=46)
# Row(movie_id=1371, cnt=45)
# Row(movie_id=1690, cnt=45)
# Row(movie_id=196, cnt=45)
# Row(movie_id=31685, cnt=45)
# Row(movie_id=3863, cnt=45)
# Row(movie_id=2294, cnt=45)
# Row(movie_id=1722, cnt=45)
# Row(movie_id=4270, cnt=45)
# Row(movie_id=920, cnt=45)
# Row(movie_id=236, cnt=45)
# Row(movie_id=1250, cnt=45)
# Row(movie_id=1266, cnt=45)
# Row(movie_id=2288, cnt=45)
# Row(movie_id=4571, cnt=45)
# Row(movie_id=3255, cnt=45)
# Row(movie_id=2490, cnt=45)
# Row(movie_id=4718, cnt=45)
# Row(movie_id=1204, cnt=45)
# Row(movie_id=2023, cnt=45)
# Row(movie_id=4369, cnt=45)
# Row(movie_id=1907, cnt=45)
# Row(movie_id=616, cnt=45)
# Row(movie_id=1183, cnt=45)
# Row(movie_id=2890, cnt=45)
# Row(movie_id=6537, cnt=45)
# Row(movie_id=4975, cnt=44)
# Row(movie_id=849, cnt=44)
# Row(movie_id=2085, cnt=44)
# Row(movie_id=5377, cnt=44)
# Row(movie_id=52722, cnt=44)
# Row(movie_id=3499, cnt=44)
# Row(movie_id=33004, cnt=44)
# Row(movie_id=79702, cnt=44)
# Row(movie_id=46976, cnt=44)
# Row(movie_id=913, cnt=44)
# Row(movie_id=111759, cnt=44)
# Row(movie_id=1333, cnt=44)
# Row(movie_id=151, cnt=44)
# Row(movie_id=8798, cnt=44)
# Row(movie_id=3755, cnt=44)
# Row(movie_id=5903, cnt=44)
# Row(movie_id=37729, cnt=44)
# Row(movie_id=2278, cnt=43)
# Row(movie_id=87232, cnt=43)
# Row(movie_id=1376, cnt=43)
# Row(movie_id=76251, cnt=43)
# Row(movie_id=3275, cnt=43)
# Row(movie_id=852, cnt=43)
# Row(movie_id=1263, cnt=43)
# Row(movie_id=2455, cnt=43)
# Row(movie_id=134853, cnt=43)
# Row(movie_id=1597, cnt=43)
# Row(movie_id=252, cnt=43)
# Row(movie_id=497, cnt=43)
# Row(movie_id=3624, cnt=43)
# Row(movie_id=1876, cnt=43)
# Row(movie_id=4310, cnt=43)
# Row(movie_id=2605, cnt=43)
# Row(movie_id=3448, cnt=43)
# Row(movie_id=60684, cnt=43)
# Row(movie_id=47610, cnt=43)
# Row(movie_id=3363, cnt=43)
# Row(movie_id=8984, cnt=43)
# Row(movie_id=2161, cnt=43)
# Row(movie_id=2407, cnt=43)
# Row(movie_id=1262, cnt=43)
# Row(movie_id=1042, cnt=42)
# Row(movie_id=2724, cnt=42)
# Row(movie_id=1967, cnt=42)
# Row(movie_id=3210, cnt=42)
# Row(movie_id=69757, cnt=42)
# Row(movie_id=3868, cnt=42)
# Row(movie_id=1909, cnt=42)
# Row(movie_id=1562, cnt=42)
# Row(movie_id=2915, cnt=42)
# Row(movie_id=59369, cnt=42)
# Row(movie_id=441, cnt=42)
# Row(movie_id=431, cnt=42)
# Row(movie_id=1372, cnt=42)
# Row(movie_id=355, cnt=42)
# Row(movie_id=785, cnt=42)
# Row(movie_id=1088, cnt=42)
# Row(movie_id=81591, cnt=42)
# Row(movie_id=1375, cnt=42)
# Row(movie_id=2273, cnt=42)
# Row(movie_id=91658, cnt=42)
# Row(movie_id=1094, cnt=42)
# Row(movie_id=1022, cnt=42)
# Row(movie_id=261, cnt=42)
# Row(movie_id=3301, cnt=42)
# Row(movie_id=57669, cnt=41)
# Row(movie_id=3617, cnt=41)
# Row(movie_id=1242, cnt=41)
# Row(movie_id=2968, cnt=41)
# Row(movie_id=3418, cnt=41)
# Row(movie_id=45517, cnt=41)
# Row(movie_id=115617, cnt=41)
# Row(movie_id=762, cnt=41)
# Row(movie_id=122886, cnt=41)
# Row(movie_id=2003, cnt=41)
# Row(movie_id=543, cnt=41)
# Row(movie_id=2087, cnt=41)
# Row(movie_id=55247, cnt=41)
# Row(movie_id=5810, cnt=41)
# Row(movie_id=7373, cnt=41)
# Row(movie_id=3916, cnt=41)
# Row(movie_id=1285, cnt=41)
# Row(movie_id=494, cnt=41)
# Row(movie_id=4299, cnt=41)
# Row(movie_id=529, cnt=40)
# Row(movie_id=3703, cnt=40)
# Row(movie_id=1233, cnt=40)
# Row(movie_id=376, cnt=40)
# Row(movie_id=44199, cnt=40)
# Row(movie_id=98809, cnt=40)
# Row(movie_id=2193, cnt=40)
# Row(movie_id=6807, cnt=40)
# Row(movie_id=1228, cnt=40)
# Row(movie_id=224, cnt=40)
# Row(movie_id=31658, cnt=40)
# Row(movie_id=471, cnt=40)
# Row(movie_id=1569, cnt=40)
# Row(movie_id=4223, cnt=40)
# Row(movie_id=41569, cnt=40)
# Row(movie_id=2541, cnt=40)
# Row(movie_id=6218, cnt=40)
# Row(movie_id=4367, cnt=40)
# Row(movie_id=33615, cnt=40)
# Row(movie_id=1674, cnt=40)
# Row(movie_id=282, cnt=40)
# Row(movie_id=1032, cnt=40)
# Row(movie_id=2723, cnt=39)
# Row(movie_id=2908, cnt=39)
# Row(movie_id=53996, cnt=39)
# Row(movie_id=1274, cnt=39)
# Row(movie_id=3174, cnt=39)
# Row(movie_id=4148, cnt=39)
# Row(movie_id=1673, cnt=39)
# Row(movie_id=3300, cnt=39)
# Row(movie_id=58998, cnt=39)
# Row(movie_id=1953, cnt=39)
# Row(movie_id=6936, cnt=39)
# Row(movie_id=40819, cnt=39)
# Row(movie_id=27773, cnt=39)
# Row(movie_id=2951, cnt=39)
# Row(movie_id=7451, cnt=39)
# Row(movie_id=8949, cnt=39)
# Row(movie_id=2580, cnt=39)
# Row(movie_id=3039, cnt=39)
# Row(movie_id=2746, cnt=39)
# Row(movie_id=59615, cnt=39)
# Row(movie_id=2761, cnt=39)
# Row(movie_id=3082, cnt=39)
# Row(movie_id=2248, cnt=39)
# Row(movie_id=6188, cnt=39)
# Row(movie_id=1408, cnt=39)
# Row(movie_id=1129, cnt=39)
# Row(movie_id=8528, cnt=39)
# Row(movie_id=3826, cnt=39)
# Row(movie_id=2094, cnt=39)
# Row(movie_id=61323, cnt=39)
# Row(movie_id=29, cnt=38)
# Row(movie_id=277, cnt=38)
# Row(movie_id=3362, cnt=38)
# Row(movie_id=2289, cnt=38)
# Row(movie_id=31, cnt=38)
# Row(movie_id=8950, cnt=38)
# Row(movie_id=112552, cnt=38)
# Row(movie_id=7090, cnt=38)
# Row(movie_id=2420, cnt=38)
# Row(movie_id=2018, cnt=38)
# Row(movie_id=79091, cnt=38)
# Row(movie_id=2124, cnt=38)
# Row(movie_id=3702, cnt=38)
# Row(movie_id=8972, cnt=38)
# Row(movie_id=91542, cnt=38)
# Row(movie_id=8533, cnt=38)
# Row(movie_id=315, cnt=38)
# Row(movie_id=2770, cnt=38)
# Row(movie_id=51540, cnt=38)
# Row(movie_id=44665, cnt=38)
# Row(movie_id=2021, cnt=37)
# Row(movie_id=455, cnt=37)
# Row(movie_id=58, cnt=37)
# Row(movie_id=30810, cnt=37)
# Row(movie_id=5971, cnt=37)
# Row(movie_id=5266, cnt=37)
# Row(movie_id=92259, cnt=37)
# Row(movie_id=8376, cnt=37)
# Row(movie_id=3967, cnt=37)
# Row(movie_id=55765, cnt=37)
# Row(movie_id=64957, cnt=37)
# Row(movie_id=1020, cnt=37)
# Row(movie_id=112556, cnt=37)
# Row(movie_id=1093, cnt=37)
# Row(movie_id=4016, cnt=37)
# Row(movie_id=8622, cnt=37)
# Row(movie_id=832, cnt=37)
# Row(movie_id=2581, cnt=36)
# Row(movie_id=3034, cnt=36)
# Row(movie_id=22, cnt=36)
# Row(movie_id=1059, cnt=36)
# Row(movie_id=902, cnt=36)
# Row(movie_id=119145, cnt=36)
# Row(movie_id=3510, cnt=36)
# Row(movie_id=585, cnt=36)
# Row(movie_id=1060, cnt=36)
# Row(movie_id=3108, cnt=36)
# Row(movie_id=671, cnt=36)
# Row(movie_id=3247, cnt=36)
# Row(movie_id=2231, cnt=36)
# Row(movie_id=345, cnt=36)
# Row(movie_id=34150, cnt=36)
# Row(movie_id=1345, cnt=36)
# Row(movie_id=44195, cnt=36)
# Row(movie_id=4638, cnt=36)
# Row(movie_id=3101, cnt=36)
# Row(movie_id=2948, cnt=36)
# Row(movie_id=180, cnt=36)
# Row(movie_id=6947, cnt=36)
# Row(movie_id=31696, cnt=35)
# Row(movie_id=193, cnt=35)
# Row(movie_id=7445, cnt=35)
# Row(movie_id=3809, cnt=35)
# Row(movie_id=170, cnt=35)
# Row(movie_id=3409, cnt=35)
# Row(movie_id=38061, cnt=35)
# Row(movie_id=3361, cnt=35)
# Row(movie_id=719, cnt=35)
# Row(movie_id=1084, cnt=35)
# Row(movie_id=628, cnt=35)
# Row(movie_id=60040, cnt=35)
# Row(movie_id=30812, cnt=35)
# Row(movie_id=914, cnt=35)
# Row(movie_id=805, cnt=35)
# Row(movie_id=66097, cnt=35)
# Row(movie_id=256, cnt=35)
# Row(movie_id=1029, cnt=35)
# Row(movie_id=1249, cnt=35)
# Row(movie_id=36529, cnt=35)
# Row(movie_id=2427, cnt=35)
# Row(movie_id=63113, cnt=35)
# Row(movie_id=6287, cnt=34)
# Row(movie_id=3698, cnt=34)
# Row(movie_id=44555, cnt=34)
# Row(movie_id=39183, cnt=34)
# Row(movie_id=64839, cnt=34)
# Row(movie_id=45720, cnt=34)
# Row(movie_id=2140, cnt=34)
# Row(movie_id=1287, cnt=34)
# Row(movie_id=3882, cnt=34)
# Row(movie_id=85414, cnt=34)
# Row(movie_id=1947, cnt=34)
# Row(movie_id=54259, cnt=34)
# Row(movie_id=1172, cnt=34)
# Row(movie_id=1663, cnt=34)
# Row(movie_id=362, cnt=34)
# Row(movie_id=1261, cnt=34)
# Row(movie_id=8807, cnt=34)
# Row(movie_id=6708, cnt=34)
# Row(movie_id=327, cnt=34)
# Row(movie_id=5254, cnt=34)
# Row(movie_id=524, cnt=34)
# Row(movie_id=64969, cnt=34)
# Row(movie_id=69481, cnt=34)
# Row(movie_id=4344, cnt=34)
# Row(movie_id=86332, cnt=34)
# Row(movie_id=4734, cnt=34)
# Row(movie_id=4641, cnt=34)
# Row(movie_id=60, cnt=34)
# Row(movie_id=969, cnt=34)
# Row(movie_id=1882, cnt=33)
# Row(movie_id=3988, cnt=33)
# Row(movie_id=2300, cnt=33)
# Row(movie_id=53322, cnt=33)
# Row(movie_id=3396, cnt=33)
# Row(movie_id=5673, cnt=33)
# Row(movie_id=6754, cnt=33)
# Row(movie_id=5388, cnt=33)
# Row(movie_id=1918, cnt=33)
# Row(movie_id=342, cnt=33)
# Row(movie_id=610, cnt=33)
# Row(movie_id=4015, cnt=33)
# Row(movie_id=637, cnt=33)
# Row(movie_id=1047, cnt=33)
# Row(movie_id=1244, cnt=33)
# Row(movie_id=2949, cnt=33)
# Row(movie_id=61132, cnt=33)
# Row(movie_id=3555, cnt=33)
# Row(movie_id=2145, cnt=33)
# Row(movie_id=3681, cnt=33)
# Row(movie_id=265, cnt=33)
# Row(movie_id=8957, cnt=33)
# Row(movie_id=2393, cnt=33)
# Row(movie_id=1272, cnt=33)
# Row(movie_id=6534, cnt=33)
# Row(movie_id=4874, cnt=33)
# Row(movie_id=30825, cnt=33)
# Row(movie_id=837, cnt=33)
# Row(movie_id=72011, cnt=32)
# Row(movie_id=152081, cnt=32)
# Row(movie_id=2944, cnt=32)
# Row(movie_id=96610, cnt=32)
# Row(movie_id=4361, cnt=32)
# Row(movie_id=8970, cnt=32)
# Row(movie_id=1911, cnt=32)
# Row(movie_id=88140, cnt=32)
# Row(movie_id=5064, cnt=32)
# Row(movie_id=3257, cnt=32)
# Row(movie_id=303, cnt=32)
# Row(movie_id=3285, cnt=32)
# Row(movie_id=1912, cnt=32)
# Row(movie_id=104841, cnt=32)
# Row(movie_id=68237, cnt=32)
# Row(movie_id=2160, cnt=32)
# Row(movie_id=102125, cnt=32)
# Row(movie_id=6541, cnt=32)
# Row(movie_id=6157, cnt=32)
# Row(movie_id=8917, cnt=32)
# Row(movie_id=53972, cnt=32)
# Row(movie_id=6281, cnt=32)
# Row(movie_id=1644, cnt=32)
# Row(movie_id=88129, cnt=32)
# Row(movie_id=45, cnt=32)
# Row(movie_id=65, cnt=31)
# Row(movie_id=724, cnt=31)
# Row(movie_id=3386, cnt=31)
# Row(movie_id=2953, cnt=31)
# Row(movie_id=34319, cnt=31)
# Row(movie_id=61024, cnt=31)
# Row(movie_id=1405, cnt=31)
# Row(movie_id=1805, cnt=31)
# Row(movie_id=4321, cnt=31)
# Row(movie_id=4890, cnt=31)
# Row(movie_id=46723, cnt=31)
# Row(movie_id=5630, cnt=31)
# Row(movie_id=1717, cnt=31)
# Row(movie_id=4446, cnt=31)
# Row(movie_id=1566, cnt=31)
# Row(movie_id=2064, cnt=31)
# Row(movie_id=3006, cnt=31)
# Row(movie_id=4701, cnt=31)
# Row(movie_id=3256, cnt=31)
# Row(movie_id=1747, cnt=31)
# Row(movie_id=88163, cnt=31)
# Row(movie_id=97938, cnt=31)
# Row(movie_id=108932, cnt=31)
# Row(movie_id=272, cnt=31)
# Row(movie_id=135, cnt=31)
# Row(movie_id=110102, cnt=31)
# Row(movie_id=72641, cnt=31)
# Row(movie_id=139385, cnt=31)
# Row(movie_id=1587, cnt=31)
# Row(movie_id=56757, cnt=30)
# Row(movie_id=348, cnt=30)
# Row(movie_id=2403, cnt=30)
# Row(movie_id=5219, cnt=30)
# Row(movie_id=111362, cnt=30)
# Row(movie_id=2501, cnt=30)
# Row(movie_id=915, cnt=30)
# Row(movie_id=95167, cnt=30)
# Row(movie_id=1267, cnt=30)
# Row(movie_id=1373, cnt=30)
# Row(movie_id=838, cnt=30)
# Row(movie_id=38038, cnt=30)
# Row(movie_id=1271, cnt=30)
# Row(movie_id=97921, cnt=30)
# Row(movie_id=2058, cnt=30)
# Row(movie_id=2423, cnt=30)
# Row(movie_id=2871, cnt=30)
# Row(movie_id=84152, cnt=30)
# Row(movie_id=1479, cnt=30)
# Row(movie_id=7022, cnt=30)
# Row(movie_id=204, cnt=30)
# Row(movie_id=95510, cnt=30)
# Row(movie_id=5444, cnt=29)
# Row(movie_id=1513, cnt=29)
# Row(movie_id=1269, cnt=29)
# Row(movie_id=2384, cnt=29)
# Row(movie_id=1831, cnt=29)
# Row(movie_id=246, cnt=29)
# Row(movie_id=115149, cnt=29)
# Row(movie_id=743, cnt=29)
# Row(movie_id=2722, cnt=29)
# Row(movie_id=6155, cnt=29)
# Row(movie_id=106696, cnt=29)
# Row(movie_id=1339, cnt=29)
# Row(movie_id=2485, cnt=29)
# Row(movie_id=898, cnt=29)
# Row(movie_id=3168, cnt=29)
# Row(movie_id=3273, cnt=29)
# Row(movie_id=2411, cnt=29)
# Row(movie_id=3450, cnt=29)
# Row(movie_id=2421, cnt=29)
# Row(movie_id=60074, cnt=29)
# Row(movie_id=647, cnt=29)
# Row(movie_id=3825, cnt=29)
# Row(movie_id=94959, cnt=29)
# Row(movie_id=1061, cnt=29)
# Row(movie_id=3745, cnt=29)
# Row(movie_id=60756, cnt=28)
# Row(movie_id=1077, cnt=28)
# Row(movie_id=198, cnt=28)
# Row(movie_id=1299, cnt=28)
# Row(movie_id=82459, cnt=28)
# Row(movie_id=115713, cnt=28)
# Row(movie_id=4232, cnt=28)
# Row(movie_id=46970, cnt=28)
# Row(movie_id=968, cnt=28)
# Row(movie_id=52, cnt=28)
# Row(movie_id=3740, cnt=28)
# Row(movie_id=4019, cnt=28)
# Row(movie_id=2335, cnt=28)
# Row(movie_id=2788, cnt=28)
# Row(movie_id=56782, cnt=28)
# Row(movie_id=74789, cnt=28)
# Row(movie_id=45186, cnt=28)
# Row(movie_id=1027, cnt=28)
# Row(movie_id=5620, cnt=28)
# Row(movie_id=1223, cnt=28)
# Row(movie_id=2150, cnt=28)
# Row(movie_id=3186, cnt=28)
# Row(movie_id=2243, cnt=28)
# Row(movie_id=273, cnt=28)
# Row(movie_id=24, cnt=28)
# Row(movie_id=97304, cnt=28)
# Row(movie_id=102445, cnt=27)
# Row(movie_id=720, cnt=27)
# Row(movie_id=3252, cnt=27)
# Row(movie_id=57368, cnt=27)
# Row(movie_id=3269, cnt=27)
# Row(movie_id=909, cnt=27)
# Row(movie_id=80549, cnt=27)
# Row(movie_id=5013, cnt=27)
# Row(movie_id=880, cnt=27)
# Row(movie_id=1021, cnt=27)
# Row(movie_id=88744, cnt=27)
# Row(movie_id=1347, cnt=27)
# Row(movie_id=40629, cnt=27)
# Row(movie_id=122892, cnt=27)
# Row(movie_id=4343, cnt=27)
# Row(movie_id=6787, cnt=27)
# Row(movie_id=5872, cnt=27)
# Row(movie_id=166528, cnt=27)
# Row(movie_id=122900, cnt=27)
# Row(movie_id=1257, cnt=27)
# Row(movie_id=4700, cnt=27)
# Row(movie_id=741, cnt=27)
# Row(movie_id=6503, cnt=27)
# Row(movie_id=3072, cnt=27)
# Row(movie_id=52281, cnt=27)
# Row(movie_id=2232, cnt=27)
# Row(movie_id=922, cnt=27)
# Row(movie_id=37733, cnt=27)
# Row(movie_id=1120, cnt=27)
# Row(movie_id=1982, cnt=27)
# Row(movie_id=4002, cnt=27)
# Row(movie_id=8873, cnt=27)
# Row(movie_id=1179, cnt=27)
# Row(movie_id=94864, cnt=27)
# Row(movie_id=3424, cnt=27)
# Row(movie_id=4901, cnt=27)
# Row(movie_id=2109, cnt=27)
# Row(movie_id=1499, cnt=27)
# Row(movie_id=3254, cnt=27)
# Row(movie_id=3968, cnt=27)
# Row(movie_id=1293, cnt=27)
# Row(movie_id=122918, cnt=27)
# Row(movie_id=2431, cnt=27)
# Row(movie_id=3869, cnt=26)
# Row(movie_id=1591, cnt=26)
# Row(movie_id=6957, cnt=26)
# Row(movie_id=89492, cnt=26)
# Row(movie_id=4128, cnt=26)
# Row(movie_id=3969, cnt=26)
# Row(movie_id=2478, cnt=26)
# Row(movie_id=413, cnt=26)
# Row(movie_id=1960, cnt=26)
# Row(movie_id=2616, cnt=26)
# Row(movie_id=2795, cnt=26)
# Row(movie_id=107, cnt=26)
# Row(movie_id=1476, cnt=26)
# Row(movie_id=2826, cnt=26)
# Row(movie_id=53519, cnt=26)
# Row(movie_id=106487, cnt=26)
# Row(movie_id=3148, cnt=26)
# Row(movie_id=68319, cnt=26)
# Row(movie_id=112183, cnt=26)
# Row(movie_id=3476, cnt=26)
# Row(movie_id=5574, cnt=26)
# Row(movie_id=148626, cnt=26)
# Row(movie_id=8783, cnt=26)
# Row(movie_id=2359, cnt=26)
# Row(movie_id=3556, cnt=26)
# Row(movie_id=2082, cnt=26)
# Row(movie_id=1235, cnt=26)
# Row(movie_id=5945, cnt=26)
# Row(movie_id=916, cnt=26)
# Row(movie_id=2409, cnt=26)
# Row(movie_id=3264, cnt=26)
# Row(movie_id=93510, cnt=26)
# Row(movie_id=3638, cnt=26)
# Row(movie_id=164179, cnt=26)
# Row(movie_id=1614, cnt=26)
# Row(movie_id=4388, cnt=26)
# Row(movie_id=4823, cnt=25)
# Row(movie_id=5617, cnt=25)
# Row(movie_id=2598, cnt=25)
# Row(movie_id=1343, cnt=25)
# Row(movie_id=1025, cnt=25)
# Row(movie_id=106489, cnt=25)
# Row(movie_id=46530, cnt=25)
# Row(movie_id=3534, cnt=25)
# Row(movie_id=2186, cnt=25)
# Row(movie_id=2394, cnt=25)
# Row(movie_id=3005, cnt=25)
# Row(movie_id=3608, cnt=25)
# Row(movie_id=1253, cnt=25)
# Row(movie_id=106920, cnt=25)
# Row(movie_id=27706, cnt=25)
# Row(movie_id=2366, cnt=25)
# Row(movie_id=54997, cnt=25)
# Row(movie_id=86882, cnt=25)
# Row(movie_id=3462, cnt=25)
# Row(movie_id=2352, cnt=25)
# Row(movie_id=1378, cnt=25)
# Row(movie_id=1801, cnt=25)
# Row(movie_id=1590, cnt=25)
# Row(movie_id=53953, cnt=25)
# Row(movie_id=2986, cnt=25)
# Row(movie_id=168252, cnt=25)
# Row(movie_id=2020, cnt=25)
# Row(movie_id=2872, cnt=25)
# Row(movie_id=6953, cnt=25)
# Row(movie_id=475, cnt=25)
# Row(movie_id=1086, cnt=25)
# Row(movie_id=374, cnt=25)
# Row(movie_id=51935, cnt=25)
# Row(movie_id=1680, cnt=25)
# Row(movie_id=67255, cnt=25)
# Row(movie_id=3438, cnt=25)
# Row(movie_id=8983, cnt=25)
# Row(movie_id=3798, cnt=25)
# Row(movie_id=3704, cnt=24)
# Row(movie_id=2371, cnt=24)
# Row(movie_id=926, cnt=24)
# Row(movie_id=1711, cnt=24)
# Row(movie_id=1212, cnt=24)
# Row(movie_id=5103, cnt=24)
# Row(movie_id=6593, cnt=24)
# Row(movie_id=1945, cnt=24)
# Row(movie_id=2687, cnt=24)
# Row(movie_id=3098, cnt=24)
# Row(movie_id=215, cnt=24)
# Row(movie_id=49286, cnt=24)
# Row(movie_id=307, cnt=24)
# Row(movie_id=515, cnt=24)
# Row(movie_id=56775, cnt=24)
# Row(movie_id=1037, cnt=24)
# Row(movie_id=5110, cnt=24)
# Row(movie_id=2369, cnt=24)
# Row(movie_id=1449, cnt=24)
# Row(movie_id=2410, cnt=24)
# Row(movie_id=1357, cnt=24)
# Row(movie_id=87869, cnt=24)
# Row(movie_id=3087, cnt=24)
# Row(movie_id=1125, cnt=24)
# Row(movie_id=2471, cnt=24)
# Row(movie_id=81847, cnt=24)
# Row(movie_id=3037, cnt=24)
# Row(movie_id=1031, cnt=24)
# Row(movie_id=1438, cnt=24)
# Row(movie_id=230, cnt=24)
# Row(movie_id=2046, cnt=24)
# Row(movie_id=3979, cnt=24)
# Row(movie_id=2528, cnt=24)
# Row(movie_id=1385, cnt=24)
# Row(movie_id=2108, cnt=24)
# Row(movie_id=7173, cnt=24)
# Row(movie_id=5507, cnt=24)
# Row(movie_id=2993, cnt=24)
# Row(movie_id=4489, cnt=24)
# Row(movie_id=86880, cnt=24)
# Row(movie_id=7454, cnt=24)
# Row(movie_id=1883, cnt=24)
# Row(movie_id=66934, cnt=24)
# Row(movie_id=6350, cnt=24)
# Row(movie_id=531, cnt=24)
# Row(movie_id=1409, cnt=23)
# Row(movie_id=4161, cnt=23)
# Row(movie_id=4235, cnt=23)
# Row(movie_id=1256, cnt=23)
# Row(movie_id=2336, cnt=23)
# Row(movie_id=7099, cnt=23)
# Row(movie_id=3827, cnt=23)
# Row(movie_id=562, cnt=23)
# Row(movie_id=933, cnt=23)
# Row(movie_id=2496, cnt=23)
# Row(movie_id=866, cnt=23)
# Row(movie_id=1321, cnt=23)
# Row(movie_id=1779, cnt=23)
# Row(movie_id=2840, cnt=23)
# Row(movie_id=2805, cnt=23)
# Row(movie_id=105, cnt=23)
# Row(movie_id=2052, cnt=23)
# Row(movie_id=117529, cnt=23)
# Row(movie_id=101, cnt=23)
# Row(movie_id=1186, cnt=23)
# Row(movie_id=81932, cnt=23)
# Row(movie_id=45672, cnt=23)
# Row(movie_id=1962, cnt=23)
# Row(movie_id=46972, cnt=23)
# Row(movie_id=37741, cnt=23)
# Row(movie_id=1298, cnt=23)
# Row(movie_id=3107, cnt=23)
# Row(movie_id=2428, cnt=23)
# Row(movie_id=44022, cnt=23)
# Row(movie_id=799, cnt=23)
# Row(movie_id=1792, cnt=23)
# Row(movie_id=4023, cnt=23)
# Row(movie_id=2991, cnt=23)
# Row(movie_id=116823, cnt=23)
# Row(movie_id=8371, cnt=23)
# Row(movie_id=7323, cnt=23)
# Row(movie_id=1958, cnt=22)
# Row(movie_id=237, cnt=22)
# Row(movie_id=2378, cnt=22)
# Row(movie_id=97913, cnt=22)
# Row(movie_id=3105, cnt=22)
# Row(movie_id=80489, cnt=22)
# Row(movie_id=4069, cnt=22)
# Row(movie_id=203, cnt=22)
# Row(movie_id=5449, cnt=22)
# Row(movie_id=227, cnt=22)
# Row(movie_id=27904, cnt=22)
# Row(movie_id=54995, cnt=22)
# Row(movie_id=60072, cnt=22)
# Row(movie_id=276, cnt=22)
# Row(movie_id=103042, cnt=22)
# Row(movie_id=2134, cnt=22)
# Row(movie_id=5171, cnt=22)
# Row(movie_id=93840, cnt=22)
# Row(movie_id=2707, cnt=22)
# Row(movie_id=748, cnt=22)
# Row(movie_id=1231, cnt=22)
# Row(movie_id=3360, cnt=22)
# Row(movie_id=122920, cnt=22)
# Row(movie_id=2642, cnt=22)
# Row(movie_id=6323, cnt=22)
# Row(movie_id=3263, cnt=22)
# Row(movie_id=6773, cnt=22)
# Row(movie_id=5954, cnt=22)
# Row(movie_id=468, cnt=22)
# Row(movie_id=1350, cnt=22)
# Row(movie_id=3504, cnt=22)
# Row(movie_id=1188, cnt=22)
# Row(movie_id=63992, cnt=22)
# Row(movie_id=5313, cnt=22)
# Row(movie_id=2096, cnt=22)
# Row(movie_id=1586, cnt=22)
# Row(movie_id=2600, cnt=22)
# Row(movie_id=122922, cnt=22)
# Row(movie_id=2391, cnt=22)
# Row(movie_id=4105, cnt=22)
# Row(movie_id=91630, cnt=22)
# Row(movie_id=5283, cnt=22)
# Row(movie_id=3104, cnt=22)
# Row(movie_id=102903, cnt=22)
# Row(movie_id=2245, cnt=22)
# Row(movie_id=3100, cnt=22)
# Row(movie_id=1952, cnt=22)
# Row(movie_id=3317, cnt=22)
# Row(movie_id=2989, cnt=21)
# Row(movie_id=1175, cnt=21)
# Row(movie_id=86833, cnt=21)
# Row(movie_id=104211, cnt=21)
# Row(movie_id=79592, cnt=21)
# Row(movie_id=7325, cnt=21)
# Row(movie_id=2720, cnt=21)
# Row(movie_id=830, cnt=21)
# Row(movie_id=34437, cnt=21)
# Row(movie_id=262, cnt=21)
# Row(movie_id=62434, cnt=21)
# Row(movie_id=72378, cnt=21)
# Row(movie_id=2137, cnt=21)
# Row(movie_id=37386, cnt=21)
# Row(movie_id=84954, cnt=21)
# Row(movie_id=546, cnt=21)
# Row(movie_id=87306, cnt=21)
# Row(movie_id=519, cnt=21)
# Row(movie_id=207, cnt=21)
# Row(movie_id=2376, cnt=21)
# Row(movie_id=3984, cnt=21)
# Row(movie_id=53121, cnt=21)
# Row(movie_id=88810, cnt=21)
# Row(movie_id=2010, cnt=21)
# Row(movie_id=3070, cnt=21)
# Row(movie_id=41997, cnt=21)
# Row(movie_id=2405, cnt=21)
# Row(movie_id=4247, cnt=21)
# Row(movie_id=247, cnt=21)
# Row(movie_id=105504, cnt=21)
# Row(movie_id=2013, cnt=21)
# Row(movie_id=383, cnt=21)
# Row(movie_id=379, cnt=21)
# Row(movie_id=7444, cnt=21)
# Row(movie_id=53000, cnt=21)
# Row(movie_id=1091, cnt=21)
# Row(movie_id=371, cnt=21)
# Row(movie_id=107406, cnt=21)
# Row(movie_id=2067, cnt=21)
# Row(movie_id=6979, cnt=21)
# Row(movie_id=3697, cnt=21)
# Row(movie_id=2139, cnt=21)
# Row(movie_id=5225, cnt=21)
# Row(movie_id=372, cnt=21)
# Row(movie_id=2125, cnt=21)
# Row(movie_id=8910, cnt=21)
# Row(movie_id=3536, cnt=21)
# Row(movie_id=106072, cnt=21)
# Row(movie_id=1965, cnt=21)
# Row(movie_id=55269, cnt=21)
# Row(movie_id=3354, cnt=21)
# Row(movie_id=3298, cnt=21)
# Row(movie_id=95441, cnt=21)
# Row(movie_id=707, cnt=21)
# Row(movie_id=1049, cnt=21)
# Row(movie_id=2375, cnt=21)
# Row(movie_id=6297, cnt=20)
# Row(movie_id=4545, cnt=20)
# Row(movie_id=96821, cnt=20)
# Row(movie_id=737, cnt=20)
# Row(movie_id=7346, cnt=20)
# Row(movie_id=55290, cnt=20)
# Row(movie_id=4623, cnt=20)
# Row(movie_id=5881, cnt=20)
# Row(movie_id=1297, cnt=20)
# Row(movie_id=36401, cnt=20)
# Row(movie_id=27660, cnt=20)
# Row(movie_id=3986, cnt=20)
# Row(movie_id=6873, cnt=20)
# Row(movie_id=96588, cnt=20)
# Row(movie_id=1429, cnt=20)
# Row(movie_id=102407, cnt=20)
# Row(movie_id=7387, cnt=20)
# Row(movie_id=81564, cnt=20)
# Row(movie_id=319, cnt=20)
# Row(movie_id=419, cnt=20)
# Row(movie_id=4980, cnt=20)
# Row(movie_id=1588, cnt=20)
# Row(movie_id=122916, cnt=20)
# Row(movie_id=88405, cnt=20)
# Row(movie_id=4448, cnt=20)
# Row(movie_id=69526, cnt=20)
# Row(movie_id=81229, cnt=20)
# Row(movie_id=2253, cnt=20)
# Row(movie_id=101864, cnt=20)
# Row(movie_id=1688, cnt=20)
# Row(movie_id=56949, cnt=20)
# Row(movie_id=1245, cnt=20)
# Row(movie_id=2990, cnt=20)
# Row(movie_id=39292, cnt=20)
# Row(movie_id=2133, cnt=20)
# Row(movie_id=4958, cnt=20)
# Row(movie_id=1292, cnt=20)
# Row(movie_id=175, cnt=20)
# Row(movie_id=4007, cnt=20)
# Row(movie_id=930, cnt=20)
# Row(movie_id=4865, cnt=20)
# Row(movie_id=308, cnt=20)
# Row(movie_id=63131, cnt=20)
# Row(movie_id=31410, cnt=20)
# Row(movie_id=49278, cnt=20)
# Row(movie_id=1015, cnt=20)
# Row(movie_id=18, cnt=20)
# Row(movie_id=69, cnt=20)
# Row(movie_id=7371, cnt=20)
# Row(movie_id=3910, cnt=20)
# Row(movie_id=6283, cnt=20)
# Row(movie_id=106918, cnt=20)
# Row(movie_id=2053, cnt=20)
# Row(movie_id=53464, cnt=20)
# Row(movie_id=6888, cnt=20)
# Row(movie_id=1104, cnt=20)
# Row(movie_id=8969, cnt=20)
# Row(movie_id=2340, cnt=20)
# Row(movie_id=4855, cnt=20)
# Row(movie_id=1616, cnt=20)
# Row(movie_id=1033, cnt=20)
# Row(movie_id=48738, cnt=20)
# Row(movie_id=1224, cnt=19)
# Row(movie_id=6156, cnt=19)
# Row(movie_id=2881, cnt=19)
# Row(movie_id=5957, cnt=19)
# Row(movie_id=27831, cnt=19)
# Row(movie_id=5528, cnt=19)
# Row(movie_id=4084, cnt=19)
# Row(movie_id=1283, cnt=19)
# Row(movie_id=55118, cnt=19)
# Row(movie_id=1441, cnt=19)
# Row(movie_id=3861, cnt=19)
# Row(movie_id=3328, cnt=19)
# Row(movie_id=5782, cnt=19)
# Row(movie_id=6383, cnt=19)
# Row(movie_id=5943, cnt=19)
# Row(movie_id=1693, cnt=19)
# Row(movie_id=2567, cnt=19)
# Row(movie_id=103249, cnt=19)
# Row(movie_id=31878, cnt=19)
# Row(movie_id=1100, cnt=19)
# Row(movie_id=8958, cnt=19)
# Row(movie_id=2009, cnt=19)
# Row(movie_id=1381, cnt=19)
# Row(movie_id=1556, cnt=19)
# Row(movie_id=89864, cnt=19)
# Row(movie_id=103335, cnt=19)
# Row(movie_id=4873, cnt=19)
# Row(movie_id=761, cnt=19)
# Row(movie_id=481, cnt=19)
# Row(movie_id=800, cnt=19)
# Row(movie_id=3083, cnt=19)
# Row(movie_id=12, cnt=19)
# Row(movie_id=142488, cnt=19)
# Row(movie_id=3683, cnt=19)
# Row(movie_id=82461, cnt=19)
# Row(movie_id=2792, cnt=19)
# Row(movie_id=2402, cnt=19)
# Row(movie_id=765, cnt=19)
# Row(movie_id=4366, cnt=19)
# Row(movie_id=2863, cnt=19)
# Row(movie_id=2686, cnt=19)
# Row(movie_id=3744, cnt=19)
# Row(movie_id=112138, cnt=19)
# Row(movie_id=5944, cnt=19)
# Row(movie_id=338, cnt=19)
# Row(movie_id=48304, cnt=19)
# Row(movie_id=5308, cnt=19)
# Row(movie_id=97752, cnt=19)
# Row(movie_id=3593, cnt=19)
# Row(movie_id=32031, cnt=19)
# Row(movie_id=2083, cnt=19)
# Row(movie_id=27611, cnt=19)
# Row(movie_id=3157, cnt=19)
# Row(movie_id=3893, cnt=19)
# Row(movie_id=3452, cnt=18)
# Row(movie_id=2088, cnt=18)
# Row(movie_id=1687, cnt=18)
# Row(movie_id=4639, cnt=18)
# Row(movie_id=2841, cnt=18)
# Row(movie_id=3468, cnt=18)
# Row(movie_id=3173, cnt=18)
# Row(movie_id=2530, cnt=18)
# Row(movie_id=103341, cnt=18)
# Row(movie_id=516, cnt=18)
# Row(movie_id=108190, cnt=18)
# Row(movie_id=128360, cnt=18)
# Row(movie_id=6796, cnt=18)
# Row(movie_id=5152, cnt=18)
# Row(movie_id=57640, cnt=18)
# Row(movie_id=118696, cnt=18)
# Row(movie_id=2527, cnt=18)
# Row(movie_id=2110, cnt=18)
# Row(movie_id=5463, cnt=18)
# Row(movie_id=3267, cnt=18)
# Row(movie_id=6565, cnt=18)
# Row(movie_id=2338, cnt=18)
# Row(movie_id=176371, cnt=18)
# Row(movie_id=928, cnt=18)
# Row(movie_id=58803, cnt=18)
# Row(movie_id=2413, cnt=18)
# Row(movie_id=58025, cnt=18)
# Row(movie_id=6620, cnt=18)
# Row(movie_id=1237, cnt=18)
# Row(movie_id=1920, cnt=18)
# Row(movie_id=3635, cnt=18)
# Row(movie_id=2973, cnt=18)
# Row(movie_id=540, cnt=18)
# Row(movie_id=5151, cnt=18)
# Row(movie_id=91535, cnt=18)
# Row(movie_id=249, cnt=18)
# Row(movie_id=8865, cnt=18)
# Row(movie_id=63859, cnt=18)
# Row(movie_id=4728, cnt=18)
# Row(movie_id=68791, cnt=18)
# Row(movie_id=514, cnt=18)
# Row(movie_id=1209, cnt=18)
# Row(movie_id=2505, cnt=18)
# Row(movie_id=138036, cnt=18)
# Row(movie_id=954, cnt=18)
# Row(movie_id=428, cnt=18)
# Row(movie_id=2467, cnt=18)
# Row(movie_id=72226, cnt=18)
# Row(movie_id=2141, cnt=18)
# Row(movie_id=4621, cnt=18)
# Row(movie_id=83134, cnt=18)
# Row(movie_id=955, cnt=18)
# Row(movie_id=533, cnt=18)
# Row(movie_id=14, cnt=18)
# Row(movie_id=1359, cnt=18)
# Row(movie_id=194, cnt=18)
# Row(movie_id=56171, cnt=18)
# Row(movie_id=81562, cnt=18)
# Row(movie_id=5291, cnt=18)
# Row(movie_id=5015, cnt=18)
# Row(movie_id=115569, cnt=18)
# Row(movie_id=47997, cnt=18)
# Row(movie_id=3508, cnt=18)
# Row(movie_id=94777, cnt=18)
# Row(movie_id=3639, cnt=18)
# Row(movie_id=3479, cnt=18)
# Row(movie_id=34072, cnt=18)
# Row(movie_id=90866, cnt=18)
# Row(movie_id=106100, cnt=17)
# Row(movie_id=6879, cnt=17)
# Row(movie_id=8228, cnt=17)
# Row(movie_id=5400, cnt=17)
# Row(movie_id=8810, cnt=17)
# Row(movie_id=87222, cnt=17)
# Row(movie_id=84944, cnt=17)
# Row(movie_id=78469, cnt=17)
# Row(movie_id=79695, cnt=17)
# Row(movie_id=181, cnt=17)
# Row(movie_id=6564, cnt=17)
# Row(movie_id=7149, cnt=17)
# Row(movie_id=234, cnt=17)
# Row(movie_id=239, cnt=17)
# Row(movie_id=58293, cnt=17)
# Row(movie_id=2412, cnt=17)
# Row(movie_id=111781, cnt=17)
# Row(movie_id=3646, cnt=17)
# Row(movie_id=79, cnt=17)
# Row(movie_id=248, cnt=17)
# Row(movie_id=4238, cnt=17)
# Row(movie_id=112290, cnt=17)
# Row(movie_id=5014, cnt=17)
# Row(movie_id=8914, cnt=17)
# Row(movie_id=1388, cnt=17)
# Row(movie_id=836, cnt=17)
# Row(movie_id=361, cnt=17)
# Row(movie_id=68554, cnt=17)
# Row(movie_id=2808, cnt=17)
# Row(movie_id=3735, cnt=17)
# Row(movie_id=40278, cnt=17)
# Row(movie_id=67087, cnt=17)
# Row(movie_id=56152, cnt=17)
# Row(movie_id=2072, cnt=17)
# Row(movie_id=5785, cnt=17)
# Row(movie_id=491, cnt=17)
# Row(movie_id=1296, cnt=17)
# Row(movie_id=1464, cnt=17)
# Row(movie_id=136020, cnt=17)
# Row(movie_id=4881, cnt=17)
# Row(movie_id=3633, cnt=17)
# Row(movie_id=4992, cnt=17)
# Row(movie_id=7004, cnt=17)
# Row(movie_id=1248, cnt=17)
# Row(movie_id=3020, cnt=17)
# Row(movie_id=41285, cnt=17)
# Row(movie_id=1171, cnt=17)
# Row(movie_id=477, cnt=17)
# Row(movie_id=7160, cnt=17)
# Row(movie_id=1303, cnt=17)
# Row(movie_id=162, cnt=17)
# Row(movie_id=1635, cnt=17)
# Row(movie_id=6618, cnt=17)
# Row(movie_id=6059, cnt=17)
# Row(movie_id=26662, cnt=17)
# Row(movie_id=3271, cnt=17)
# Row(movie_id=33660, cnt=17)
# Row(movie_id=2311, cnt=17)
# Row(movie_id=117176, cnt=17)
# Row(movie_id=52245, cnt=17)
# Row(movie_id=6548, cnt=17)
# Row(movie_id=33162, cnt=17)
# Row(movie_id=351, cnt=17)
# Row(movie_id=1019, cnt=17)
# Row(movie_id=71264, cnt=17)
# Row(movie_id=2398, cnt=17)
# Row(movie_id=55276, cnt=17)
# Row(movie_id=5419, cnt=17)
# Row(movie_id=7163, cnt=17)
# Row(movie_id=2313, cnt=17)
# Row(movie_id=1835, cnt=17)
# Row(movie_id=3730, cnt=17)
# Row(movie_id=6764, cnt=17)
# Row(movie_id=94677, cnt=17)
# Row(movie_id=267, cnt=17)
# Row(movie_id=3435, cnt=17)
# Row(movie_id=3146, cnt=17)
# Row(movie_id=50068, cnt=17)
# Row(movie_id=61240, cnt=17)
# Row(movie_id=106002, cnt=16)
# Row(movie_id=222, cnt=16)
# Row(movie_id=415, cnt=16)
# Row(movie_id=103253, cnt=16)
# Row(movie_id=106916, cnt=16)
# Row(movie_id=3821, cnt=16)
# Row(movie_id=5690, cnt=16)
# Row(movie_id=532, cnt=16)
# Row(movie_id=2643, cnt=16)
# Row(movie_id=2942, cnt=16)
# Row(movie_id=60126, cnt=16)
# Row(movie_id=3791, cnt=16)
# Row(movie_id=103772, cnt=16)
# Row(movie_id=4039, cnt=16)
# Row(movie_id=136864, cnt=16)
# Row(movie_id=111659, cnt=16)
# Row(movie_id=1665, cnt=16)
# Row(movie_id=9, cnt=16)
# Row(movie_id=2114, cnt=16)
# Row(movie_id=8981, cnt=16)
# Row(movie_id=122926, cnt=16)
# Row(movie_id=88, cnt=16)
# Row(movie_id=2318, cnt=16)
# Row(movie_id=2819, cnt=16)
# Row(movie_id=1894, cnt=16)
# Row(movie_id=575, cnt=16)
# Row(movie_id=36519, cnt=16)
# Row(movie_id=3178, cnt=16)
# Row(movie_id=306, cnt=16)
# Row(movie_id=69406, cnt=16)
# Row(movie_id=3089, cnt=16)
# Row(movie_id=69951, cnt=16)
# Row(movie_id=2735, cnt=16)
# Row(movie_id=1348, cnt=16)
# Row(movie_id=2416, cnt=16)
# Row(movie_id=6586, cnt=16)
# Row(movie_id=1254, cnt=16)
# Row(movie_id=1227, cnt=16)
# Row(movie_id=382, cnt=16)
# Row(movie_id=60950, cnt=16)
# Row(movie_id=1589, cnt=16)
# Row(movie_id=1719, cnt=16)
# Row(movie_id=3763, cnt=16)
# Row(movie_id=73321, cnt=16)
# Row(movie_id=1753, cnt=16)
# Row(movie_id=1892, cnt=16)
# Row(movie_id=2301, cnt=16)
# Row(movie_id=6659, cnt=16)
# Row(movie_id=2450, cnt=16)
# Row(movie_id=314, cnt=16)
# Row(movie_id=114180, cnt=16)
# Row(movie_id=40583, cnt=16)
# Row(movie_id=140, cnt=16)
# Row(movie_id=1974, cnt=16)
# Row(movie_id=122, cnt=16)
# Row(movie_id=42738, cnt=16)
# Row(movie_id=104879, cnt=16)
# Row(movie_id=23, cnt=16)
# Row(movie_id=5791, cnt=16)
# Row(movie_id=105844, cnt=16)
# Row(movie_id=4054, cnt=16)
# Row(movie_id=103141, cnt=16)
# Row(movie_id=4351, cnt=16)
# Row(movie_id=1411, cnt=16)
# Row(movie_id=7360, cnt=16)
# Row(movie_id=2387, cnt=16)
# Row(movie_id=1702, cnt=16)
# Row(movie_id=4327, cnt=16)
# Row(movie_id=134368, cnt=16)
# Row(movie_id=4499, cnt=16)
# Row(movie_id=2146, cnt=16)
# Row(movie_id=1243, cnt=16)
# Row(movie_id=1431, cnt=16)
# Row(movie_id=3972, cnt=16)
# Row(movie_id=76077, cnt=15)
# Row(movie_id=1217, cnt=15)
# Row(movie_id=502, cnt=15)
# Row(movie_id=5025, cnt=15)
# Row(movie_id=3243, cnt=15)
# Row(movie_id=2116, cnt=15)
# Row(movie_id=1895, cnt=15)
# Row(movie_id=3258, cnt=15)
# Row(movie_id=3398, cnt=15)
# Row(movie_id=412, cnt=15)
# Row(movie_id=2606, cnt=15)
# Row(movie_id=3246, cnt=15)
# Row(movie_id=3156, cnt=15)
# Row(movie_id=3507, cnt=15)
# Row(movie_id=2059, cnt=15)
# Row(movie_id=5992, cnt=15)
# Row(movie_id=3668, cnt=15)
# Row(movie_id=6003, cnt=15)
# Row(movie_id=3836, cnt=15)
# Row(movie_id=8638, cnt=15)
# Row(movie_id=1103, cnt=15)
# Row(movie_id=3591, cnt=15)
# Row(movie_id=3355, cnt=15)
# Row(movie_id=41, cnt=15)
# Row(movie_id=714, cnt=15)
# Row(movie_id=1845, cnt=15)
# Row(movie_id=3060, cnt=15)
# Row(movie_id=3113, cnt=15)
# Row(movie_id=104374, cnt=15)
# Row(movie_id=3526, cnt=15)
# Row(movie_id=3917, cnt=15)
# Row(movie_id=1754, cnt=15)
# Row(movie_id=79293, cnt=15)
# Row(movie_id=114662, cnt=15)
# Row(movie_id=1488, cnt=15)
# Row(movie_id=1959, cnt=15)
# Row(movie_id=2533, cnt=15)
# Row(movie_id=535, cnt=15)
# Row(movie_id=158238, cnt=15)
# Row(movie_id=2004, cnt=15)
# Row(movie_id=52975, cnt=15)
# Row(movie_id=135569, cnt=15)
# Row(movie_id=97306, cnt=15)
# Row(movie_id=135887, cnt=15)
# Row(movie_id=1327, cnt=15)
# Row(movie_id=84772, cnt=15)
# Row(movie_id=67734, cnt=15)
# Row(movie_id=112623, cnt=15)
# Row(movie_id=2468, cnt=15)
# Row(movie_id=1515, cnt=15)
# Row(movie_id=5541, cnt=15)
# Row(movie_id=112175, cnt=15)
# Row(movie_id=168250, cnt=15)
# Row(movie_id=2118, cnt=15)
# Row(movie_id=7347, cnt=15)
# Row(movie_id=76, cnt=15)
# Row(movie_id=3159, cnt=15)
# Row(movie_id=1095, cnt=15)
# Row(movie_id=2447, cnt=15)
# Row(movie_id=7317, cnt=15)
# Row(movie_id=3686, cnt=15)
# Row(movie_id=3978, cnt=15)
# Row(movie_id=1030, cnt=15)
# Row(movie_id=46, cnt=15)
# Row(movie_id=20, cnt=15)
# Row(movie_id=59900, cnt=15)
# Row(movie_id=86, cnt=15)
# Row(movie_id=86911, cnt=15)
# Row(movie_id=1260, cnt=15)
# Row(movie_id=1281, cnt=15)
# Row(movie_id=147, cnt=15)
# Row(movie_id=1057, cnt=15)
# Row(movie_id=839, cnt=15)
# Row(movie_id=2702, cnt=15)
# Row(movie_id=2123, cnt=15)
# Row(movie_id=2794, cnt=15)
# Row(movie_id=2126, cnt=15)
# Row(movie_id=2688, cnt=15)
# Row(movie_id=71530, cnt=14)
# Row(movie_id=49651, cnt=14)
# Row(movie_id=2857, cnt=14)
# Row(movie_id=2966, cnt=14)
# Row(movie_id=47518, cnt=14)
# Row(movie_id=6595, cnt=14)
# Row(movie_id=3440, cnt=14)
# Row(movie_id=2995, cnt=14)
# Row(movie_id=46965, cnt=14)
# Row(movie_id=111360, cnt=14)
# Row(movie_id=232, cnt=14)
# Row(movie_id=71057, cnt=14)
# Row(movie_id=51412, cnt=14)
# Row(movie_id=2297, cnt=14)
# Row(movie_id=8861, cnt=14)
# Row(movie_id=122924, cnt=14)
# Row(movie_id=56145, cnt=14)
# Row(movie_id=7367, cnt=14)
# Row(movie_id=3198, cnt=14)
# Row(movie_id=5878, cnt=14)
# Row(movie_id=1769, cnt=14)
# Row(movie_id=51086, cnt=14)
# Row(movie_id=45431, cnt=14)
# Row(movie_id=6709, cnt=14)
# Row(movie_id=1955, cnt=14)
# Row(movie_id=6385, cnt=14)
# Row(movie_id=48043, cnt=14)
# Row(movie_id=257, cnt=14)
# Row(movie_id=3615, cnt=14)
# Row(movie_id=4144, cnt=14)
# Row(movie_id=6296, cnt=14)
# Row(movie_id=103228, cnt=14)
# Row(movie_id=84374, cnt=14)
# Row(movie_id=98961, cnt=14)
# Row(movie_id=1284, cnt=14)
# Row(movie_id=4887, cnt=14)
# Row(movie_id=2463, cnt=14)
# Row(movie_id=3543, cnt=14)
# Row(movie_id=7439, cnt=14)
# Row(movie_id=26776, cnt=14)
# Row(movie_id=99007, cnt=14)
# Row(movie_id=2367, cnt=14)
# Row(movie_id=65230, cnt=14)
# Row(movie_id=8985, cnt=14)
# Row(movie_id=1251, cnt=14)
# Row(movie_id=100, cnt=14)
# Row(movie_id=2912, cnt=14)
# Row(movie_id=45666, cnt=14)
# Row(movie_id=218, cnt=14)
# Row(movie_id=3980, cnt=14)
# Row(movie_id=951, cnt=14)
# Row(movie_id=3016, cnt=14)
# Row(movie_id=96737, cnt=14)
# Row(movie_id=69644, cnt=14)
# Row(movie_id=5026, cnt=14)
# Row(movie_id=905, cnt=14)
# Row(movie_id=3441, cnt=14)
# Row(movie_id=492, cnt=14)
# Row(movie_id=1619, cnt=14)
# Row(movie_id=4974, cnt=14)
# Row(movie_id=2117, cnt=14)
# Row(movie_id=290, cnt=14)
# Row(movie_id=5066, cnt=14)
# Row(movie_id=60397, cnt=14)
# Row(movie_id=152077, cnt=14)
# Row(movie_id=3999, cnt=14)
# Row(movie_id=6440, cnt=14)
# Row(movie_id=164, cnt=14)
# Row(movie_id=1344, cnt=14)
# Row(movie_id=2422, cnt=14)
# Row(movie_id=2136, cnt=14)
# Row(movie_id=6755, cnt=14)
# Row(movie_id=102123, cnt=14)
# Row(movie_id=542, cnt=14)
# Row(movie_id=2901, cnt=14)
# Row(movie_id=53894, cnt=14)
# Row(movie_id=2950, cnt=14)
# Row(movie_id=90405, cnt=14)
# Row(movie_id=81, cnt=14)
# Row(movie_id=609, cnt=14)
# Row(movie_id=58047, cnt=14)
# Row(movie_id=135143, cnt=14)
# Row(movie_id=47200, cnt=14)
# Row(movie_id=159, cnt=14)
# Row(movie_id=4041, cnt=14)
# Row(movie_id=4017, cnt=14)
# Row(movie_id=534, cnt=14)
# Row(movie_id=52328, cnt=14)
# Row(movie_id=4558, cnt=14)
# Row(movie_id=8366, cnt=14)
# Row(movie_id=3248, cnt=14)
# Row(movie_id=4378, cnt=14)
# Row(movie_id=281, cnt=14)
# Row(movie_id=2060, cnt=14)
# Row(movie_id=26, cnt=13)
# Row(movie_id=1537, cnt=13)
# Row(movie_id=55052, cnt=13)
# Row(movie_id=8640, cnt=13)
# Row(movie_id=111364, cnt=13)
# Row(movie_id=1211, cnt=13)
# Row(movie_id=177765, cnt=13)
# Row(movie_id=8907, cnt=13)
# Row(movie_id=6331, cnt=13)
# Row(movie_id=1799, cnt=13)
# Row(movie_id=4020, cnt=13)
# Row(movie_id=1064, cnt=13)
# Row(movie_id=115210, cnt=13)
# Row(movie_id=417, cnt=13)
# Row(movie_id=4677, cnt=13)
# Row(movie_id=4254, cnt=13)
# Row(movie_id=7156, cnt=13)
# Row(movie_id=77455, cnt=13)
# Row(movie_id=47629, cnt=13)
# Row(movie_id=39446, cnt=13)
# Row(movie_id=5065, cnt=13)
# Row(movie_id=2334, cnt=13)
# Row(movie_id=1135, cnt=13)
# Row(movie_id=7265, cnt=13)
# ...
# Row(movie_id=94867, cnt=1)
# Row(movie_id=27705, cnt=1)
# Row(movie_id=106927, cnt=1)
# Row(movie_id=159069, cnt=1)
# Row(movie_id=6395, cnt=1)
# Row(movie_id=2837, cnt=1)
# Row(movie_id=470, cnt=1)
# Row(movie_id=6561, cnt=1)
# Row(movie_id=4612, cnt=1)
# Row(movie_id=118784, cnt=1)
# Row(movie_id=3625, cnt=1)
# Row(movie_id=5322, cnt=1)
# Row(movie_id=6033, cnt=1)
# Row(movie_id=169992, cnt=1)
# Row(movie_id=92198, cnt=1)
# Row(movie_id=115151, cnt=1)
# Row(movie_id=89039, cnt=1)
# Row(movie_id=3789, cnt=1)
# Row(movie_id=7086, cnt=1)
# Row(movie_id=86000, cnt=1)
# Row(movie_id=92681, cnt=1)
# Row(movie_id=69495, cnt=1)
# Row(movie_id=99638, cnt=1)
# Row(movie_id=27491, cnt=1)
# Row(movie_id=117444, cnt=1)
# Row(movie_id=147282, cnt=1)
# Row(movie_id=173963, cnt=1)
# Row(movie_id=161024, cnt=1)
# Row(movie_id=6246, cnt=1)
# Row(movie_id=56274, cnt=1)
# Row(movie_id=1746, cnt=1)
# Row(movie_id=70663, cnt=1)
# Row(movie_id=7636, cnt=1)
# Row(movie_id=2307, cnt=1)
# Row(movie_id=8512, cnt=1)
# Row(movie_id=2751, cnt=1)
# Row(movie_id=5424, cnt=1)
# Row(movie_id=136654, cnt=1)
# Row(movie_id=3568, cnt=1)
# Row(movie_id=7181, cnt=1)
# Row(movie_id=1180, cnt=1)
# Row(movie_id=6163, cnt=1)
# Row(movie_id=112326, cnt=1)
# Row(movie_id=73741, cnt=1)
# Row(movie_id=102802, cnt=1)
# Row(movie_id=4325, cnt=1)
# Row(movie_id=159161, cnt=1)
# Row(movie_id=77846, cnt=1)
# Row(movie_id=8225, cnt=1)
# Row(movie_id=183295, cnt=1)
# Row(movie_id=32917, cnt=1)
# Row(movie_id=5156, cnt=1)
# Row(movie_id=180045, cnt=1)
# Row(movie_id=5580, cnt=1)
# Row(movie_id=113186, cnt=1)
# Row(movie_id=79536, cnt=1)
# Row(movie_id=85261, cnt=1)
# Row(movie_id=111384, cnt=1)
# Row(movie_id=81681, cnt=1)
# Row(movie_id=5268, cnt=1)
# Row(movie_id=54274, cnt=1)
# Row(movie_id=30994, cnt=1)
# Row(movie_id=72603, cnt=1)
# Row(movie_id=31086, cnt=1)
# Row(movie_id=174681, cnt=1)
# Row(movie_id=7561, cnt=1)
# Row(movie_id=95311, cnt=1)
# Row(movie_id=6279, cnt=1)
# Row(movie_id=3192, cnt=1)
# Row(movie_id=67799, cnt=1)
# Row(movie_id=27866, cnt=1)
# Row(movie_id=31162, cnt=1)
# Row(movie_id=48319, cnt=1)
# Row(movie_id=6596, cnt=1)
# Row(movie_id=91266, cnt=1)
# Row(movie_id=5041, cnt=1)
# Row(movie_id=57502, cnt=1)
# Row(movie_id=77201, cnt=1)
# Row(movie_id=95165, cnt=1)
# Row(movie_id=2008, cnt=1)
# Row(movie_id=3792, cnt=1)
# Row(movie_id=34450, cnt=1)
# Row(movie_id=183611, cnt=1)
# Row(movie_id=27473, cnt=1)
# Row(movie_id=135777, cnt=1)
# Row(movie_id=143559, cnt=1)
# Row(movie_id=184257, cnt=1)
# Row(movie_id=4864, cnt=1)
# Row(movie_id=3389, cnt=1)
# Row(movie_id=33132, cnt=1)
# Row(movie_id=2055, cnt=1)
# Row(movie_id=4953, cnt=1)
# Row(movie_id=7940, cnt=1)
# Row(movie_id=60894, cnt=1)
# Row(movie_id=6408, cnt=1)
# Row(movie_id=109416, cnt=1)
# Row(movie_id=156553, cnt=1)
# Row(movie_id=161918, cnt=1)
# Row(movie_id=6454, cnt=1)
# Row(movie_id=4202, cnt=1)
# Row(movie_id=5028, cnt=1)
# Row(movie_id=26285, cnt=1)
# Row(movie_id=31921, cnt=1)
# Row(movie_id=139052, cnt=1)
# Row(movie_id=149380, cnt=1)
# Row(movie_id=99853, cnt=1)
# Row(movie_id=150554, cnt=1)
# Row(movie_id=26587, cnt=1)
# Row(movie_id=4180, cnt=1)
# Row(movie_id=7459, cnt=1)
# Row(movie_id=190215, cnt=1)
# Row(movie_id=5489, cnt=1)
# Row(movie_id=130842, cnt=1)
# Row(movie_id=118248, cnt=1)
# Row(movie_id=25927, cnt=1)
# Row(movie_id=7455, cnt=1)
# Row(movie_id=117133, cnt=1)
# Row(movie_id=61071, cnt=1)
# Row(movie_id=27246, cnt=1)
# Row(movie_id=7443, cnt=1)
# Row(movie_id=116044, cnt=1)
# Row(movie_id=117, cnt=1)
# Row(movie_id=48214, cnt=1)
# Row(movie_id=91666, cnt=1)
# Row(movie_id=193587, cnt=1)
# Row(movie_id=31952, cnt=1)
# Row(movie_id=6654, cnt=1)
# Row(movie_id=824, cnt=1)
# Row(movie_id=6427, cnt=1)
# Row(movie_id=7713, cnt=1)
# Row(movie_id=7832, cnt=1)
# Row(movie_id=8938, cnt=1)
# Row(movie_id=99191, cnt=1)
# Row(movie_id=176051, cnt=1)
# Row(movie_id=4670, cnt=1)
# Row(movie_id=80083, cnt=1)
# Row(movie_id=160872, cnt=1)
# Row(movie_id=1841, cnt=1)
# Row(movie_id=4658, cnt=1)
# Row(movie_id=987, cnt=1)
# Row(movie_id=110330, cnt=1)
# Row(movie_id=3434, cnt=1)
# Row(movie_id=62437, cnt=1)
# Row(movie_id=1008, cnt=1)
# Row(movie_id=1660, cnt=1)
# Row(movie_id=409, cnt=1)
# Row(movie_id=5515, cnt=1)
# Row(movie_id=7951, cnt=1)
# Row(movie_id=183199, cnt=1)
# Row(movie_id=7716, cnt=1)
# Row(movie_id=112316, cnt=1)
# Row(movie_id=26308, cnt=1)
# Row(movie_id=102800, cnt=1)
# Row(movie_id=3021, cnt=1)
# Row(movie_id=284, cnt=1)
# Row(movie_id=26176, cnt=1)
# Row(movie_id=3920, cnt=1)
# Row(movie_id=8933, cnt=1)
# Row(movie_id=82765, cnt=1)
# Row(movie_id=103483, cnt=1)
# Row(movie_id=81535, cnt=1)
# Row(movie_id=180265, cnt=1)
# Row(movie_id=95761, cnt=1)
# Row(movie_id=175475, cnt=1)
# Row(movie_id=8831, cnt=1)
# Row(movie_id=54934, cnt=1)
# Row(movie_id=5838, cnt=1)
# Row(movie_id=42176, cnt=1)
# Row(movie_id=62208, cnt=1)
# Row(movie_id=59814, cnt=1)
# Row(movie_id=6598, cnt=1)
# Row(movie_id=5779, cnt=1)
# Row(movie_id=94919, cnt=1)
# Row(movie_id=124859, cnt=1)
# Row(movie_id=31903, cnt=1)
# Row(movie_id=91890, cnt=1)
# Row(movie_id=139747, cnt=1)
# Row(movie_id=8934, cnt=1)
# Row(movie_id=33435, cnt=1)
# Row(movie_id=44243, cnt=1)
# Row(movie_id=57499, cnt=1)
# Row(movie_id=1759, cnt=1)
# Row(movie_id=2512, cnt=1)
# Row(movie_id=63826, cnt=1)
# Row(movie_id=69304, cnt=1)
# Row(movie_id=100843, cnt=1)
# Row(movie_id=30818, cnt=1)
# Row(movie_id=4946, cnt=1)
# Row(movie_id=5723, cnt=1)
# Row(movie_id=140627, cnt=1)
# Row(movie_id=7781, cnt=1)
# Row(movie_id=27176, cnt=1)
# Row(movie_id=90528, cnt=1)
# Row(movie_id=46865, cnt=1)
# Row(movie_id=4818, cnt=1)
# Row(movie_id=151501, cnt=1)
# Row(movie_id=27830, cnt=1)
# Row(movie_id=3962, cnt=1)
# Row(movie_id=5269, cnt=1)
# Row(movie_id=510, cnt=1)
# Row(movie_id=175693, cnt=1)
# Row(movie_id=96608, cnt=1)
# Row(movie_id=25797, cnt=1)
# Row(movie_id=136912, cnt=1)
# Row(movie_id=64499, cnt=1)
# Row(movie_id=32392, cnt=1)
# Row(movie_id=4962, cnt=1)
# Row(movie_id=132618, cnt=1)
# Row(movie_id=157130, cnt=1)
# Row(movie_id=187717, cnt=1)
# Row(movie_id=976, cnt=1)
# Row(movie_id=3609, cnt=1)
# Row(movie_id=4046, cnt=1)
# Row(movie_id=8459, cnt=1)
# Row(movie_id=75416, cnt=1)
# Row(movie_id=129779, cnt=1)
# Row(movie_id=161008, cnt=1)
# Row(movie_id=4420, cnt=1)
# Row(movie_id=7037, cnt=1)
# Row(movie_id=31309, cnt=1)
# Row(movie_id=1140, cnt=1)
# Row(movie_id=80572, cnt=1)
# Row(movie_id=27134, cnt=1)
# Row(movie_id=172637, cnt=1)
# Row(movie_id=6571, cnt=1)
# Row(movie_id=51562, cnt=1)
# Row(movie_id=8383, cnt=1)
# Row(movie_id=4404, cnt=1)
# Row(movie_id=5209, cnt=1)
# Row(movie_id=6718, cnt=1)
# Row(movie_id=8587, cnt=1)
# Row(movie_id=33893, cnt=1)
# Row(movie_id=100487, cnt=1)
# Row(movie_id=115216, cnt=1)
# Row(movie_id=2652, cnt=1)
# Row(movie_id=5786, cnt=1)
# Row(movie_id=56389, cnt=1)
# Row(movie_id=5442, cnt=1)
# Row(movie_id=55207, cnt=1)
# Row(movie_id=69227, cnt=1)
# Row(movie_id=1349, cnt=1)
# Row(movie_id=6449, cnt=1)
# Row(movie_id=55805, cnt=1)
# Row(movie_id=158874, cnt=1)
# Row(movie_id=70990, cnt=1)
# Row(movie_id=76751, cnt=1)
# Row(movie_id=2651, cnt=1)
# Row(movie_id=136447, cnt=1)
# Row(movie_id=8571, cnt=1)
# Row(movie_id=183911, cnt=1)
# Row(movie_id=31223, cnt=1)
# Row(movie_id=106785, cnt=1)
# Row(movie_id=179135, cnt=1)
# Row(movie_id=3736, cnt=1)
# Row(movie_id=3648, cnt=1)
# Row(movie_id=4115, cnt=1)
# Row(movie_id=2368, cnt=1)
# Row(movie_id=75816, cnt=1)
# Row(movie_id=98175, cnt=1)
# Row(movie_id=159690, cnt=1)
# Row(movie_id=2930, cnt=1)
# Row(movie_id=5651, cnt=1)
# Row(movie_id=73804, cnt=1)
# Row(movie_id=5839, cnt=1)
# Row(movie_id=26357, cnt=1)
# Row(movie_id=104337, cnt=1)
# Row(movie_id=26195, cnt=1)
# Row(movie_id=27784, cnt=1)
# Row(movie_id=95717, cnt=1)
# Row(movie_id=103366, cnt=1)
# Row(movie_id=102066, cnt=1)
# Row(movie_id=142961, cnt=1)
# Row(movie_id=27523, cnt=1)
# Row(movie_id=4877, cnt=1)
# Row(movie_id=62553, cnt=1)
# Row(movie_id=5889, cnt=1)
# Row(movie_id=33124, cnt=1)
# Row(movie_id=60904, cnt=1)
# Row(movie_id=172909, cnt=1)
# Row(movie_id=183197, cnt=1)
# Row(movie_id=476, cnt=1)
# Row(movie_id=2462, cnt=1)
# Row(movie_id=8588, cnt=1)
# Row(movie_id=126420, cnt=1)
# Row(movie_id=142424, cnt=1)
# Row(movie_id=8774, cnt=1)
# Row(movie_id=61257, cnt=1)
# Row(movie_id=2388, cnt=1)
# Row(movie_id=4449, cnt=1)
# Row(movie_id=114335, cnt=1)
# Row(movie_id=170993, cnt=1)
# Row(movie_id=189547, cnt=1)
# Row(movie_id=34330, cnt=1)
# Row(movie_id=134528, cnt=1)
# Row(movie_id=26073, cnt=1)
# Row(movie_id=60857, cnt=1)
# Row(movie_id=4212, cnt=1)
# Row(movie_id=102278, cnt=1)
# Row(movie_id=6434, cnt=1)
# Row(movie_id=8771, cnt=1)
# Row(movie_id=5704, cnt=1)
# Row(movie_id=96520, cnt=1)
# Row(movie_id=76743, cnt=1)
# Row(movie_id=5513, cnt=1)
# Row(movie_id=82684, cnt=1)
# Row(movie_id=159403, cnt=1)
# Row(movie_id=2892, cnt=1)
# Row(movie_id=4615, cnt=1)
# Row(movie_id=6516, cnt=1)
# Row(movie_id=26796, cnt=1)
# Row(movie_id=27178, cnt=1)
# Row(movie_id=73876, cnt=1)
# Row(movie_id=98061, cnt=1)
# Row(movie_id=189, cnt=1)
# Row(movie_id=2032, cnt=1)
# Row(movie_id=134847, cnt=1)
# Row(movie_id=69140, cnt=1)
# Row(movie_id=164881, cnt=1)
# Row(movie_id=55020, cnt=1)
# Row(movie_id=4830, cnt=1)
# Row(movie_id=65740, cnt=1)
# Row(movie_id=4687, cnt=1)
# Row(movie_id=99574, cnt=1)
# Row(movie_id=3941, cnt=1)
# Row(movie_id=114396, cnt=1)
# Row(movie_id=46574, cnt=1)
# Row(movie_id=163809, cnt=1)
# Row(movie_id=2609, cnt=1)
# Row(movie_id=2156, cnt=1)
# Row(movie_id=8391, cnt=1)
# Row(movie_id=27744, cnt=1)
# Row(movie_id=56333, cnt=1)
# Row(movie_id=126577, cnt=1)
# Row(movie_id=172589, cnt=1)
# Row(movie_id=5358, cnt=1)
# Row(movie_id=26366, cnt=1)
# Row(movie_id=26693, cnt=1)
# Row(movie_id=97328, cnt=1)
# Row(movie_id=165139, cnt=1)
# Row(movie_id=165343, cnt=1)
# Row(movie_id=3832, cnt=1)
# Row(movie_id=120807, cnt=1)
# Row(movie_id=122888, cnt=1)
# Row(movie_id=33629, cnt=1)
# Row(movie_id=95163, cnt=1)
# Row(movie_id=311, cnt=1)
# Row(movie_id=69224, cnt=1)
# Row(movie_id=7843, cnt=1)
# Row(movie_id=42761, cnt=1)
# Row(movie_id=106594, cnt=1)
# Row(movie_id=109241, cnt=1)
# Row(movie_id=142831, cnt=1)
# Row(movie_id=26003, cnt=1)
# Row(movie_id=150696, cnt=1)
# Row(movie_id=130686, cnt=1)
# Row(movie_id=5537, cnt=1)
# Row(movie_id=89388, cnt=1)
# Row(movie_id=103755, cnt=1)
# Row(movie_id=122490, cnt=1)
# Row(movie_id=136664, cnt=1)
# Row(movie_id=8711, cnt=1)
# Row(movie_id=633, cnt=1)
# Row(movie_id=43930, cnt=1)
# Row(movie_id=2774, cnt=1)
# Row(movie_id=59549, cnt=1)
# Row(movie_id=88327, cnt=1)
# Row(movie_id=118270, cnt=1)
# Row(movie_id=2992, cnt=1)
# Row(movie_id=163112, cnt=1)
# Row(movie_id=94735, cnt=1)
# Row(movie_id=106648, cnt=1)
# Row(movie_id=115969, cnt=1)
# Row(movie_id=4198, cnt=1)
# Row(movie_id=8136, cnt=1)
# Row(movie_id=1477, cnt=1)
# Row(movie_id=71810, cnt=1)
# Row(movie_id=3303, cnt=1)
# Row(movie_id=44597, cnt=1)
# Row(movie_id=102760, cnt=1)
# Row(movie_id=180987, cnt=1)
# Row(movie_id=4156, cnt=1)
# Row(movie_id=8463, cnt=1)
# Row(movie_id=32914, cnt=1)
# Row(movie_id=80858, cnt=1)
# Row(movie_id=59667, cnt=1)
# Row(movie_id=285, cnt=1)
# Row(movie_id=112727, cnt=1)
# Row(movie_id=27450, cnt=1)
# Row(movie_id=61167, cnt=1)
# Row(movie_id=74647, cnt=1)
# Row(movie_id=53578, cnt=1)
# Row(movie_id=193579, cnt=1)
# Row(movie_id=69746, cnt=1)
# Row(movie_id=71302, cnt=1)
# Row(movie_id=63239, cnt=1)
# Row(movie_id=4453, cnt=1)
# Row(movie_id=1839, cnt=1)
# Row(movie_id=4952, cnt=1)
# Row(movie_id=109897, cnt=1)
# Row(movie_id=31553, cnt=1)
# Row(movie_id=66915, cnt=1)
# Row(movie_id=97988, cnt=1)
# Row(movie_id=100906, cnt=1)
# Row(movie_id=138610, cnt=1)
# Row(movie_id=93114, cnt=1)
# Row(movie_id=44851, cnt=1)
# Row(movie_id=109596, cnt=1)
# Row(movie_id=165645, cnt=1)
# Row(movie_id=47254, cnt=1)
# Row(movie_id=112512, cnt=1)
# Row(movie_id=137863, cnt=1)
# Row(movie_id=7165, cnt=1)
# Row(movie_id=140850, cnt=1)
# Row(movie_id=84553, cnt=1)
# Row(movie_id=92730, cnt=1)
# Row(movie_id=7730, cnt=1)
# Row(movie_id=3442, cnt=1)
# Row(movie_id=6557, cnt=1)
# Row(movie_id=91981, cnt=1)
# Row(movie_id=107447, cnt=1)
# Row(movie_id=141400, cnt=1)
# Row(movie_id=132333, cnt=1)
# Row(movie_id=174737, cnt=1)
# Row(movie_id=3315, cnt=1)
# Row(movie_id=69211, cnt=1)
# Row(movie_id=6067, cnt=1)
# Row(movie_id=172705, cnt=1)
# Row(movie_id=68444, cnt=1)
# Row(movie_id=4408, cnt=1)
# Row(movie_id=1870, cnt=1)
# Row(movie_id=8137, cnt=1)
# Row(movie_id=2697, cnt=1)
# Row(movie_id=5629, cnt=1)
# Row(movie_id=6289, cnt=1)
# Row(movie_id=8591, cnt=1)
# Row(movie_id=48045, cnt=1)
# Row(movie_id=58306, cnt=1)
# Row(movie_id=263, cnt=1)
# Row(movie_id=47566, cnt=1)
# Row(movie_id=125970, cnt=1)
# Row(movie_id=136503, cnt=1)
# Row(movie_id=53883, cnt=1)
# Row(movie_id=100044, cnt=1)
# Row(movie_id=33188, cnt=1)
# Row(movie_id=52299, cnt=1)
# Row(movie_id=56908, cnt=1)
# Row(movie_id=133377, cnt=1)
# Row(movie_id=139415, cnt=1)
# Row(movie_id=6948, cnt=1)
# Row(movie_id=186587, cnt=1)
# Row(movie_id=3678, cnt=1)
# Row(movie_id=3414, cnt=1)
# Row(movie_id=110591, cnt=1)
# Row(movie_id=336, cnt=1)
# Row(movie_id=147196, cnt=1)
# Row(movie_id=698, cnt=1)
# Row(movie_id=3496, cnt=1)
# Row(movie_id=112070, cnt=1)
# Row(movie_id=7708, cnt=1)
# Row(movie_id=49917, cnt=1)
# Row(movie_id=131439, cnt=1)
# Row(movie_id=4505, cnt=1)
# Row(movie_id=5285, cnt=1)
# Row(movie_id=7058, cnt=1)
# Row(movie_id=1985, cnt=1)
# Row(movie_id=3661, cnt=1)
# Row(movie_id=68835, cnt=1)
# Row(movie_id=5856, cnt=1)
# Row(movie_id=78142, cnt=1)
# Row(movie_id=184349, cnt=1)
# Row(movie_id=127184, cnt=1)
# Row(movie_id=148978, cnt=1)
# Row(movie_id=81831, cnt=1)
# Row(movie_id=26928, cnt=1)
# Row(movie_id=65631, cnt=1)
# Row(movie_id=103233, cnt=1)
# Row(movie_id=5114, cnt=1)
# Row(movie_id=1990, cnt=1)
# Row(movie_id=8601, cnt=1)
# Row(movie_id=185031, cnt=1)
# Row(movie_id=149508, cnt=1)
# Row(movie_id=171811, cnt=1)
# Row(movie_id=107410, cnt=1)
# Row(movie_id=3711, cnt=1)
# Row(movie_id=757, cnt=1)
# Row(movie_id=89047, cnt=1)
# Row(movie_id=110350, cnt=1)
# Row(movie_id=68597, cnt=1)
# Row(movie_id=149334, cnt=1)
# Row(movie_id=173317, cnt=1)
# Row(movie_id=33312, cnt=1)
# Row(movie_id=4064, cnt=1)
# Row(movie_id=31590, cnt=1)
# Row(movie_id=7134, cnt=1)
# Row(movie_id=109295, cnt=1)
# Row(movie_id=129250, cnt=1)
# Row(movie_id=164753, cnt=1)
# Row(movie_id=4236, cnt=1)
# Row(movie_id=956, cnt=1)
# Row(movie_id=50514, cnt=1)
# Row(movie_id=109313, cnt=1)
# Row(movie_id=1652, cnt=1)
# Row(movie_id=113849, cnt=1)
# Row(movie_id=116963, cnt=1)
# Row(movie_id=8143, cnt=1)
# Row(movie_id=6604, cnt=1)
# Row(movie_id=86066, cnt=1)
# Row(movie_id=34397, cnt=1)
# Row(movie_id=5817, cnt=1)
# Row(movie_id=115828, cnt=1)
# Row(movie_id=5649, cnt=1)
# Row(movie_id=8987, cnt=1)
# Row(movie_id=36397, cnt=1)
# Row(movie_id=150993, cnt=1)
# Row(movie_id=6882, cnt=1)
# Row(movie_id=72479, cnt=1)
# Row(movie_id=88697, cnt=1)
# Row(movie_id=77931, cnt=1)
# Row(movie_id=37444, cnt=1)
# Row(movie_id=165671, cnt=1)
# Row(movie_id=73488, cnt=1)
# Row(movie_id=94931, cnt=1)
# Row(movie_id=162082, cnt=1)
# Row(movie_id=148, cnt=1)
# Row(movie_id=74624, cnt=1)
# Row(movie_id=6316, cnt=1)
# Row(movie_id=169982, cnt=1)
# Row(movie_id=44657, cnt=1)
# Row(movie_id=80864, cnt=1)
# Row(movie_id=129659, cnt=1)
# Row(movie_id=6775, cnt=1)
# Row(movie_id=7560, cnt=1)
# Row(movie_id=7457, cnt=1)
# Row(movie_id=113705, cnt=1)
# Row(movie_id=113862, cnt=1)
# Row(movie_id=4496, cnt=1)
# Row(movie_id=115111, cnt=1)
# Row(movie_id=168632, cnt=1)
# Row(movie_id=3455, cnt=1)
# Row(movie_id=78034, cnt=1)
# Row(movie_id=90719, cnt=1)
# Row(movie_id=132488, cnt=1)
# Row(movie_id=2801, cnt=1)
# Row(movie_id=8894, cnt=1)
# Row(movie_id=171917, cnt=1)
# Row(movie_id=113565, cnt=1)
# Row(movie_id=124273, cnt=1)
# Row(movie_id=131130, cnt=1)
# Row(movie_id=3096, cnt=1)
# Row(movie_id=3872, cnt=1)
# Row(movie_id=69953, cnt=1)
# Row(movie_id=91784, cnt=1)
# Row(movie_id=58492, cnt=1)
# Row(movie_id=1656, cnt=1)
# Row(movie_id=93982, cnt=1)
# Row(movie_id=3720, cnt=1)
# Row(movie_id=128832, cnt=1)
# Row(movie_id=6417, cnt=1)
# Row(movie_id=4490, cnt=1)
# Row(movie_id=45183, cnt=1)
# Row(movie_id=165529, cnt=1)
# Row(movie_id=3002, cnt=1)
# Row(movie_id=3289, cnt=1)
# Row(movie_id=68872, cnt=1)
# Row(movie_id=130840, cnt=1)
# Row(movie_id=132362, cnt=1)
# Row(movie_id=114066, cnt=1)
# Row(movie_id=117922, cnt=1)
# Row(movie_id=115203, cnt=1)
# Row(movie_id=50613, cnt=1)
# Row(movie_id=147250, cnt=1)
# Row(movie_id=3894, cnt=1)
# Row(movie_id=8626, cnt=1)
# Row(movie_id=102742, cnt=1)
# Row(movie_id=128902, cnt=1)
# Row(movie_id=93610, cnt=1)
# Row(movie_id=181315, cnt=1)
# Row(movie_id=47384, cnt=1)
# Row(movie_id=7131, cnt=1)
# Row(movie_id=158721, cnt=1)
# Row(movie_id=41724, cnt=1)
# Row(movie_id=96917, cnt=1)
# Row(movie_id=175293, cnt=1)
# Row(movie_id=95690, cnt=1)
# Row(movie_id=168090, cnt=1)
# Row(movie_id=64501, cnt=1)
# Row(movie_id=8954, cnt=1)
# Row(movie_id=8577, cnt=1)
# Row(movie_id=168174, cnt=1)
# Row(movie_id=47793, cnt=1)
# Row(movie_id=94122, cnt=1)
# Row(movie_id=2800, cnt=1)
# Row(movie_id=526, cnt=1)
# Row(movie_id=5550, cnt=1)
# Row(movie_id=32649, cnt=1)

# %%
new_data=top_rated_movies.show(10)
# Out:
# +--------+---+
# |movie_id|cnt|
# +--------+---+
# |     356|329|
# |     318|317|
# |     296|307|
# |     593|279|
# |    2571|278|
# |     260|251|
# |     480|238|
# |     110|237|
# |     589|224|
# |     527|220|
# +--------+---+

# %%
lines_rdd.count()
# Out:
# 100836

# %%
type(lines_rdd)
# Out:
# pyspark.rdd.RDD

# %%
type(lines_rdd.collect())
# Out:
# list

# %%
# stop SparkContext.
sc.stop()
